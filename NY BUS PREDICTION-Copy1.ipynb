# %%
import re
import time
import math
import pandas as pd
import numpy as np
import seaborn as sns
#plt.style.use('seaborn')
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy import stats
from scipy.stats.mstats import winsorize
from scipy.stats import boxcox
from matplotlib import pyplot
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report   
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.preprocessing import binarize
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.decomposition import PCA
from datetime import datetime

# %% [markdown]
# # Predicting if an MTA(Metropolitan Transportation Authority) Bus Will Be Late.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Metropolitan Transportation Authority(MTA) busses in New York city are notorious for being slow and late. For this project we will take a look at a data set from Kaggle and see how accurately we can determine if a bus is going to be late or not. A useful model will be able to be interpreted so that solutions can be developed to improve the bus service performance but we will also be trying to see how accurate wecan get the predictions.

# %%
 # Load data 
#mta = pd.read_csv('C:/Users/keith/Desktop/Thinkful/mta_1706.csv',encoding = "ISO-8859-1",error_bad_lines=False)
mta_bus = pd.read_csv('C:/Users/keith/Desktop/Thinkful/mta_1706_1.csv',encoding = "ISO-8859-1",error_bad_lines=False)
pd.set_option('display.max_columns', 50)
# Out:
# b'Skipping line 53192: expected 17 fields, saw 18\nSkipping line 56712: expected 17 fields, saw 18\nSkipping line 64874: expected 17 fields, saw 18\n'
# b'Skipping line 80636: expected 17 fields, saw 18\nSkipping line 97072: expected 17 fields, saw 18\n'
# b'Skipping line 107697: expected 17 fields, saw 18\nSkipping line 109317: expected 17 fields, saw 18\nSkipping line 119951: expected 17 fields, saw 18\n'
# b'Skipping line 134667: expected 17 fields, saw 18\nSkipping line 139923: expected 17 fields, saw 18\nSkipping line 144309: expected 17 fields, saw 18\nSkipping line 157927: expected 17 fields, saw 18\nSkipping line 158907: expected 17 fields, saw 18\nSkipping line 161424: expected 17 fields, saw 18\n'
# b'Skipping line 173221: expected 17 fields, saw 18\nSkipping line 173623: expected 17 fields, saw 18\nSkipping line 177253: expected 17 fields, saw 18\nSkipping line 181883: expected 17 fields, saw 18\nSkipping line 186684: expected 17 fields, saw 18\nSkipping line 191267: expected 17 fields, saw 18\nSkipping line 192638: expected 17 fields, saw 18\n'
# b'Skipping line 198582: expected 17 fields, saw 18\nSkipping line 207576: expected 17 fields, saw 18\n'
# b'Skipping line 274978: expected 17 fields, saw 18\nSkipping line 282857: expected 17 fields, saw 18\n'
# b'Skipping line 306714: expected 17 fields, saw 18\nSkipping line 307656: expected 17 fields, saw 18\nSkipping line 308636: expected 17 fields, saw 18\nSkipping line 311964: expected 17 fields, saw 18\nSkipping line 315657: expected 17 fields, saw 18\nSkipping line 317437: expected 17 fields, saw 18\n'
# b'Skipping line 332034: expected 17 fields, saw 18\nSkipping line 336792: expected 17 fields, saw 18\n'
# b'Skipping line 360611: expected 17 fields, saw 18\nSkipping line 369173: expected 17 fields, saw 18\nSkipping line 373398: expected 17 fields, saw 18\n'
# b'Skipping line 418734: expected 17 fields, saw 18\nSkipping line 423485: expected 17 fields, saw 18\nSkipping line 425578: expected 17 fields, saw 18\n'
# b'Skipping line 442738: expected 17 fields, saw 18\nSkipping line 446894: expected 17 fields, saw 18\nSkipping line 449808: expected 17 fields, saw 18\n'
# b'Skipping line 464755: expected 17 fields, saw 18\n'
# b'Skipping line 740832: expected 17 fields, saw 18\n'
# b'Skipping line 844406: expected 17 fields, saw 18\n'
# b'Skipping line 872155: expected 17 fields, saw 18\nSkipping line 876394: expected 17 fields, saw 18\n'
# b'Skipping line 899678: expected 17 fields, saw 18\n'
# b'Skipping line 919833: expected 17 fields, saw 18\nSkipping line 929574: expected 17 fields, saw 18\nSkipping line 946011: expected 17 fields, saw 18\n'
# b'Skipping line 957396: expected 17 fields, saw 18\nSkipping line 965579: expected 17 fields, saw 18\nSkipping line 969684: expected 17 fields, saw 18\nSkipping line 976815: expected 17 fields, saw 18\nSkipping line 982269: expected 17 fields, saw 18\n'
# b'Skipping line 992521: expected 17 fields, saw 18\nSkipping line 996306: expected 17 fields, saw 18\nSkipping line 1000790: expected 17 fields, saw 18\n'
# b'Skipping line 1070414: expected 17 fields, saw 18\nSkipping line 1072055: expected 17 fields, saw 18\n'
# b'Skipping line 1101971: expected 17 fields, saw 18\nSkipping line 1106995: expected 17 fields, saw 18\n'
# b'Skipping line 1115222: expected 17 fields, saw 18\nSkipping line 1142539: expected 17 fields, saw 18\nSkipping line 1144118: expected 17 fields, saw 18\n'
# b'Skipping line 1147281: expected 17 fields, saw 18\nSkipping line 1147458: expected 17 fields, saw 18\nSkipping line 1153785: expected 17 fields, saw 18\nSkipping line 1160059: expected 17 fields, saw 18\nSkipping line 1164062: expected 17 fields, saw 18\nSkipping line 1170855: expected 17 fields, saw 18\nSkipping line 1174682: expected 17 fields, saw 18\n'
# b'Skipping line 1186903: expected 17 fields, saw 18\nSkipping line 1188705: expected 17 fields, saw 18\nSkipping line 1190863: expected 17 fields, saw 18\nSkipping line 1210933: expected 17 fields, saw 18\n'
# b'Skipping line 1217362: expected 17 fields, saw 18\nSkipping line 1230158: expected 17 fields, saw 18\nSkipping line 1232587: expected 17 fields, saw 18\nSkipping line 1236069: expected 17 fields, saw 18\n'
# b'Skipping line 1254443: expected 17 fields, saw 18\nSkipping line 1256202: expected 17 fields, saw 18\nSkipping line 1263156: expected 17 fields, saw 18\nSkipping line 1270521: expected 17 fields, saw 18\n'
# b'Skipping line 1281745: expected 17 fields, saw 18\nSkipping line 1282451: expected 17 fields, saw 18\n'
# b'Skipping line 1355578: expected 17 fields, saw 18\n'
# b'Skipping line 1377038: expected 17 fields, saw 18\nSkipping line 1388187: expected 17 fields, saw 18\nSkipping line 1390642: expected 17 fields, saw 18\nSkipping line 1401056: expected 17 fields, saw 18\n'
# b'Skipping line 1416542: expected 17 fields, saw 18\nSkipping line 1416985: expected 17 fields, saw 18\nSkipping line 1422864: expected 17 fields, saw 18\nSkipping line 1423747: expected 17 fields, saw 18\nSkipping line 1430234: expected 17 fields, saw 18\nSkipping line 1433229: expected 17 fields, saw 18\n'
# b'Skipping line 1454896: expected 17 fields, saw 18\nSkipping line 1459654: expected 17 fields, saw 18\nSkipping line 1467629: expected 17 fields, saw 18\nSkipping line 1471608: expected 17 fields, saw 18\n'
# b'Skipping line 1502344: expected 17 fields, saw 18\nSkipping line 1505312: expected 17 fields, saw 18\n'
# b'Skipping line 1525902: expected 17 fields, saw 18\n'
# b'Skipping line 1561590: expected 17 fields, saw 18\n'
# b'Skipping line 1590940: expected 17 fields, saw 18\n'
# b'Skipping line 1636897: expected 17 fields, saw 18\n'
# b'Skipping line 1655995: expected 17 fields, saw 18\nSkipping line 1660656: expected 17 fields, saw 18\n'
# b'Skipping line 1680500: expected 17 fields, saw 18\nSkipping line 1682744: expected 17 fields, saw 18\nSkipping line 1700295: expected 17 fields, saw 18\n'
# b'Skipping line 1707982: expected 17 fields, saw 18\nSkipping line 1720081: expected 17 fields, saw 18\nSkipping line 1723379: expected 17 fields, saw 18\nSkipping line 1732178: expected 17 fields, saw 18\n'
# b'Skipping line 1745701: expected 17 fields, saw 18\n'
# b'Skipping line 1849221: expected 17 fields, saw 18\nSkipping line 1860422: expected 17 fields, saw 18\nSkipping line 1864756: expected 17 fields, saw 18\n'
# b'Skipping line 1901602: expected 17 fields, saw 18\nSkipping line 1907204: expected 17 fields, saw 18\nSkipping line 1921663: expected 17 fields, saw 18\nSkipping line 1923928: expected 17 fields, saw 18\nSkipping line 1929858: expected 17 fields, saw 18\n'
# b'Skipping line 1947980: expected 17 fields, saw 18\nSkipping line 1948149: expected 17 fields, saw 18\nSkipping line 1950035: expected 17 fields, saw 18\n'
# b'Skipping line 1970713: expected 17 fields, saw 18\nSkipping line 1987045: expected 17 fields, saw 18\nSkipping line 1988365: expected 17 fields, saw 18\nSkipping line 1992639: expected 17 fields, saw 18\n'
# b'Skipping line 2000986: expected 17 fields, saw 18\nSkipping line 2019763: expected 17 fields, saw 18\nSkipping line 2020432: expected 17 fields, saw 18\nSkipping line 2028497: expected 17 fields, saw 18\n'
# b'Skipping line 2095920: expected 17 fields, saw 18\n'
# b'Skipping line 2404951: expected 17 fields, saw 18\n'
# b'Skipping line 2437013: expected 17 fields, saw 18\n'
# b'Skipping line 2458160: expected 17 fields, saw 18\n'
# b'Skipping line 2493052: expected 17 fields, saw 18\nSkipping line 2500451: expected 17 fields, saw 18\n'
# b'Skipping line 2523849: expected 17 fields, saw 18\nSkipping line 2541460: expected 17 fields, saw 18\nSkipping line 2554787: expected 17 fields, saw 18\n'
# b'Skipping line 2558302: expected 17 fields, saw 18\nSkipping line 2578372: expected 17 fields, saw 18\n'
# b'Skipping line 2589324: expected 17 fields, saw 18\nSkipping line 2591779: expected 17 fields, saw 18\n'
# b'Skipping line 2682435: expected 17 fields, saw 18\n'
# b'Skipping line 2704020: expected 17 fields, saw 18\nSkipping line 2704911: expected 17 fields, saw 18\n'
# b'Skipping line 2723063: expected 17 fields, saw 18\nSkipping line 2735017: expected 17 fields, saw 18\nSkipping line 2739993: expected 17 fields, saw 18\nSkipping line 2747034: expected 17 fields, saw 18\n'
# b'Skipping line 2787875: expected 17 fields, saw 18\nSkipping line 2796290: expected 17 fields, saw 18\nSkipping line 2798729: expected 17 fields, saw 18\nSkipping line 2800652: expected 17 fields, saw 18\nSkipping line 2808117: expected 17 fields, saw 18\nSkipping line 2813104: expected 17 fields, saw 18\nSkipping line 2815115: expected 17 fields, saw 18\n'
# b'Skipping line 2831078: expected 17 fields, saw 18\nSkipping line 2831884: expected 17 fields, saw 18\nSkipping line 2832778: expected 17 fields, saw 18\n'
# b'Skipping line 2935466: expected 17 fields, saw 18\nSkipping line 2937968: expected 17 fields, saw 18\n'
# b'Skipping line 2952504: expected 17 fields, saw 18\n'
# b'Skipping line 2982958: expected 17 fields, saw 18\nSkipping line 2991335: expected 17 fields, saw 18\nSkipping line 3006710: expected 17 fields, saw 18\nSkipping line 3013361: expected 17 fields, saw 18\n'
# b'Skipping line 3019557: expected 17 fields, saw 18\nSkipping line 3032671: expected 17 fields, saw 18\n'
# b'Skipping line 3068454: expected 17 fields, saw 18\nSkipping line 3079236: expected 17 fields, saw 18\n'
# b'Skipping line 3081942: expected 17 fields, saw 18\nSkipping line 3095240: expected 17 fields, saw 18\n'
# b'Skipping line 3166450: expected 17 fields, saw 18\nSkipping line 3178126: expected 17 fields, saw 18\n'
# b'Skipping line 3192452: expected 17 fields, saw 18\nSkipping line 3197375: expected 17 fields, saw 18\nSkipping line 3201771: expected 17 fields, saw 18\nSkipping line 3204318: expected 17 fields, saw 18\nSkipping line 3204532: expected 17 fields, saw 18\nSkipping line 3210597: expected 17 fields, saw 18\n'
# b'Skipping line 3212282: expected 17 fields, saw 18\nSkipping line 3228977: expected 17 fields, saw 18\nSkipping line 3231910: expected 17 fields, saw 18\nSkipping line 3240546: expected 17 fields, saw 18\nSkipping line 3243270: expected 17 fields, saw 18\n'
# b'Skipping line 3245772: expected 17 fields, saw 18\nSkipping line 3259252: expected 17 fields, saw 18\nSkipping line 3272379: expected 17 fields, saw 18\n'
# b'Skipping line 3280630: expected 17 fields, saw 18\nSkipping line 3281342: expected 17 fields, saw 18\nSkipping line 3291539: expected 17 fields, saw 18\nSkipping line 3300347: expected 17 fields, saw 18\n'
# b'Skipping line 3309875: expected 17 fields, saw 18\nSkipping line 3317106: expected 17 fields, saw 18\nSkipping line 3335049: expected 17 fields, saw 18\n'
# b'Skipping line 3376809: expected 17 fields, saw 18\n'
# b'Skipping line 3412350: expected 17 fields, saw 18\nSkipping line 3419390: expected 17 fields, saw 18\n'
# b'Skipping line 3446892: expected 17 fields, saw 18\nSkipping line 3456194: expected 17 fields, saw 18\nSkipping line 3458959: expected 17 fields, saw 18\nSkipping line 3459635: expected 17 fields, saw 18\nSkipping line 3472051: expected 17 fields, saw 18\n'
# b'Skipping line 3475751: expected 17 fields, saw 18\nSkipping line 3476571: expected 17 fields, saw 18\nSkipping line 3497325: expected 17 fields, saw 18\n'
# b'Skipping line 3512051: expected 17 fields, saw 18\nSkipping line 3515105: expected 17 fields, saw 18\nSkipping line 3527521: expected 17 fields, saw 18\n'
# b'Skipping line 3547380: expected 17 fields, saw 18\nSkipping line 3549855: expected 17 fields, saw 18\n'
# b'Skipping line 3572799: expected 17 fields, saw 18\nSkipping line 3590486: expected 17 fields, saw 18\nSkipping line 3596992: expected 17 fields, saw 18\n'
# b'Skipping line 3960523: expected 17 fields, saw 18\n'
# b'Skipping line 3988533: expected 17 fields, saw 18\nSkipping line 3997918: expected 17 fields, saw 18\n'
# b'Skipping line 3999453: expected 17 fields, saw 18\nSkipping line 4007138: expected 17 fields, saw 18\nSkipping line 4007920: expected 17 fields, saw 18\nSkipping line 4014103: expected 17 fields, saw 18\nSkipping line 4014583: expected 17 fields, saw 18\n'
# b'Skipping line 4037166: expected 17 fields, saw 18\nSkipping line 4058680: expected 17 fields, saw 18\n'
# b'Skipping line 4064046: expected 17 fields, saw 18\nSkipping line 4066807: expected 17 fields, saw 18\nSkipping line 4073482: expected 17 fields, saw 18\nSkipping line 4076186: expected 17 fields, saw 18\nSkipping line 4093190: expected 17 fields, saw 18\nSkipping line 4093852: expected 17 fields, saw 18\n'
# b'Skipping line 4097270: expected 17 fields, saw 18\nSkipping line 4110167: expected 17 fields, saw 18\nSkipping line 4127349: expected 17 fields, saw 18\n'
# b'Skipping line 4164525: expected 17 fields, saw 18\n'
# b'Skipping line 4201456: expected 17 fields, saw 18\nSkipping line 4211555: expected 17 fields, saw 18\n'
# b'Skipping line 4228824: expected 17 fields, saw 18\nSkipping line 4234196: expected 17 fields, saw 18\nSkipping line 4236536: expected 17 fields, saw 18\nSkipping line 4251822: expected 17 fields, saw 18\nSkipping line 4252329: expected 17 fields, saw 18\nSkipping line 4258045: expected 17 fields, saw 18\n'
# b'Skipping line 4260182: expected 17 fields, saw 18\nSkipping line 4263103: expected 17 fields, saw 18\nSkipping line 4271671: expected 17 fields, saw 18\nSkipping line 4278125: expected 17 fields, saw 18\nSkipping line 4285474: expected 17 fields, saw 18\n'
# b'Skipping line 4298761: expected 17 fields, saw 18\nSkipping line 4300543: expected 17 fields, saw 18\nSkipping line 4301790: expected 17 fields, saw 18\nSkipping line 4316570: expected 17 fields, saw 18\n'
# b'Skipping line 4338237: expected 17 fields, saw 18\nSkipping line 4354436: expected 17 fields, saw 18\n'
# b'Skipping line 4361610: expected 17 fields, saw 18\n'
# b'Skipping line 4444283: expected 17 fields, saw 18\n'
# b'Skipping line 4477147: expected 17 fields, saw 18\n'
# b'Skipping line 4492082: expected 17 fields, saw 18\nSkipping line 4495557: expected 17 fields, saw 18\nSkipping line 4501701: expected 17 fields, saw 18\nSkipping line 4510449: expected 17 fields, saw 18\nSkipping line 4513207: expected 17 fields, saw 18\nSkipping line 4521441: expected 17 fields, saw 18\n'
# b'Skipping line 4530077: expected 17 fields, saw 18\nSkipping line 4537333: expected 17 fields, saw 18\nSkipping line 4548580: expected 17 fields, saw 18\n'
# b'Skipping line 4556105: expected 17 fields, saw 18\nSkipping line 4568176: expected 17 fields, saw 18\nSkipping line 4572140: expected 17 fields, saw 18\nSkipping line 4572520: expected 17 fields, saw 18\nSkipping line 4580452: expected 17 fields, saw 18\n'
# b'Skipping line 4612265: expected 17 fields, saw 18\nSkipping line 4618925: expected 17 fields, saw 18\n'
# b'Skipping line 4624453: expected 17 fields, saw 18\nSkipping line 4639035: expected 17 fields, saw 18\n'
# b'Skipping line 4718629: expected 17 fields, saw 18\n'
# b'Skipping line 4742362: expected 17 fields, saw 18\nSkipping line 4748345: expected 17 fields, saw 18\n'
# b'Skipping line 4755233: expected 17 fields, saw 18\nSkipping line 4758047: expected 17 fields, saw 18\nSkipping line 4763645: expected 17 fields, saw 18\nSkipping line 4770279: expected 17 fields, saw 18\nSkipping line 4775067: expected 17 fields, saw 18\nSkipping line 4775823: expected 17 fields, saw 18\nSkipping line 4776025: expected 17 fields, saw 18\nSkipping line 4780525: expected 17 fields, saw 18\n'
# b'Skipping line 4801294: expected 17 fields, saw 18\n'
# b'Skipping line 4818472: expected 17 fields, saw 18\nSkipping line 4830909: expected 17 fields, saw 18\nSkipping line 4832988: expected 17 fields, saw 18\nSkipping line 4835432: expected 17 fields, saw 18\nSkipping line 4836249: expected 17 fields, saw 18\n'
# b'Skipping line 4851377: expected 17 fields, saw 18\nSkipping line 4865343: expected 17 fields, saw 18\n'
# b'Skipping line 4884503: expected 17 fields, saw 18\n'
# b'Skipping line 4958585: expected 17 fields, saw 18\nSkipping line 4961274: expected 17 fields, saw 18\nSkipping line 4974784: expected 17 fields, saw 18\n'
# b'Skipping line 5006716: expected 17 fields, saw 18\nSkipping line 5009085: expected 17 fields, saw 18\n'
# b'Skipping line 5015818: expected 17 fields, saw 18\nSkipping line 5017357: expected 17 fields, saw 18\nSkipping line 5020180: expected 17 fields, saw 18\nSkipping line 5037360: expected 17 fields, saw 18\nSkipping line 5039693: expected 17 fields, saw 18\nSkipping line 5044272: expected 17 fields, saw 18\n'
# b'Skipping line 5048007: expected 17 fields, saw 18\nSkipping line 5055144: expected 17 fields, saw 18\nSkipping line 5056368: expected 17 fields, saw 18\nSkipping line 5063196: expected 17 fields, saw 18\nSkipping line 5071921: expected 17 fields, saw 18\n'
# b'Skipping line 5082156: expected 17 fields, saw 18\n'
# b'Skipping line 5113679: expected 17 fields, saw 18\nSkipping line 5119167: expected 17 fields, saw 18\nSkipping line 5131938: expected 17 fields, saw 18\nSkipping line 5133736: expected 17 fields, saw 18\n'
# b'Skipping line 5158386: expected 17 fields, saw 18\n'
# b'Skipping line 5278636: expected 17 fields, saw 18\n'
# b'Skipping line 5389023: expected 17 fields, saw 18\nSkipping line 5393062: expected 17 fields, saw 18\n'
# b'Skipping line 5410409: expected 17 fields, saw 18\n'
# b'Skipping line 5444054: expected 17 fields, saw 18\n'
# b'Skipping line 5496628: expected 17 fields, saw 18\nSkipping line 5496629: expected 17 fields, saw 18\n'
# b'Skipping line 5510776: expected 17 fields, saw 18\n'
# b'Skipping line 5548626: expected 17 fields, saw 18\nSkipping line 5551773: expected 17 fields, saw 18\nSkipping line 5556312: expected 17 fields, saw 18\nSkipping line 5570453: expected 17 fields, saw 18\n'
# b'Skipping line 5577387: expected 17 fields, saw 18\nSkipping line 5580723: expected 17 fields, saw 18\nSkipping line 5582075: expected 17 fields, saw 18\nSkipping line 5596334: expected 17 fields, saw 18\nSkipping line 5602325: expected 17 fields, saw 18\n'
# b'Skipping line 5606005: expected 17 fields, saw 18\nSkipping line 5621782: expected 17 fields, saw 18\nSkipping line 5629873: expected 17 fields, saw 18\n'
# b'Skipping line 5639776: expected 17 fields, saw 18\nSkipping line 5662907: expected 17 fields, saw 18\n'
# b'Skipping line 5673236: expected 17 fields, saw 18\nSkipping line 5678791: expected 17 fields, saw 18\nSkipping line 5684215: expected 17 fields, saw 18\nSkipping line 5693496: expected 17 fields, saw 18\n'
# b'Skipping line 5731235: expected 17 fields, saw 18\n'
# b'Skipping line 5759128: expected 17 fields, saw 18\nSkipping line 5766555: expected 17 fields, saw 18\n'
# b'Skipping line 5775788: expected 17 fields, saw 18\nSkipping line 5779012: expected 17 fields, saw 18\n'
# b'Skipping line 5801331: expected 17 fields, saw 18\nSkipping line 5807183: expected 17 fields, saw 18\nSkipping line 5812686: expected 17 fields, saw 18\nSkipping line 5822305: expected 17 fields, saw 18\nSkipping line 5828445: expected 17 fields, saw 18\n'
# b'Skipping line 5851730: expected 17 fields, saw 18\nSkipping line 5856208: expected 17 fields, saw 18\nSkipping line 5856889: expected 17 fields, saw 18\nSkipping line 5864523: expected 17 fields, saw 18\n'
# b'Skipping line 5871637: expected 17 fields, saw 18\nSkipping line 5875905: expected 17 fields, saw 18\nSkipping line 5888949: expected 17 fields, saw 18\nSkipping line 5894274: expected 17 fields, saw 18\n'
# b'Skipping line 5901556: expected 17 fields, saw 18\nSkipping line 5908375: expected 17 fields, saw 18\nSkipping line 5928411: expected 17 fields, saw 18\n'
# b'Skipping line 5939929: expected 17 fields, saw 18\n'
# b'Skipping line 5997128: expected 17 fields, saw 18\nSkipping line 6023760: expected 17 fields, saw 18\n'
# b'Skipping line 6030761: expected 17 fields, saw 18\nSkipping line 6032844: expected 17 fields, saw 18\nSkipping line 6046718: expected 17 fields, saw 18\nSkipping line 6060288: expected 17 fields, saw 18\nSkipping line 6060477: expected 17 fields, saw 18\n'
# b'Skipping line 6065731: expected 17 fields, saw 18\nSkipping line 6067656: expected 17 fields, saw 18\nSkipping line 6072908: expected 17 fields, saw 18\nSkipping line 6079543: expected 17 fields, saw 18\nSkipping line 6088356: expected 17 fields, saw 18\nSkipping line 6094155: expected 17 fields, saw 18\n'
# b'Skipping line 6101235: expected 17 fields, saw 18\n'
# b'Skipping line 6132143: expected 17 fields, saw 18\nSkipping line 6139104: expected 17 fields, saw 18\nSkipping line 6146333: expected 17 fields, saw 18\n'
# b'Skipping line 6190077: expected 17 fields, saw 18\nSkipping line 6193015: expected 17 fields, saw 18\n'
# b'Skipping line 6262650: expected 17 fields, saw 18\nSkipping line 6284097: expected 17 fields, saw 18\n'
# b'Skipping line 6292669: expected 17 fields, saw 18\nSkipping line 6302387: expected 17 fields, saw 18\n'
# b'Skipping line 6339934: expected 17 fields, saw 18\nSkipping line 6341457: expected 17 fields, saw 18\nSkipping line 6346586: expected 17 fields, saw 18\nSkipping line 6346878: expected 17 fields, saw 18\n'
# b'Skipping line 6360199: expected 17 fields, saw 18\nSkipping line 6388811: expected 17 fields, saw 18\nSkipping line 6389583: expected 17 fields, saw 18\n'
# b'Skipping line 6401202: expected 17 fields, saw 18\n'
# b'Skipping line 6426884: expected 17 fields, saw 18\nSkipping line 6438882: expected 17 fields, saw 18\nSkipping line 6439104: expected 17 fields, saw 18\n'
# b'Skipping line 6539344: expected 17 fields, saw 18\n'
# b'Skipping line 6567952: expected 17 fields, saw 18\nSkipping line 6569797: expected 17 fields, saw 18\nSkipping line 6574347: expected 17 fields, saw 18\nSkipping line 6577542: expected 17 fields, saw 18\nSkipping line 6578318: expected 17 fields, saw 18\nSkipping line 6579562: expected 17 fields, saw 18\n'
# b'Skipping line 6595302: expected 17 fields, saw 18\nSkipping line 6597315: expected 17 fields, saw 18\nSkipping line 6602012: expected 17 fields, saw 18\nSkipping line 6610542: expected 17 fields, saw 18\n'
# b'Skipping line 6637529: expected 17 fields, saw 18\nSkipping line 6643652: expected 17 fields, saw 18\n'
# b'Skipping line 6689855: expected 17 fields, saw 18\n'

# %% [markdown]
# I am only going to use a sample of the data.

# %%
#take sample because the full set is too much to try to analyze on local machine
mta = mta_bus.sample(n=200000,random_state=20)

# %% [markdown]
# # Data Description

# %% [markdown]
# This dataset was pulled from Kaggle and can be found here: https://www.kaggle.com/stoney71/new-york-city-transport-statistics. The data was collected from MTA SIRI Real Time data feed and the MTA GTFS Schedule data. It contains 6.73 million rows of data and 17 feature columns. It is a mixture of categorical and continuous variables such route names, bus stops, and distances the bus is from the bus stop when recorded. There is also geospacial data of the the location of the bus and well as the time the bus will reach the stop. The recordings are taken every 10 minutes.

# %%
mta.head()
# Out:
#               RecordedAtTime  DirectionRef PublishedLineName  \
# 249431   2017-06-02 00:05:00             1               Q17
# 5083624  2017-06-23 16:20:48             0           B44-SBS
# 2001707  2017-06-09 17:38:05             1               Bx9
# 2315680  2017-06-11 15:10:33             1              Bx41
# 2230060  2017-06-10 22:20:22             1                B1
#
#                             OriginName  OriginLat  OriginLong  \
# 249431                    138 ST/37 AV  40.761806  -73.829559
# 5083624             KNAPP ST/SHORE PKY  40.585033  -73.931328
# 2001707                            NaN        NaN         NaN
# 2315680  WHITE PLAINS RD/E GUN HILL RD  40.877853  -73.866669
# 2230060                     87 ST/4 Av  40.621925  -74.028496
#
#                                   DestinationName  DestinationLat  \
# 249431                          JAMAICA ARCHER AV       40.704933
# 5083624  SBS WLMSBRG BRDG PLZ via NSTRND via RGRS       40.709316
# 2001707                                WEST FARMS       40.840641
# 2315680                THE HUB 150 ST via WEBSTER       40.816887
# 2230060              MANHATTAN BEACH KINGSBORO CC       40.578094
#
#          DestinationLong VehicleRef  VehicleLocation.Latitude  \
# 249431        -73.793320  NYCT_8442                 40.712529
# 5083624       -73.959587  NYCT_5357                 40.603164
# 2001707       -73.879807  NYCT_1214                 40.879992
# 2315680       -73.917488  NYCT_5538                 40.819222
# 2230060       -73.940170  NYCT_7158                 40.576590
#
#          VehicleLocation.Longitude           NextStopPointName  \
# 249431                  -73.784314     HILLSIDE AV/EDGERTON BL
# 5083624                 -73.942410        NOSTRAND AV/KINGS HY
# 2001707                 -73.904038           BROADWAY/W 231 ST
# 2315680                 -73.916341         MELROSE AV/E 152 ST
# 2230060                 -73.968469  BRIGHTON BEACH AV/OCEAN PY
#
#         ArrivalProximityText  DistanceFromStop  ExpectedArrivalTime  \
# 249431           approaching             128.0                  NaN
# 5083624       0.9 miles away            1427.0  2017-06-23 16:26:00
# 2001707          approaching             120.0  2017-06-09 17:39:19
# 2315680        < 1 stop away             154.0  2017-06-11 15:11:24
# 2230060          approaching             104.0  2017-06-10 22:20:58
#
#         ScheduledArrivalTime
# 249431              23:58:34
# 5083624             16:26:16
# 2001707                  NaN
# 2315680             14:59:05
# 2230060             22:21:22

# %%
 mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 249431 to 4007649
# Data columns (total 17 columns):
# RecordedAtTime               200000 non-null object
# DirectionRef                 200000 non-null int64
# PublishedLineName            200000 non-null object
# OriginName                   198089 non-null object
# OriginLat                    198089 non-null float64
# OriginLong                   198089 non-null float64
# DestinationName              200000 non-null object
# DestinationLat               199706 non-null float64
# DestinationLong              199706 non-null float64
# VehicleRef                   200000 non-null object
# VehicleLocation.Latitude     200000 non-null float64
# VehicleLocation.Longitude    200000 non-null float64
# NextStopPointName            199799 non-null object
# ArrivalProximityText         199799 non-null object
# DistanceFromStop             199799 non-null float64
# ExpectedArrivalTime          173610 non-null object
# ScheduledArrivalTime         194797 non-null object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 27.5+ MB

# %%
mta.shape
# Out:
# (200000, 17)

# %% [markdown]
# # Data cleaning

# %%
mta.duplicated().sum()
# Out:
# 0

# %%
#pd.set_option('display.max_columns', None) # disables trucated columns 
#pd.set_option('display.max_rows', None) # disables trucated rows
mta.head()
# Out:
#               RecordedAtTime  DirectionRef PublishedLineName  \
# 249431   2017-06-02 00:05:00             1               Q17
# 5083624  2017-06-23 16:20:48             0           B44-SBS
# 2001707  2017-06-09 17:38:05             1               Bx9
# 2315680  2017-06-11 15:10:33             1              Bx41
# 2230060  2017-06-10 22:20:22             1                B1
#
#                             OriginName  OriginLat  OriginLong  \
# 249431                    138 ST/37 AV  40.761806  -73.829559
# 5083624             KNAPP ST/SHORE PKY  40.585033  -73.931328
# 2001707                            NaN        NaN         NaN
# 2315680  WHITE PLAINS RD/E GUN HILL RD  40.877853  -73.866669
# 2230060                     87 ST/4 Av  40.621925  -74.028496
#
#                                   DestinationName  DestinationLat  \
# 249431                          JAMAICA ARCHER AV       40.704933
# 5083624  SBS WLMSBRG BRDG PLZ via NSTRND via RGRS       40.709316
# 2001707                                WEST FARMS       40.840641
# 2315680                THE HUB 150 ST via WEBSTER       40.816887
# 2230060              MANHATTAN BEACH KINGSBORO CC       40.578094
#
#          DestinationLong VehicleRef  VehicleLocation.Latitude  \
# 249431        -73.793320  NYCT_8442                 40.712529
# 5083624       -73.959587  NYCT_5357                 40.603164
# 2001707       -73.879807  NYCT_1214                 40.879992
# 2315680       -73.917488  NYCT_5538                 40.819222
# 2230060       -73.940170  NYCT_7158                 40.576590
#
#          VehicleLocation.Longitude           NextStopPointName  \
# 249431                  -73.784314     HILLSIDE AV/EDGERTON BL
# 5083624                 -73.942410        NOSTRAND AV/KINGS HY
# 2001707                 -73.904038           BROADWAY/W 231 ST
# 2315680                 -73.916341         MELROSE AV/E 152 ST
# 2230060                 -73.968469  BRIGHTON BEACH AV/OCEAN PY
#
#         ArrivalProximityText  DistanceFromStop  ExpectedArrivalTime  \
# 249431           approaching             128.0                  NaN
# 5083624       0.9 miles away            1427.0  2017-06-23 16:26:00
# 2001707          approaching             120.0  2017-06-09 17:39:19
# 2315680        < 1 stop away             154.0  2017-06-11 15:11:24
# 2230060          approaching             104.0  2017-06-10 22:20:58
#
#         ScheduledArrivalTime
# 249431              23:58:34
# 5083624             16:26:16
# 2001707                  NaN
# 2315680             14:59:05
# 2230060             22:21:22

# %%
mta.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation.Latitude',
#        'VehicleLocation.Longitude', 'NextStopPointName',
#        'ArrivalProximityText', 'DistanceFromStop', 'ExpectedArrivalTime',
#        'ScheduledArrivalTime'],
#       dtype='object')

# %%
mta.columns=['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
       'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
       'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
       'VehicleLocation_Long', 'NextStopPointName',
       'ArrivalProximityText', 'DistanceFromStop', 'ExpectedArrivalTime',
       'ScheduledArrivalTime']

# %%
mta.isnull().sum()
# Out:
# RecordedAtTime              0
# DirectionRef                0
# PublishedLineName           0
# OriginName               1911
# OriginLat                1911
# OriginLong               1911
# DestinationName             0
# DestinationLat            294
# DestinationLong           294
# VehicleRef                  0
# VehicleLocation_Lat         0
# VehicleLocation_Long        0
# NextStopPointName         201
# ArrivalProximityText      201
# DistanceFromStop          201
# ExpectedArrivalTime     26390
# ScheduledArrivalTime     5203
# dtype: int64

# %%
# check to see what percentage of data will be lost if all null values are dropped
(mta.isnull().sum()/mta.isnull().count()*100).astype(str)+" %"
# Out:
# RecordedAtTime                         0.0 %
# DirectionRef                           0.0 %
# PublishedLineName                      0.0 %
# OriginName              0.9554999999999999 %
# OriginLat               0.9554999999999999 %
# OriginLong              0.9554999999999999 %
# DestinationName                        0.0 %
# DestinationLat                       0.147 %
# DestinationLong                      0.147 %
# VehicleRef                             0.0 %
# VehicleLocation_Lat                    0.0 %
# VehicleLocation_Long                   0.0 %
# NextStopPointName                   0.1005 %
# ArrivalProximityText                0.1005 %
# DistanceFromStop                    0.1005 %
# ExpectedArrivalTime                 13.195 %
# ScheduledArrivalTime                2.6015 %
# dtype: object

# %% [markdown]
# We need to drop the rows with missing arrival times. It is usless to us if we can't find the bus is late or not.

# %%
mta = mta[mta.ExpectedArrivalTime.isnull()==False]  
mta.isnull().sum()
# Out:
# RecordedAtTime             0
# DirectionRef               0
# PublishedLineName          0
# OriginName              1623
# OriginLat               1623
# OriginLong              1623
# DestinationName            0
# DestinationLat           221
# DestinationLong          221
# VehicleRef                 0
# VehicleLocation_Lat        0
# VehicleLocation_Long       0
# NextStopPointName          0
# ArrivalProximityText       0
# DistanceFromStop           0
# ExpectedArrivalTime        0
# ScheduledArrivalTime    1623
# dtype: int64

# %%
mta = mta[mta.ScheduledArrivalTime.isnull()==False]
mta.isnull().sum()
# Out:
# RecordedAtTime          0
# DirectionRef            0
# PublishedLineName       0
# OriginName              0
# OriginLat               0
# OriginLong              0
# DestinationName         0
# DestinationLat          0
# DestinationLong         0
# VehicleRef              0
# VehicleLocation_Lat     0
# VehicleLocation_Long    0
# NextStopPointName       0
# ArrivalProximityText    0
# DistanceFromStop        0
# ExpectedArrivalTime     0
# ScheduledArrivalTime    0
# dtype: int64

# %%
len(mta)/200000
# Out:
# 0.859935

# %%
# reindex dataset
mta.index = range(len(mta.index))

# %% [markdown]
# That took care of all of our null values, that we can tell anyway.

# %% [markdown]
# Next we need to create a target variable. We are trying to predict if a bus is going to be late or not so we will convert the time rows in to manageable data and the find the difference in times.

# %%
# modifying "ScheduledArrivalTime" format to match "EstimatedArrivalTime"
mta.loc[list(np.where(mta.ScheduledArrivalTime=='24:00:00')[0]),'ScheduledArrivalTime'] = '00:00:01'
mta['ScheduledArrivalTime'] = pd.to_timedelta(mta.ScheduledArrivalTime)
mta['ScheduledArrivalTime'] = pd.to_timedelta(mta.ScheduledArrivalTime)
mta['ScheduledArrivalTime'] = pd.to_datetime(mta.ScheduledArrivalTime)

# converting "ExpectedArrivalTime" to datetime format and them finding the diffence between ScheduledArrivalTime
# "ExpectedArrivalTime"
mta['ExpectedArrivalTime'] = pd.to_datetime(mta.ExpectedArrivalTime)
mta['ScheduledArrivalTime'] = mta.ExpectedArrivalTime.dt.date.astype('str') +' '+ mta.ScheduledArrivalTime.dt.time.astype('str')
mta['ScheduledArrivalTime'] = pd.to_datetime(mta.ScheduledArrivalTime)
mta['ScheduledArrivalTime'] = pd.to_datetime(mta.ScheduledArrivalTime)
index = mta[(mta.ScheduledArrivalTime.dt.hour==23) & (mta.ExpectedArrivalTime.dt.hour==00)].index
mta.loc[index,'ScheduledArrivalTime'] = mta.ScheduledArrivalTime + pd.DateOffset(days=-1)

# Finally creating a binary target "Late_bus"
mta.loc[list(np.where(mta.ExpectedArrivalTime>mta.ScheduledArrivalTime)[0]),'Time_delay'] = pd.to_datetime(mta.ExpectedArrivalTime -  mta.ScheduledArrivalTime).dt.minute 
mta.loc[list(np.where(mta.ExpectedArrivalTime<mta.ScheduledArrivalTime)[0]),'Time_delay'] = pd.to_datetime(mta.ScheduledArrivalTime - mta.ExpectedArrivalTime ).dt.minute*-1
mta.loc[list(np.where(mta.Time_delay.isna()==True)[0]),'Time_delay'] = 0

mta['Late_Bus'] = np.where(mta.Time_delay>7, 1, 0)

# %%
# checking to make sure that time is only in the month of June
mta.ScheduledArrivalTime.dt.month.unique()
# Out:
# array([6, 5], dtype=int64)

# %%
mta.drop(list(np.where(mta.ScheduledArrivalTime.dt.month==5)[0]),axis='index',inplace=True)
# reindex dataset
mta.index = range(len(mta.index))
mta.ScheduledArrivalTime.dt.month.unique()
# Out:
# array([6], dtype=int64)

# %%
# test to see if it worked from a sample
mta.sample(frac=.001).head()
# Out:
#              RecordedAtTime  DirectionRef PublishedLineName  \
# 123588  2017-06-23 11:40:07             1          Bx12-SBS
# 164163  2017-06-22 15:38:37             1               B63
# 42183   2017-06-29 22:21:47             0               B15
# 169929  2017-06-16 09:29:14             1              Bx31
# 160655  2017-06-24 15:11:59             1          Bx12-SBS
#
#                          OriginName  OriginLat  OriginLong  \
# 123588       PARKING RAMP/ACCESS RD  40.865990  -73.827301
# 164163  BROOKLYN BRIDGE PARK/PIER 6  40.692036  -74.000534
# 42183     MARCUS GARVEY BL/BROADWAY  40.699722  -73.941513
# 169929  VAN CORTLANDT PK E/E 242 ST  40.902660  -73.868378
# 160655       PARKING RAMP/ACCESS RD  40.865990  -73.827301
#
#                            DestinationName  DestinationLat  DestinationLong  \
# 123588  SELECT BUS SERVICE BROADWAY INWOOD       40.867786       -73.920547
# 164163         BAY RIDGE SHORE RD via 5 AV       40.612312       -74.035980
# 42183                          JFK AIRPORT       40.646908       -73.779564
# 169929                      WESTCHESTER SQ       40.841076       -73.842850
# 160655  SELECT BUS SERVICE BROADWAY INWOOD       40.867786       -73.920547
#
#        VehicleRef  VehicleLocation_Lat  VehicleLocation_Long  \
# 123588  NYCT_5772            40.862386            -73.896538
# 164163   NYCT_434            40.689432            -73.991582
# 42183   NYCT_6607            40.668113            -73.878654
# 169929  NYCT_7696            40.868713            -73.842302
# 160655  NYCT_5797            40.867024            -73.920782
#
#                NextStopPointName ArrivalProximityText  DistanceFromStop  \
# 123588   E FORDHAM RD/ JEROME AV        < 1 stop away             417.0
# 164163      ATLANTIC AV/SMITH ST        < 1 stop away             262.0
# 42183    NEW LOTS AV/BERRIMAN ST              at stop              16.0
# 169929  EASTCHESTER RD/SCHORR PL        < 1 stop away             195.0
# 160655       BROADWAY/W 207th ST          approaching             138.0
#
#        ExpectedArrivalTime ScheduledArrivalTime  Time_delay  Late_Bus
# 123588 2017-06-23 11:42:43  2017-06-23 11:40:02         2.0         0
# 164163 2017-06-22 15:40:39  2017-06-22 15:37:25         3.0         0
# 42183  2017-06-29 22:22:08  2017-06-29 22:12:39         9.0         1
# 169929 2017-06-16 09:30:34  2017-06-16 09:29:36         0.0         0
# 160655 2017-06-24 15:12:47  2017-06-24 15:05:00         7.0         0

# %% [markdown]
# The conversion worked. We created a feature 'Time_delay' where the values are the minutes of delay ot the bus. Values that are greater than zero are the number of minutes past the scheduled arrival time. The values that are less that zero are the number of minutes the bus arrived ahead of schedule.
#
# The 'Late_Bus' feature is labels a '1' for a bus who's arrival time is greater than 15 min past the scheduled arrival time and labels a '0' for anything under that time. This is our target

# %%
mta.head()
# Out:
#         RecordedAtTime  DirectionRef PublishedLineName  \
# 0  2017-06-23 16:20:48             0           B44-SBS
# 1  2017-06-11 15:10:33             1              Bx41
# 2  2017-06-10 22:20:22             1                B1
# 3  2017-06-14 10:06:11             1               B62
# 4  2017-06-28 17:09:54             1               Q76
#
#                       OriginName  OriginLat  OriginLong  \
# 0             KNAPP ST/SHORE PKY  40.585033  -73.931328
# 1  WHITE PLAINS RD/E GUN HILL RD  40.877853  -73.866669
# 2                     87 ST/4 Av  40.621925  -74.028496
# 3         JACKSON AV/QUEENS PZ S  40.748638  -73.938446
# 4                   132 ST/20 AV  40.782063  -73.836716
#
#                             DestinationName  DestinationLat  DestinationLong  \
# 0  SBS WLMSBRG BRDG PLZ via NSTRND via RGRS       40.709316       -73.959587
# 1                THE HUB 150 ST via WEBSTER       40.816887       -73.917488
# 2              MANHATTAN BEACH KINGSBORO CC       40.578094       -73.940170
# 3                DOWNTOWN BKLYN FULTON MALL       40.690407       -73.989471
# 4           JAMAICA 165 ST TERM via F LEWIS       40.707615       -73.795540
#
#   VehicleRef  VehicleLocation_Lat  VehicleLocation_Long  \
# 0  NYCT_5357            40.603164            -73.942410
# 1  NYCT_5538            40.819222            -73.916341
# 2  NYCT_7158            40.576590            -73.968469
# 3  NYCT_4519            40.712838            -73.960482
# 4  NYCT_4195            40.715189            -73.773367
#
#             NextStopPointName ArrivalProximityText  DistanceFromStop  \
# 0        NOSTRAND AV/KINGS HY       0.9 miles away            1427.0
# 1         MELROSE AV/E 152 ST        < 1 stop away             154.0
# 2  BRIGHTON BEACH AV/OCEAN PY          approaching             104.0
# 3            DRIGGS AV/S 2 ST          approaching              49.0
# 4          HILLSIDE AV/188 ST              at stop               8.0
#
#   ExpectedArrivalTime ScheduledArrivalTime  Time_delay  Late_Bus
# 0 2017-06-23 16:26:00  2017-06-23 16:26:16         0.0         0
# 1 2017-06-11 15:11:24  2017-06-11 14:59:05        12.0         1
# 2 2017-06-10 22:20:58  2017-06-10 22:21:22         0.0         0
# 3 2017-06-14 10:06:27  2017-06-14 09:59:15         7.0         0
# 4 2017-06-28 17:10:08  2017-06-28 17:03:28         6.0         0

# %%
mta.Late_Bus.value_counts()
# Out:
# 0    126854
# 1     45128
# Name: Late_Bus, dtype: int64

# %% [markdown]
#     Next, "ArrivalProximityText" and "DistanceFromStop" are redundant variables so one can be dropped.

# %%
mta.drop("ArrivalProximityText",1,inplace=True)

# %%
# convert the categorical variables to the correct data type
columns = ['DirectionRef','PublishedLineName','OriginName',
           'DestinationName','VehicleRef','NextStopPointName']
for col in columns:
    mta[col] = mta[col].astype('category')
    
mta['RecordedAtTime'] = pd.to_datetime(mta.RecordedAtTime)

# %%
# breaking up "ScheduledArrivalTime" into components
mta['day'] = pd.to_numeric(mta.ScheduledArrivalTime.dt.day)
mta['hour'] = pd.to_numeric(mta.ScheduledArrivalTime.dt.hour)
mta['minute'] = pd.to_numeric(mta.ScheduledArrivalTime.dt.minute)
mta['weekday'] = mta.ScheduledArrivalTime.dt.day_name().astype('category')
mta['day_of_week'] = pd.to_numeric(mta.ScheduledArrivalTime.dt.weekday)

# %%
# sort dataframe by Scheduled arrival time
mta.index = mta.ScheduledArrivalTime
mta = mta.sort_index()
mta.index = range(len(mta))

# %%
mta.head()
# Out:
#        RecordedAtTime DirectionRef PublishedLineName  \
# 0 2017-06-01 00:13:34            1               M15
# 1 2017-06-01 00:13:50            0           M23-SBS
# 2 2017-06-01 00:03:28            1               B36
# 3 2017-06-01 23:55:30            0               B65
# 4 2017-06-01 00:03:50            0           M23-SBS
#
#                       OriginName  OriginLat  OriginLong  \
# 0                  E 126 ST/2 AV  40.803230  -73.932449
# 1                  12 AV/W 23 ST  40.748718  -74.008110
# 2  NOSTRAND AV/GRAVESEND NECK RD  40.599972  -73.941872
# 3             SMITH ST/FULTON ST  40.691208  -73.987373
# 4                  12 AV/W 23 ST  40.748718  -74.008110
#
#                            DestinationName  DestinationLat  DestinationLong  \
# 0                     SOUTH FERRY via 2 AV       40.701611       -74.012230
# 1  SELECT BUS EAST SIDE AVENUE C CROSSTOWN       40.733006       -73.974594
# 2                     CONEY ISLAND W 37 ST       40.573429       -74.002480
# 3                       CROWN HTS RALPH AV       40.670197       -73.922546
# 4  SELECT BUS EAST SIDE AVENUE C CROSSTOWN       40.733006       -73.974594
#
#   VehicleRef  VehicleLocation_Lat  VehicleLocation_Long  \
# 0  NYCT_5643            40.701616            -74.011917
# 1  NYCT_5986            40.733219            -73.974631
# 2  NYCT_4890            40.575429            -73.983304
# 3  NYCT_7117            40.691361            -73.987366
# 4  NYCT_5930            40.748865            -74.006943
#
#         NextStopPointName  DistanceFromStop ExpectedArrivalTime  \
# 0   SOUTH ST/WHITEHALL ST              25.0 2017-06-01 00:13:57
# 1            AV C/E 20 ST              23.0 2017-06-01 00:13:57
# 2        SURF AV /W 17 ST              89.0 2017-06-01 00:04:08
# 3  BOERUM PL/JORALEMON ST             196.0 2017-06-01 23:55:58
# 4           W 23 ST/11 AV              36.0 2017-06-01 00:04:07
#
#   ScheduledArrivalTime  Time_delay  Late_Bus  day  hour  minute   weekday  \
# 0  2017-06-01 00:00:01        13.0         1    1     0       0  Thursday
# 1  2017-06-01 00:01:00        12.0         1    1     0       1  Thursday
# 2  2017-06-01 00:01:09         2.0         0    1     0       1  Thursday
# 3  2017-06-01 00:01:09        54.0         1    1     0       1  Thursday
# 4  2017-06-01 00:01:22         2.0         0    1     0       1  Thursday
#
#    day_of_week
# 0            3
# 1            3
# 2            3
# 3            3
# 4            3

# %% [markdown]
# # Exploratory Data Analysis

# %%
mta.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
#        'VehicleLocation_Long', 'NextStopPointName', 'DistanceFromStop',
#        'ExpectedArrivalTime', 'ScheduledArrivalTime', 'Time_delay', 'Late_Bus',
#        'day', 'hour', 'minute', 'weekday', 'day_of_week'],
#       dtype='object')

# %%
mta.describe()
# Out:
#            OriginLat     OriginLong  DestinationLat  DestinationLong  \
# count  171982.000000  171982.000000   171982.000000    171982.000000
# mean       40.729743     -73.931292       40.728878       -73.931646
# std         0.090307       0.093433        0.090422         0.094624
# min        40.506882     -74.248062       40.508106       -74.246948
# 25%        40.660664     -73.987373       40.660854       -73.988831
# 50%        40.715233     -73.932449       40.713356       -73.932266
# 75%        40.809174     -73.879936       40.809078       -73.878326
# max        40.912365     -73.701866       40.912376       -73.701385
#
#        VehicleLocation_Lat  VehicleLocation_Long  DistanceFromStop  \
# count        171982.000000         171982.000000     171982.000000
# mean             40.728741            -73.930962        245.051738
# std               0.086789              0.088194       1027.517800
# min              40.502898            -74.252338          0.000000
# 25%              40.659367            -73.978920         32.000000
# 50%              40.723188            -73.936394        104.000000
# 75%              40.804045            -73.883442        212.000000
# max              40.912340            -73.701492      33604.000000
#
#           Time_delay      Late_Bus            day           hour  \
# count  171982.000000  171982.00000  171982.000000  171982.000000
# mean        5.344042       0.26240      15.444110      13.079200
# std         9.176854       0.43994       8.725905       5.399986
# min       -59.000000       0.00000       1.000000       0.000000
# 25%         0.000000       0.00000       8.000000       9.000000
# 50%         3.000000       0.00000      15.000000      13.000000
# 75%         8.000000       1.00000      23.000000      17.000000
# max        59.000000       1.00000      30.000000      23.000000
#
#               minute    day_of_week
# count  171982.000000  171982.000000
# mean       29.409113       2.760277
# std        17.338473       1.823133
# min         0.000000       0.000000
# 25%        14.000000       1.000000
# 50%        29.000000       3.000000
# 75%        44.000000       4.000000
# max        59.000000       6.000000

# %%
mta.hist(figsize=(11,11),bins=20)
plt.show()

# %% [markdown]
# From the histograms of our continuous features we can see that we have a very unbalanced target, which would be expected. There should definetly be more on-time busses that late ones. From here I want to look at the continuous variables for against the target.

# %%
# Test of the mean distance between stops of late and on-time busses
Late_Bus_dist = mta[mta.Late_Bus==1] 
On_Time_Bus_dist = mta[mta.Late_Bus==0] 
print(stats.ttest_ind(Late_Bus_dist.DistanceFromStop,On_Time_Bus_dist.DistanceFromStop),'\n')

# calculate correlation distance from stop and late busses
print('Correlation of distance from stops and late busses \n',mta.DistanceFromStop.corr(mta.Late_Bus))
print()
print(stats.ttest_ind(Late_Bus_dist.Time_delay,On_Time_Bus_dist.Time_delay),'\n')
# Out:
# Ttest_indResult(statistic=7.869970433057999, pvalue=3.567719827090452e-15)
#
# Correlation of distance from stops and late busses
#  0.018973870829949994
#
# Ttest_indResult(statistic=486.5687532774816, pvalue=0.0)

# %% [markdown]
# There is a statistically significant difference in the average distance from stop of Late busses and on-time busses. There is also a positive correlation between distance from stop and late busses.

# %%
mta[['Time_delay','DistanceFromStop']].describe()
# Out:
#           Time_delay  DistanceFromStop
# count  171982.000000     171982.000000
# mean        5.344042        245.051738
# std         9.176854       1027.517800
# min       -59.000000          0.000000
# 25%         0.000000         32.000000
# 50%         3.000000        104.000000
# 75%         8.000000        212.000000
# max        59.000000      33604.000000

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.boxplot(mta.Time_delay)
plt.title('Time Delay')
plt.subplot(222)
plt.title('Distance From Stop')
plt.boxplot(mta.DistanceFromStop) 
plt.show()

# %% [markdown]
# Nothing will be done to correct the outliers in the Time Delay variable. We used this to create out target variable and it will not be used in any models. As far a the distance from stop variable we can look at winzorizing to minimize the outliers.

# %%
winsor_dist = winsorize(mta["DistanceFromStop"], (0, .1)) # one way wizorization of distance from stop 
#                                                           variable with limit set at the 90th percentile

plt.figure(figsize=(10,10))
plt.title('Distance From Stop') 
plt.subplot(221)
plt.title('Distance From Stop')
plt.boxplot(mta.DistanceFromStop) 


plt.subplot(222)
plt.title('Winsorized Distance From Stop')
plt.boxplot(winsor_dist)
plt.show()

# %%
# create a feature for winsorization of the distance from stops
mta['winsor_dist'] = winsor_dist

# %%
mta.sample(frac=.1)[:10]
# Out:
#             RecordedAtTime DirectionRef PublishedLineName  \
# 114664 2017-06-21 06:56:24            1               Q32
# 100253 2017-06-18 10:52:36            1               B47
# 11961  2017-06-02 18:56:43            1               Q77
# 148986 2017-06-27 08:36:59            0               Bx3
# 125272 2017-06-22 18:09:33            1               Q32
# 95353  2017-06-17 07:50:13            1               X10
# 94079  2017-06-16 20:29:13            0           M15-SBS
# 124529 2017-06-22 15:58:02            0               B61
# 20980  2017-06-04 20:48:08            1               Q48
# 106499 2017-06-19 16:24:33            0           M15-SBS
#
#                          OriginName  OriginLat  OriginLong  \
# 114664            82 ST/NORTHERN BL  40.755196  -73.885406
# 100253  MARCUS GARVEY BLVD/BROADWAY  40.699574  -73.941444
# 11961         165 ST / BUS TERMINAL  40.708622  -73.795944
# 148986              BROADWAY/179 ST  40.849327  -73.936508
# 125272            82 ST/NORTHERN BL  40.755196  -73.885406
# 95353                  E 57 ST/3 AV  40.760429  -73.967674
# 94079          SOUTH FERRY/TERMINAL  40.702171  -74.013535
# 124529          PROSPECT PK W/18 ST  40.657639  -73.982887
# 20980          ROOSEVELT AV/MAIN ST  40.759586  -73.830299
# 106499         SOUTH FERRY/TERMINAL  40.702171  -74.013535
#
#                                  DestinationName  DestinationLat  \
# 114664                           MIDTOWN PENN ST       40.749435
# 100253                  KINGS PLAZA via RALPH AV       40.611008
# 11961                 SPRINGFIELD GARDENS 145 RD       40.663960
# 148986                   RIVERDALE BWAY - 238 ST       40.885086
# 125272                           MIDTOWN PENN ST       40.749435
# 95353   PT RICHMOND via NARROWS RD via GANNON AV       40.633698
# 94079          SELECT BUS SERVICE 125ST via 1 AV       40.803150
# 124529   DOWNTOWN BKLYN FULTON MALL via RED HOOK       40.690514
# 20980                          LAGUARDIA AIRPORT       40.768642
# 106499         SELECT BUS SERVICE 125ST via 1 AV       40.803150
#
#         DestinationLong VehicleRef  VehicleLocation_Lat  VehicleLocation_Long  \
# 114664       -73.991081  NYCT_7414            40.749542            -73.991173
# 100253       -73.920410  NYCT_4557            40.657248            -73.924925
# 11961        -73.759315  NYCT_8063            40.673521            -73.756232
# 148986       -73.900436  NYCT_4381            40.857757            -73.909439
# 125272       -73.991081  NYCT_7396            40.746369            -73.934746
# 95353        -74.129776  NYCT_2656            40.736912            -73.988751
# 94079        -73.932266  NYCT_1234            40.733679            -73.980876
# 124529       -73.987724   NYCT_422            40.679083            -74.010867
# 20980        -73.868271  NYCT_4476            40.768930            -73.868539
# 106499       -73.932266  NYCT_1263            40.717297            -73.991236
#
#               NextStopPointName  DistanceFromStop ExpectedArrivalTime  \
# 114664             W 32 ST/7 AV              12.0 2017-06-21 06:56:38
# 100253     REMSEN AV/LENOX ROAD             188.0 2017-06-18 10:53:34
# 11961     SPRINGFIELD BL/139 AV              49.0 2017-06-02 18:56:57
# 148986   UNIVERSITY AV/W 183 ST             284.0 2017-06-27 08:37:58
# 125272    QUEENS BL/QUEENS PZ E             342.0 2017-06-22 18:16:59
# 95353          BROADWAY/E 13 ST             324.0 2017-06-17 07:51:18
# 94079              1 AV/E 25 ST             552.0 2017-06-16 20:31:45
# 124529  VAN BRUNT ST/PIONEER ST              10.0 2017-06-22 15:58:35
# 20980               23 AV/97 ST             405.0 2017-06-04 20:49:51
# 106499              1 AV/E 1 ST             805.0 2017-06-19 16:29:23
#
#        ScheduledArrivalTime  Time_delay  Late_Bus  day  hour  minute  \
# 114664  2017-06-21 06:45:00        11.0         1   21     6      45
# 100253  2017-06-18 10:51:14         2.0         0   18    10      51
# 11961   2017-06-02 18:55:45         1.0         0    2    18      55
# 148986  2017-06-27 08:37:19         0.0         0   27     8      37
# 125272  2017-06-22 17:39:14        37.0         1   22    17      39
# 95353   2017-06-17 07:48:17         3.0         0   17     7      48
# 94079   2017-06-16 20:24:41         7.0         0   16    20      24
# 124529  2017-06-22 15:53:10         5.0         0   22    15      53
# 20980   2017-06-04 20:49:19         0.0         0    4    20      49
# 106499  2017-06-19 16:28:00         1.0         0   19    16      28
#
#           weekday  day_of_week  winsor_dist
# 114664  Wednesday            2         12.0
# 100253     Sunday            6        188.0
# 11961      Friday            4         49.0
# 148986    Tuesday            1        284.0
# 125272   Thursday            3        342.0
# 95353    Saturday            5        324.0
# 94079      Friday            4        388.0
# 124529   Thursday            3         10.0
# 20980      Sunday            6        388.0
# 106499     Monday            0        388.0

# %% [markdown]
# # Categorical Variables

# %%
mta[['PublishedLineName', 'OriginName','DestinationName','VehicleRef','NextStopPointName']].describe()
# Out:
#        PublishedLineName     OriginName           DestinationName VehicleRef  \
# count             171982         171982                    171982     171982
# unique               236            582                       610       4460
# top                   B6  E 126 ST/2 AV  WASHINGTON HTS GW BRIDGE  NYCT_4624
# freq                3299           2923                      2395         94
#
#              NextStopPointName
# count                   171982
# unique                    8877
# top     BAY ST/NICK LAPORTE PL
# freq                       340

# %% [markdown]
# # Late Buses and Time Delays by hour

# %%
plt.figure(figsize=(14,16))
plt.subplot(321)
sns.lineplot(x= mta.ScheduledArrivalTime.dt.hour, 
             y=mta.Time_delay, data=mta,)
plt.title('Average Arrival delay (24 hours)') 
plt.xlabel('Hour')

plt.subplot(322)
sns.barplot(mta.ScheduledArrivalTime.dt.hour,mta[mta.DistanceFromStop<500].Late_Bus,palette= "gist_gray_r")
plt.title('Average Times a Bus is Late per hour')
plt.xlabel('Hour')

plt.subplot(323)
sns.countplot(mta.ScheduledArrivalTime.dt.hour, palette= "gist_gray_r")
plt.title('Number of Stops per Hour') 
plt.xlabel('Hour')

plt.subplot(324)
hour_df = pd.DataFrame(mta.groupby('hour').VehicleRef.unique())
hour_df = pd.DataFrame(hour_df.VehicleRef.apply(lambda x : len(x)))
plt.title('Number of Unique Busses in Service')
plt.xlabel('Hour')
plt.ylabel('Busses in Service')
hour_df['hour'] = hour_df.index
hour_df.index = range(len(hour_df))
sns.barplot(hour_df.hour, hour_df.VehicleRef, palette= "gist_gray_r")
plt.ylabel('Average Number of Busses')

plt.show()

# %% [markdown]
# After 6a.m. then average number of late busses steadily increases and peaks at 6p.m. It then flattens and falls between the hours of 1a.m. and 6a.m. This could be because there is less traffic at this time.

# %%
index = mta[(mta.ScheduledArrivalTime.dt.hour>=8) & (mta.ScheduledArrivalTime.dt.hour<=19)].index  
mta['increased_Late'] = 0
mta.loc[index,'increased_Late'] = 1

# %%
mta.increased_Late.value_counts()
# Out:
# 1    120915
# 0     51067
# Name: increased_Late, dtype: int64

# %% [markdown]
# Here I am going to bin hours in to groups to form a feature that represents afternoon evening and night to caprture the differences in late busses during those times.

# %%
# create time of day feature
bins=[-1, 5, 11, 16, 20, 23]
bin_names = ['night','morning','afternoon','evening','Night']
mta['time_of_day'] = pd.cut(mta.ScheduledArrivalTime.dt.hour, bins,labels=bin_names)
mta['time_of_day'] = mta['time_of_day'].str.lower().astype('category')

# %%
(mta.groupby(mta.time_of_day).Late_Bus.mean().sort_index(ascending=False)*100).astype(str)+" %"
# Out:
# time_of_day
# night        23.938938360124897 %
# morning      18.251778968637442 %
# evening      34.281757851282855 %
# afternoon     30.30165971839849 %
# Name: Late_Bus, dtype: object

# %% [markdown]
# Afternoon and evening look to have the greatest average of late busses. Before looking I would have expected morning and evening to have the worse of the problem because of traffic at those times. Lets do a ttest to confirm that there is significant differences in the average number of late busses between each time of day.

# %%
# t-test between the means of the percentage of late busses of the hours in the day
tod_pvalues = {}
for i in range(len(mta.time_of_day.unique())):
        for j in range(i+1,4):
            print(mta.time_of_day.unique()[i],' vs ',mta.time_of_day
                  .unique()[j]) 
            print(stats.ttest_ind(
                mta[mta.time_of_day==mta.time_of_day.unique()[i]]['Late_Bus'], 
                mta[mta.time_of_day==mta.time_of_day.unique()[j]]['Late_Bus']))
# Out:
# night  vs  morning
# Ttest_indResult(statistic=19.00889082229515, pvalue=2.136968194419023e-80)
# night  vs  afternoon
# Ttest_indResult(statistic=-18.583812273183533, pvalue=6.413705965363733e-77)
# night  vs  evening
# Ttest_indResult(statistic=-28.209624725402243, pvalue=5.1712516060528955e-174)
# morning  vs  afternoon
# Ttest_indResult(statistic=-46.74507788922478, pvalue=0.0)
# morning  vs  evening
# Ttest_indResult(statistic=-57.18821681162569, pvalue=0.0)
# afternoon  vs  evening
# Ttest_indResult(statistic=-12.618618392964219, pvalue=1.7915378013284652e-36)

# %% [markdown]
#  There looks to be significant diffences between each time of day.

# %% [markdown]
# ### What percentage of buses are late per hour?

# %% [markdown]
# Here is a numerical representation of the graphs above.

# %%
(mta.groupby(mta.ScheduledArrivalTime.dt.hour).Late_Bus.mean().sort_index(ascending=False)*100).astype(str)+" %"
# Out:
# ScheduledArrivalTime
# 23    29.976209357652657 %
# 22     28.85763000852515 %
# 21    28.756004638065264 %
# 20    28.446601941747574 %
# 19     32.71506599908967 %
# 18     37.24170172978027 %
# 17    36.369916242120716 %
# 16     34.34282253179891 %
# 15    30.399071511472194 %
# 14    29.870909636745722 %
# 13    29.231763818554036 %
# 12    26.496598639455783 %
# 11     24.40225880091313 %
# 10     22.69359464627151 %
# 9     21.458667736757626 %
# 8      18.52512155591572 %
# 7     12.466721747911503 %
# 6      9.611277231952158 %
# 5      9.563066776586975 %
# 4      16.15956727518594 %
# 3     14.101184068891282 %
# 2     12.812499999999998 %
# 1     19.889162561576352 %
# 0     29.378127233738383 %
# Name: Late_Bus, dtype: object

# %% [markdown]
# # Late Busses and Time Delays by day of the Week

# %%
print('Description of Late Busses Delays by Weekday')
weekday_order={0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
Late_bus_mean = mta[mta.Time_delay>=0].groupby(mta.ScheduledArrivalTime.dt.weekday).Late_Bus.describe()
Late_bus_mean.index = weekday_order.values()
Late_bus_mean
# Out:
# Description of Late Busses Delays by Weekday
#              count      mean       std  min  25%  50%  75%  max
# Monday     20527.0  0.255956  0.436408  0.0  0.0  0.0  1.0  1.0
# Tuesday    20585.0  0.295895  0.456455  0.0  0.0  0.0  1.0  1.0
# Wednesday  21248.0  0.325489  0.468568  0.0  0.0  0.0  1.0  1.0
# Thursday   27062.0  0.316569  0.465146  0.0  0.0  0.0  1.0  1.0
# Friday     27090.0  0.329716  0.470119  0.0  0.0  0.0  1.0  1.0
# Saturday   15871.0  0.345095  0.475414  0.0  0.0  0.0  1.0  1.0
# Sunday     11835.0  0.328771  0.469786  0.0  0.0  0.0  1.0  1.0

# %%
plt.figure(figsize=(14,16))
plt.subplot(321)
sns.lineplot(x= mta.ScheduledArrivalTime.dt.day_name(), 
             y=mta.Time_delay, data=mta)
plt.xticks(range(0,7), weekday_order.values())
plt.title('Average Arrival Delay ') 
plt.xlabel('Weekday')

plt.subplot(322)
sns.barplot(mta.ScheduledArrivalTime.dt.day_name(),mta[mta.DistanceFromStop<500].Late_Bus, palette= "gist_gray_r")
plt.title('Average Times a Bus is Late per Weekday')
plt.xticks(range(0,7), weekday_order.values())
plt.xlabel('Weekday')

plt.subplot(323)
sns.countplot(mta.ScheduledArrivalTime.dt.day_name(), palette= "gist_gray_r")
plt.xticks(range(0,7), weekday_order.values())
plt.title('Number of Stops per Weekday') 
plt.xlabel('Weekday')

plt.subplot(324)
day_df = pd.DataFrame(mta.groupby('day_of_week').VehicleRef.unique())
day_df = pd.DataFrame(day_df.VehicleRef.apply(lambda x : len(x)))
plt.title('Number of Unique Busses in Service')
plt.xlabel('Weekday')
plt.ylabel('Busses in Service')
day_df['Weekday'] = day_df.index
day_df.index = range(len(day_df))
sns.barplot(day_df.Weekday, day_df.VehicleRef,palette= "gist_gray_r")
plt.ylabel('Average Number of Busses')
plt.xticks(range(0,7),weekday_order.values())
plt.show()

# %%
#ttest between the means of the percentage of late busses of the days of the week
pvales = {}
for i in range(len(mta.ScheduledArrivalTime.dt.weekday.unique())):
        for j in range(i+1,7):
            print(mta.ScheduledArrivalTime.dt.day_name().unique()[i],' vs ',mta.ScheduledArrivalTime.dt.day_name().unique()[j]) 
            print(stats.ttest_ind(
                mta[mta.ScheduledArrivalTime.dt.day_name()==mta.ScheduledArrivalTime.dt.day_name().unique()[i]]['Late_Bus'], 
                mta[mta.ScheduledArrivalTime.dt.day_name()==mta.ScheduledArrivalTime.dt.day_name().unique()[j]]['Late_Bus']))
            pvales.update({(mta.ScheduledArrivalTime.dt.day_name().unique()[i],' vs ',mta.ScheduledArrivalTime.dt.day_name().unique()[j]):
                          stats.ttest_ind(
                          mta[mta.ScheduledArrivalTime.dt.day_name()==mta.ScheduledArrivalTime.dt.day_name().unique()[i]]['Late_Bus'], 
                          mta[mta.ScheduledArrivalTime.dt.day_name()==mta.ScheduledArrivalTime.dt.day_name().unique()[j]]['Late_Bus'])[1]})
# Out:
# Thursday  vs  Friday
# Ttest_indResult(statistic=-3.874699610921449, pvalue=0.0001068612521110952)
# Thursday  vs  Saturday
# Ttest_indResult(statistic=-8.44252567407665, pvalue=3.1861069752606367e-17)
# Thursday  vs  Sunday
# Ttest_indResult(statistic=-5.1742028676756, pvalue=2.2984257981419786e-07)
# Thursday  vs  Monday
# Ttest_indResult(statistic=16.24775824958174, pvalue=3.1312035338786083e-59)
# Thursday  vs  Tuesday
# Ttest_indResult(statistic=4.332561679644271, pvalue=1.4763533149085799e-05)
# Thursday  vs  Wednesday
# Ttest_indResult(statistic=-3.5254173327051785, pvalue=0.0004231443955736152)
# Friday  vs  Saturday
# Ttest_indResult(statistic=-5.105234629258896, pvalue=3.315776132304915e-07)
# Friday  vs  Sunday
# Ttest_indResult(statistic=-2.1687617303009112, pvalue=0.03010590212819787)
# Friday  vs  Monday
# Ttest_indResult(statistic=19.830270702355577, pvalue=3.1848433195179643e-87)
# Friday  vs  Tuesday
# Ttest_indResult(statistic=7.910482093475379, pvalue=2.6098200432462915e-15)
# Friday  vs  Wednesday
# Ttest_indResult(statistic=0.098082730314258, pvalue=0.921866943713782)
# Saturday  vs  Sunday
# Ttest_indResult(statistic=2.197323785878246, pvalue=0.028004482797512983)
# Saturday  vs  Monday
# Ttest_indResult(statistic=22.382296532797856, pvalue=2.4294816565989738e-110)
# Saturday  vs  Tuesday
# Ttest_indResult(statistic=11.763974139174929, pvalue=6.698860753522049e-32)
# Saturday  vs  Wednesday
# Ttest_indResult(statistic=4.935154301446632, pvalue=8.038365967849712e-07)
# Sunday  vs  Monday
# Ttest_indResult(statistic=18.131629257898446, pvalue=3.579155436357948e-73)
# Sunday  vs  Tuesday
# Ttest_indResult(statistic=8.406041541117279, pvalue=4.385516766939627e-17)
# Sunday  vs  Wednesday
# Ttest_indResult(statistic=2.1578347214144213, pvalue=0.03094683390202565)
# Monday  vs  Tuesday
# Ttest_indResult(statistic=-11.183855464596471, pvalue=5.29407686953313e-29)
# Monday  vs  Wednesday
# Ttest_indResult(statistic=-18.69705919847827, pvalue=9.576484118453444e-78)
# Tuesday  vs  Wednesday
# Ttest_indResult(statistic=-7.381638168873674, pvalue=1.587930668220014e-13)

# %%
# find all comparisons with pvalues > .05
non_significant = [i for i in pvales if pvales.get(i)>.05]
non_significant
# Out:
# [('Friday', ' vs ', 'Wednesday')]

# %% [markdown]
# There is no statistcal significance in the average number of late busses between the above days of the week.
# Wednesday and Thursday have the greatest average number of late busses. I will make and indicator feature to mark these days.

# %%
# mark Wed and Thurs. as peak late busses
mta['is_midweek'] = 0
mta.loc[list(np.where(mta[(mta.ScheduledArrivalTime.dt.weekday==2)|(mta.ScheduledArrivalTime.dt.weekday==3)])[0]),'is_midweek'] = 1

# %%
mta.is_midweek.value_counts()
# Out:
# 0    114415
# 1     57567
# Name: is_midweek, dtype: int64

# %%
plt.figure(figsize=(17,3))
heat_weekdayhour = mta.pivot_table(index=mta.ScheduledArrivalTime.dt.day_name(), columns=mta.ScheduledArrivalTime.dt.hour, values="Late_Bus")
sns.heatmap(heat_weekdayhour,)
plt.xlabel('Hour')
plt.ylabel('Day')
plt.yticks(np.arange(7),weekday_order.values())
plt.show()

# %% [markdown]
# The heatmap above shows the average late busses of the days of week by hour. There doesnt seem to be any significant difference between the hours that we normally associate with rush hour. it seems that there is just a steady increase of late busses from about 9:30 am up to midnight and then a lull between those times.

# %% [markdown]
# # Late Busses and Time Delays by day of the Month

# %%
plt.figure(figsize=(14,16))
plt.subplot(321)
sns.lineplot(x= mta.ScheduledArrivalTime.dt.day , 
             y=mta.Time_delay, data=mta,)
plt.xlabel('Day')
plt.title('Average Delays')

plt.subplot(322)
sns.barplot(mta.ScheduledArrivalTime.dt.day,mta.Late_Bus,palette= "gist_gray_r")
plt.xlabel('Day')

plt.title('Average Times a Bus is Late')
 
plt.subplot(323)
sns.countplot(mta[mta.Late_Bus==1].ScheduledArrivalTime.dt.day , palette= "gist_gray_r")
plt.title('Number of Late Busses per Hour')
plt.xlabel('Day')

plt.ylabel('Late_busses')

plt.subplot(324)
#daydf = pd.DataFrame(mta.groupby('day').VehicleRef.unique())
#daydf = pd.DataFrame(daydf.VehicleRef.apply(lambda x : len(x)))
#daydf['day_of_month'] = daydf.index
#daydf.index = range(len(daydf))
#sns.barplot(daydf.day_of_month, daydf.VehicleRef,palette= "gist_gray_r")
sns.countplot(mta.ScheduledArrivalTime.dt.day, palette= "gist_gray_r")
plt.title('Number of Unique Busses in Service')
plt.xlabel('Day')
plt.ylabel('Busses in Service')

plt.show()

# %% [markdown]
# The days of the month seem to follow a weekly pattern. With the weekends having the least amount of late busses. The weekends also have fewer busses in service. The number of late busses doesn't seem to be affected by a larger number of busses in service.

# %% [markdown]
# In order to capture the cyclical nature of time sin/cos features of hour ,minute, and day of the week will be calculated so that the end of the cycle is show to be close to the beginning instead of far away.

# %%
# create sin cos features to capture cyclical nature
mta['sin_min'] = np.sin(mta['minute']*(2*np.pi/60))
mta['cos_min'] = np.cos(mta['minute']*(2*np.pi/60))
mta['sin_hour'] = np.sin(mta['hour']*(2.*np.pi/24))
mta['cos_hour'] = np.cos(mta['hour']*(2.*np.pi/24))
mta['sin_day_of_week'] = np.sin(mta['day_of_week']*(2.*np.pi/7))
mta['cos_day_of_week'] = np.cos(mta['day_of_week']*(2.*np.pi/7))

# %%
sns.scatterplot(mta.sin_hour,mta.cos_hour)

# %% [markdown]
# # Inbound and Outbound Late Busses and Delays

# %% [markdown]
# Let's see if there is any difference between the number of late busses of inbound vs outbound busses.

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
sns.barplot(y=mta.Late_Bus,x=mta.DirectionRef,palette="Greens_d",orient='vertical',) 
plt.title('Avg. Late Busses per Direction')
plt.xticks(range(0,2), ['Outbound','Inbound'])

plt.subplot(222)
sns.barplot(y=mta.Time_delay,x=mta.DirectionRef,palette="Greens_d",orient='vertical',) 
plt.title('Avg. Arrival delay per Direction')
plt.xticks(range(0,2), ['Outbound','Inbound'])
plt.show()

# %% [markdown]
# The average number of late busses is higher with the inbound busses as well as the average arrival delay.

# %%
inbound_df = mta[mta.DirectionRef==1]
outbound_df = mta[mta.DirectionRef==0] 
plt.figure(figsize=(15,8))
plt.subplot(221)
sns.lineplot(inbound_df.ScheduledArrivalTime.dt.day.sort_values(), inbound_df.Late_Bus, label='Inbound') 
sns.lineplot(outbound_df.ScheduledArrivalTime.dt.day.sort_values(), outbound_df.Late_Bus, label='Outbound')
plt.title('Average Number of Late Busses per day')
plt.xticks=(np.arange(0,30,.5))
plt.xlabel('Day of Month')
plt.subplot(222)
sns.lineplot(inbound_df.ScheduledArrivalTime.dt.hour.sort_values(), inbound_df.Late_Bus, label='Inbound') 
sns.lineplot(outbound_df.ScheduledArrivalTime.dt.hour.sort_values(), outbound_df.Late_Bus, label='Outbound')
plt.title('Average Number of Late Busses per hour')
plt.xlabel('Hour')
plt.xticks=(np.arange(0,30,.5))
plt.show()

# %% [markdown]
# The inbound and outbound busses show the same pattern over time. With respect hour there are more late inbound busses thoughout most of the day.

# %%
# Test of the mean distance between stops of late and on-time busses 
print(stats.ttest_ind(inbound_df.Late_Bus, outbound_df.Late_Bus),'\n')
# Out:
# Ttest_indResult(statistic=4.790982045336751, pvalue=1.661050328559205e-06)

# %% [markdown]
# ## Distance from stop vs Late Busses

# %%
sns.barplot(x='Late_Bus',y='DistanceFromStop', data=mta, palette="Greens_d")
plt.title('Distance From Stop')
#plt.xticks(list(range(0,2)), ['On-Time','Late'])
plt.show()

# %%
print('Average distance from stop of on-time and late busses')
mta.groupby('Late_Bus').mean()[['DistanceFromStop']]
# Out:
# Average distance from stop of on-time and late busses
#           DistanceFromStop
# Late_Bus
# 0               233.423471
# 1               277.738588

# %%
onTime_df = mta[mta.Late_Bus==1]
Late_df = mta[mta.Late_Bus==0] 
print('Ttest of average distance between stops of late and on-time Busses:')
print()
print(stats.ttest_ind(onTime_df.DistanceFromStop, Late_df.DistanceFromStop),'\n')
# Out:
# Ttest of average distance between stops of late and on-time Busses:
#
# Ttest_indResult(statistic=7.869970433057999, pvalue=3.567719827090452e-15)

# %% [markdown]
# The ttest shows a significant difference between the average distance from a stop and late busses.

# %%
plt.figure(figsize=(8,4))
sns.lineplot(inbound_df.ScheduledArrivalTime.dt.hour.sort_values(), inbound_df.DistanceFromStop, hue=inbound_df.Late_Bus) 
plt.title('Avg. Distance From Stop per hour (inbound)')
plt.show()
plt.figure(figsize=(8,4))

sns.lineplot(outbound_df.ScheduledArrivalTime.dt.hour.sort_values(), outbound_df.DistanceFromStop, hue=outbound_df.Late_Bus)
plt.title('Avg. Distance From Stop per hour (outbound)')
#plt.xticks=(np.arange(0,30,.5))
plt.show() 
plt.figure(figsize=(8,4))
sns.barplot(inbound_df.ScheduledArrivalTime.dt.hour.sort_values(), inbound_df.DistanceFromStop,hue=inbound_df.Late_Bus,palette='winter_r')
plt.title('Distance From Stop vs hour (inbound)')
plt.show()
plt.figure(figsize=(8,4))
sns.barplot(outbound_df.ScheduledArrivalTime.dt.hour.sort_values(), outbound_df.DistanceFromStop,hue=outbound_df.Late_Bus,palette='winter_r')
plt.title('Distance From Stop vs hour (outbound)')
#sns.lineplot(mta.ScheduledArrivalTime.dt.hour.sort_values(), mta.DistanceFromStop, hue=mta.Late_Bus)

plt.show()

# %% [markdown]
# There seems to be a pattern as the day goes on. The distacnce from stops increases for the inbound busses between 3pm and 9pm and for the outbound busses between 5am and 9am. The distance between stops for late busses is father than for the inbound busses than for the outbound. For the outbound busses it seems that distance between stops is greater for the on-time busses. This coincides with New Yorks rush hour. Since the busses are recorded approximately every ten minutes the busses are farther away from their stops for a longer amount of time because of traffic. This could possibly be why this pattern is showing. It doesn't explain the reason the distance between stops is greater for on time busses on the outbound side and the opposite for the inbound. This could be that there are more busses running at that time or that the busses are moving slower but the schedule accounts for those delays making the busses on time.
#
# I'm goding to create an indicator feature to mark this pattern.

# %%
# create rush our indicator feature
mta['rush_hour'] = np.where(np.logical_and(mta.hour>=5, mta.hour<=9) | np.logical_and(mta.hour>=15, mta.hour<=21),1,0)

# %% [markdown]
# ## Which boroughs have the farthest distance from stop?

# %% [markdown]
# The route label prefixes signify the boroughs of New York that the operate in with the exception of routes that begin with "X". The "X" routes are express routes that a operate in all five boroghs and have large distances between stops. Here I will create a feature that groups the published line name(route) in to their areas of operation to condense dimentionality and for analysis.

# %%
# create new feature based on the route names and areas of operation based on prefix
def boroughs():
    mta['boroughs'] = '0'
    mta.loc[list(np.where((mta.PublishedLineName.str.contains('x')==False) & (mta.PublishedLineName.str.startswith('B')==True))[0]),'boroughs'] = 'Brooklyn'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('Bx')==True)[0]),'boroughs'] = 'Bronx'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('Q')==True)[0]),'boroughs'] = 'Queens'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('S')==True)[0]),'boroughs'] = 'Staten Island'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('M')==True)[0]),'boroughs'] = 'Manhattan'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('X')==True)[0]),'boroughs'] = 'X'
    mta['boroughs'] = mta.boroughs.astype('category')
boroughs()

# %%
plt.figure(figsize=(12,5)) 
order = mta.groupby('boroughs').DistanceFromStop.mean().sort_values(ascending=False).index
sns.barplot(x='boroughs',y='DistanceFromStop' ,data=mta, hue=mta.Late_Bus,order=order,palette='winter_r')
plt.title('Distance From Stop vs Boroughs')
plt.show()

# %% [markdown]
# The "X" routes have the largest average distance from stops. It look like those routes are also resposible for the distance from stops for late busses being greater than the distance from stops for the on-time busses. Let's see what happens when we exclude the "X" routes.

# %%
no_x_df = mta[mta.boroughs!='X']
inbound_df = no_x_df[no_x_df.DirectionRef==1]
outbound_df = no_x_df[no_x_df.DirectionRef==0] 

plt.figure(figsize=(8,4))
sns.lineplot(inbound_df.ScheduledArrivalTime.dt.hour.sort_values(), inbound_df.DistanceFromStop, hue=inbound_df.Late_Bus) 
plt.title('Avg. Distance From Stop per hour (inbound)')
plt.show()
plt.figure(figsize=(8,4))

sns.lineplot(outbound_df.ScheduledArrivalTime.dt.hour.sort_values(), outbound_df.DistanceFromStop, hue=outbound_df.Late_Bus)
plt.title('Avg. Distance From Stop per hour (outbound)')
#plt.xticks=(np.arange(0,30,.5))
plt.show() 
plt.figure(figsize=(8,4))
sns.barplot(inbound_df.ScheduledArrivalTime.dt.hour.sort_values(), inbound_df.DistanceFromStop,hue=inbound_df.Late_Bus,palette='winter_r')
plt.title('Distance From Stop vs hour (inbound)')
plt.show()
plt.figure(figsize=(8,4))
sns.barplot(outbound_df.ScheduledArrivalTime.dt.hour.sort_values(), outbound_df.DistanceFromStop,hue=outbound_df.Late_Bus,palette='winter_r')
plt.title('Distance From Stop vs hour (outbound)')
#sns.lineplot(mta.ScheduledArrivalTime.dt.hour.sort_values(), mta.DistanceFromStop, hue=mta.Late_Bus)

plt.show()

# %% [markdown]
# Without the "X" routes the pattern pretty much disappears. This is something to be aware of when modeling because we don't want the algorithm to always focus in on the "X" routes.

# %%
#ttest between the means of the percentage of late busses of the days of the week
pvales = {}
for i in range(len(mta.boroughs.unique())):
        for j in range(i+1,6):
            print(mta.boroughs.unique()[i],' vs ',mta.boroughs.unique()[j]) 
            print(stats.ttest_ind(
                mta[mta.boroughs==mta.boroughs.unique()[i]]['Late_Bus'], 
                mta[mta.boroughs==mta.boroughs.unique()[j]]['Late_Bus']))
            pvales.update({(mta.boroughs.unique()[i],' vs ',mta.boroughs.unique()[j]):
                          stats.ttest_ind(
                          mta[mta.boroughs==mta.boroughs.unique()[i]]['Late_Bus'], 
                          mta[mta.boroughs==mta.boroughs.unique()[j]]['Late_Bus'])[1]})
# Out:
# Manhattan  vs  Brooklyn
# Ttest_indResult(statistic=7.397726815509001, pvalue=1.3978586822200188e-13)
# Manhattan  vs  X
# Ttest_indResult(statistic=-3.2957982418820144, pvalue=0.0009822314757460442)
# Manhattan  vs  Queens
# Ttest_indResult(statistic=18.28209456712291, pvalue=1.7645508928062523e-74)
# Manhattan  vs  Bronx
# Ttest_indResult(statistic=17.287575880836396, pvalue=8.039983664568708e-67)
# Manhattan  vs  Staten Island
# Ttest_indResult(statistic=19.13591801031647, pvalue=2.6653098257053266e-81)
# Brooklyn  vs  X
# Ttest_indResult(statistic=-7.8023183134589615, pvalue=6.175442628223829e-15)
# Brooklyn  vs  Queens
# Ttest_indResult(statistic=12.757972287658887, pvalue=3.05049447126417e-37)
# Brooklyn  vs  Bronx
# Ttest_indResult(statistic=11.484193745937077, pvalue=1.665720825203982e-30)
# Brooklyn  vs  Staten Island
# Ttest_indResult(statistic=15.224669341466809, pvalue=3.006962424779198e-52)
# X  vs  Queens
# Ttest_indResult(statistic=15.164784448740084, pvalue=8.49716149148302e-52)
# X  vs  Bronx
# Ttest_indResult(statistic=14.291021699133108, pvalue=3.164367968222925e-46)
# X  vs  Staten Island
# Ttest_indResult(statistic=17.764177144155315, pvalue=4.952901458685775e-70)
# Queens  vs  Bronx
# Ttest_indResult(statistic=-1.6520788750293354, pvalue=0.09852317844990022)
# Queens  vs  Staten Island
# Ttest_indResult(statistic=6.52253926347369, pvalue=6.991186373482129e-11)
# Bronx  vs  Staten Island
# Ttest_indResult(statistic=7.767742901478943, pvalue=8.152534951109593e-15)

# %%
# find all comparisons with pvalues > .05
non_significant = [i for i in pvales if pvales.get(i)>.05]
non_significant
# Out:
# [('Queens', ' vs ', 'Bronx')]

# %% [markdown]
# ## Compare boroughs to late busses

# %%
plt.figure(figsize=(12,6)) 
plt.subplot(221)
sns.barplot(x='boroughs',y='Late_Bus' ,data=mta,  palette='winter_r' )
plt.title('Avg. Number of Late Busses')

plt.subplot(222)
sns.countplot(x='boroughs',hue='Late_Bus' ,data=mta,  palette='winter_r' )
plt.legend(['On-Time','Late'])
plt.title('Count of Late and On-Time busses')
plt.show()

# %%
# chi-square test to test significance of group size
borough_count_table = pd.crosstab(mta.Late_Bus,mta.boroughs)
print('Chi-square Test Results significance of group size of boroughs')
print(stats.chisquare(borough_count_table, axis=None))
# Out:
# Chi-square Test Results significance of group size of boroughs
# Power_divergenceResult(statistic=97042.84073914713, pvalue=0.0)

# %%
mta.groupby('boroughs').Late_Bus.agg(['mean','count'])
# Out:
#                    mean  count
# boroughs
# Bronx          0.240065  35682
# Brooklyn       0.274687  52052
# Manhattan      0.297884  34265
# Queens         0.234608  31039
# Staten Island  0.204192  10877
# X              0.316598   8067

# %% [markdown]
# Although the "X" routes are represented the least in the dataset they have the highest agverage of late busses.

# %% [markdown]
# #  Geospacial features

# %%
mean_late = mta.PublishedLineName.map(dict(mta.groupby('PublishedLineName').Late_Bus.mean().sort_values(ascending=False)))
plt.figure(figsize=(15,15))
 
plt.subplot(222)
sns.scatterplot(mta.VehicleLocation_Long,mta.VehicleLocation_Lat,hue=mean_late, palette='winter_r')
plt.title('Vehicle Location Coordinates and Late Bus Density')
 
plt.subplot(221)
sns.scatterplot(mta.VehicleLocation_Long,mta.VehicleLocation_Lat,hue=mta.boroughs)
plt.title('Vehicle Location Coordinates by Borough')
plt.show()

# %% [markdown]
# Above are scatterplots of the lattitudes and longitudes of the vehicle locations. You can see the shape of New York made from the lats and longs. There doesn't seem to be any points that fall far outside of the area that we are concerned with. The left plot shows the busses grouped by their respective areas of operation and the left highlights the areas where the average number of late busses is the greatest. This may indicate that vehicle location may be a good predictor of whether a bus is going to be late or not. Since there is no meaningful relationship between the raw lattitude and longitude I will create a couple of features to cut down on the dimentionality and well as creating something useful that a model such a Random Forest could use.

# %%
# function to convert lat and long to zip code

def geo_to_zip(lat,long,zip_type):
    from uszipcode import SearchEngine
    from datetime import datetime
    startTime = datetime.now()
     
    search = SearchEngine(simple_zipcode=True)
    mta['col'] = mta[lat].astype(str)+' '+mta[long].astype(str)
    mta[zip_type] = mta['col'].apply(lambda x: search.by_coordinates(float(x.split()[0]),
                                    float(x.split()[1]), radius=10, returns=5)[0].values()[0])
   
    print(datetime.now() - startTime)
    print('done')
    mta.drop('col',1,inplace=True)
#geo_to_zip('OriginLat', 'OriginLong','Orig_zip')
#geo_to_zip('DestinationLat','DestinationLong','Dest_zip')
#geo_to_zip('VehicleLocation_Lat','VehicleLocation_Long','VL_Zip')

# %%
# fucntion to convert to compute distance between two points and create a columns of those distances
def distance_between_points(lat1,long1,lat2,long2,to_from):
    import mpu
    from datetime import datetime
    startTime = datetime.now()
    mta['point1'] =mta[lat1].astype(str)+" "+mta[long1].astype(str)
    mta['point2'] = mta[lat2].astype(str)+" "+mta[long2].astype(str)

    mta[to_from] = mta['point1']+" "+mta['point2']
    mta[to_from] = mta[to_from].apply(lambda x : mpu.haversine_distance((float(x.split()[0]), float(x.split()[1])),
                                                                              (float(x.split()[2]), float(x.split()[3]))))
    mta.drop('point1',1,inplace=True)
    mta.drop('point2',1,inplace=True)
    print(datetime.now() - startTime)
    print('done')
    return;


distance_between_points('VehicleLocation_Lat','VehicleLocation_Long','DestinationLat','DestinationLong','VL_to_Dest')
distance_between_points('VehicleLocation_Lat','VehicleLocation_Long','OriginLat', 'OriginLong','VL_to_Origin')
distance_between_points('DestinationLat','DestinationLong','OriginLat', 'OriginLong','Dest_to_Origin')
# Out:
# 0:00:01.448850
# done
# 0:00:01.423600
# done
# 0:00:01.420614
# done

# %%
# winsorizing the distances to reduce outliers
mta["winVL_to_Dest"]  = winsorize(mta["VL_to_Dest"], (0, .1)) 
mta["winVL_to_Origin"] =winsor_distVL= winsorize(mta["VL_to_Origin"], (0, .1)) 
mta["winDest_to_Origin"] =winsor_distOD= winsorize(mta["Dest_to_Origin"], (0, .1))

# %%
#create geohash features from lat and long
import pygeohash as gh
mta['VL_geohash']=mta.apply(lambda x: gh.encode(x.VehicleLocation_Lat, x.VehicleLocation_Long, precision=5), axis=1).astype('category')
mta['O_geohash']=mta.apply(lambda x: gh.encode(x.OriginLat, x.OriginLong, precision=5), axis=1).astype('category')
mta['D_geohash']=mta.apply(lambda x: gh.encode(x.DestinationLat, x.DestinationLong, precision=5), axis=1).astype('category')

# %%
mta.head()
# Out:
#        RecordedAtTime DirectionRef PublishedLineName  \
# 0 2017-06-01 00:13:34            1               M15
# 1 2017-06-01 00:13:50            0           M23-SBS
# 2 2017-06-01 00:03:28            1               B36
# 3 2017-06-01 23:55:30            0               B65
# 4 2017-06-01 00:03:50            0           M23-SBS
#
#                       OriginName  OriginLat  OriginLong  \
# 0                  E 126 ST/2 AV  40.803230  -73.932449
# 1                  12 AV/W 23 ST  40.748718  -74.008110
# 2  NOSTRAND AV/GRAVESEND NECK RD  40.599972  -73.941872
# 3             SMITH ST/FULTON ST  40.691208  -73.987373
# 4                  12 AV/W 23 ST  40.748718  -74.008110
#
#                            DestinationName  DestinationLat  DestinationLong  \
# 0                     SOUTH FERRY via 2 AV       40.701611       -74.012230
# 1  SELECT BUS EAST SIDE AVENUE C CROSSTOWN       40.733006       -73.974594
# 2                     CONEY ISLAND W 37 ST       40.573429       -74.002480
# 3                       CROWN HTS RALPH AV       40.670197       -73.922546
# 4  SELECT BUS EAST SIDE AVENUE C CROSSTOWN       40.733006       -73.974594
#
#   VehicleRef  VehicleLocation_Lat  VehicleLocation_Long  \
# 0  NYCT_5643            40.701616            -74.011917
# 1  NYCT_5986            40.733219            -73.974631
# 2  NYCT_4890            40.575429            -73.983304
# 3  NYCT_7117            40.691361            -73.987366
# 4  NYCT_5930            40.748865            -74.006943
#
#         NextStopPointName  DistanceFromStop ExpectedArrivalTime  \
# 0   SOUTH ST/WHITEHALL ST              25.0 2017-06-01 00:13:57
# 1            AV C/E 20 ST              23.0 2017-06-01 00:13:57
# 2        SURF AV /W 17 ST              89.0 2017-06-01 00:04:08
# 3  BOERUM PL/JORALEMON ST             196.0 2017-06-01 23:55:58
# 4           W 23 ST/11 AV              36.0 2017-06-01 00:04:07
#
#   ScheduledArrivalTime  Time_delay  Late_Bus  day  hour  minute   weekday  \
# 0  2017-06-01 00:00:01        13.0         1    1     0       0  Thursday
# 1  2017-06-01 00:01:00        12.0         1    1     0       1  Thursday
# 2  2017-06-01 00:01:09         2.0         0    1     0       1  Thursday
# 3  2017-06-01 00:01:09        54.0         1    1     0       1  Thursday
# 4  2017-06-01 00:01:22         2.0         0    1     0       1  Thursday
#
#    day_of_week  winsor_dist  increased_Late time_of_day  is_midweek   sin_min  \
# 0            3         25.0               0       night           1  0.000000
# 1            3         23.0               0       night           1  0.104528
# 2            3         89.0               0       night           1  0.104528
# 3            3        196.0               0       night           1  0.104528
# 4            3         36.0               0       night           1  0.104528
#
#     cos_min  sin_hour  cos_hour  sin_day_of_week  cos_day_of_week  rush_hour  \
# 0  1.000000       0.0       1.0         0.433884        -0.900969          0
# 1  0.994522       0.0       1.0         0.433884        -0.900969          0
# 2  0.994522       0.0       1.0         0.433884        -0.900969          0
# 3  0.994522       0.0       1.0         0.433884        -0.900969          0
# 4  0.994522       0.0       1.0         0.433884        -0.900969          0
#
#     boroughs  VL_to_Dest  VL_to_Origin  Dest_to_Origin  winVL_to_Dest  \
# 0  Manhattan    0.026391     13.132982       13.146918       0.026391
# 1  Manhattan    0.023889      3.305410        3.320475       0.023889
# 2   Brooklyn    1.634791      4.437133        5.908022       1.634791
# 3   Brooklyn    5.951028      0.017023        5.944870       5.951028
# 4  Manhattan    3.246128      0.099656        3.320475       3.246128
#
#    winVL_to_Origin  winDest_to_Origin VL_geohash O_geohash D_geohash
# 0         9.937921          13.146918      dr5re     dr72j     dr5re
# 1         3.305410           3.320475      dr5rs     dr5rg     dr5rs
# 2         4.437133           5.908022      dr5qu     dr5qv     dr5qu
# 3         0.017023           5.944870      dr5rk     dr5rk     dr5rm
# 4         0.099656           3.320475      dr5rg     dr5rg     dr5rs

# %%
mta.shape
# Out:
# (171982, 44)

# %% [markdown]
# # Preprcessing and Feature Selection

# %%
# import need libraries for models
from sklearn.naive_bayes import BernoulliNB 
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn import ensemble 
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report

# fucntion to plot AUC/ROC curve and score
def AUC_ROC_plot(y_test,y_prob,color):     
    auc = roc_auc_score(y_test,y_prob[:,1])
    print('AUC: %.3f' % auc)
    fpr, tpr,thresholds = roc_curve(y_test,y_prob[:,1])
    plt.plot(fpr,tpr,color)    
    plt.plot([0.0,1.0],'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristics')
    plt.xlim([0.0,1.0])     
    plt.ylim([0.0,1.0])
    return;
 
# function to print metrics for comparison 
def Metrics(model, X_train , y_train, X_test, y_test,):
    model.fit(X_train , y_train)
    y_pred = model.predict(X_test) 
    y_prob = model.predict_proba(X_test)    
    auc = roc_auc_score(y_test,y_prob[:,1])  
   
    print()
    print("Consfusion Matrix")
    print(pd.crosstab(y_test,y_pred))
    print()

    # Classification report
    print("Classification Report")    
    target_names = ['On-time','Late']
    print(classification_report(y_test,y_pred, target_names=target_names))    
    print("Train Score",model.score(X_train, y_train))
    print("Test Score",model.score(X_test, y_test))
    print("Recall Score",recall_score(y_test,y_pred))
    AUC_ROC_plot(y_test,y_prob,'r')
    plt.show() 
    return recall_score(y_test,y_pred);

# the next four fuctions convert features

# convert categorical to target mean in the training set
def cat_to_mean(X_train,X_test,cols=[]):
    X_trainC =  X_train.copy()
    X_testC =  X_test.copy()
    for col in X_trainC[cols]:
        Xmap = dict(X_train.groupby([col]).Late_Bus.mean())
        X_trainC[col] = X_trainC[col].map(Xmap)
        X_testC[col] =X_testC[col].map(Xmap)
        X_trainC.replace([np.inf, -np.inf], 0, inplace=True)
        X_testC.replace([np.inf, -np.inf], 0, inplace=True)
        X_trainC.fillna(0, inplace=True)
        X_testC.fillna(0, inplace=True)     

    return X_trainC, X_testC;

 

# convert categorical feature to the counts in the training set
def cat_to_count(X_train,X_test,cols=[]):
    X_trainC = X_train.copy()
    X_testC =  X_test.copy()
    for col in X_trainC[cols]:
        Xmap = dict(X_trainC[col].value_counts())
        X_trainC[col] = X_trainC[col].map(Xmap)
        X_testC[col] = X_testC[col].map(Xmap)
        X_trainC.replace([np.inf, -np.inf], 0, inplace=True)
        X_testC.replace([np.inf, -np.inf], 0, inplace=True)
        X_trainC.fillna(0, inplace=True)
        X_testC.fillna(0, inplace=True)
 
    return X_trainC, X_testC;

# %%
mta.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
#        'VehicleLocation_Long', 'NextStopPointName', 'DistanceFromStop',
#        'ExpectedArrivalTime', 'ScheduledArrivalTime', 'Time_delay', 'Late_Bus',
#        'day', 'hour', 'minute', 'weekday', 'day_of_week', 'winsor_dist',
#        'increased_Late', 'time_of_day', 'is_midweek', 'sin_min', 'cos_min',
#        'sin_hour', 'cos_hour', 'sin_day_of_week', 'cos_day_of_week',
#        'rush_hour', 'boroughs', 'VL_to_Dest', 'VL_to_Origin', 'Dest_to_Origin',
#        'winVL_to_Dest', 'winVL_to_Origin', 'winDest_to_Origin', 'VL_geohash',
#        'O_geohash', 'D_geohash'],
#       dtype='object')

# %%
mta.select_dtypes('category').describe()
# Out:
#         DirectionRef PublishedLineName     OriginName  \
# count         171982            171982         171982
# unique             2               236            582
# top                1                B6  E 126 ST/2 AV
# freq           86292              3299           2923
#
#                  DestinationName VehicleRef       NextStopPointName   weekday  \
# count                     171982     171982                  171982    171982
# unique                       610       4460                    8877         7
# top     WASHINGTON HTS GW BRIDGE  NYCT_4624  BAY ST/NICK LAPORTE PL  Thursday
# freq                        2395         94                     340     32544
#
#        time_of_day  boroughs VL_geohash O_geohash D_geohash
# count       171982    171982     171982    171982    171982
# unique           4         6         70        58        58
# top        morning  Brooklyn      dr5ru     dr72m     dr72m
# freq         56915     52052      13728     12057     11498

# %% [markdown]
# Since the geohashes and the zipcodes contain essentially the same information I am going to drop zipcodes because they have a higher cardinality. I will not be using vehicle reference either since the days and routes the unique busses run are not consistent. All of the other categroical features will be one-hot-encoded except for "NextStopPointName." It has over 5000 levels. I will encode it with the frequency that it occurs in the training set. This way we can still make use of it.

# %% [markdown]
# Some of the other features will be dropped initally because eithere the are redundant or they were used to create the target variable. These features are: 'RecordedAtTime','DistanceFromStop','ExpectedArrivalTime', 'ScheduledArrivalTime', 'Time_delay', 'day', 'hour', 'minute',  'OriginLat', 'OriginLong','VehicleLocation_Lat','VehicleLocation_Long','Orig_zip','Dest_zip', 'VL_Zip','OriginName','DestinationName'.
#
# There are some features that may be redundant but I'm not sure which will add more predictive power over the others so they will be left in and eliminated during feature selection.

# %%
mta.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
#        'VehicleLocation_Long', 'NextStopPointName', 'DistanceFromStop',
#        'ExpectedArrivalTime', 'ScheduledArrivalTime', 'Time_delay', 'Late_Bus',
#        'day', 'hour', 'minute', 'weekday', 'day_of_week', 'winsor_dist',
#        'increased_Late', 'time_of_day', 'is_midweek', 'sin_min', 'cos_min',
#        'sin_hour', 'cos_hour', 'sin_day_of_week', 'cos_day_of_week',
#        'rush_hour', 'boroughs', 'VL_to_Dest', 'VL_to_Origin', 'Dest_to_Origin',
#        'winVL_to_Dest', 'winVL_to_Origin', 'winDest_to_Origin', 'VL_geohash',
#        'O_geohash', 'D_geohash'],
#       dtype='object')

# %%
modeling_df = mta[['DirectionRef','Late_Bus', 'PublishedLineName',
                   'weekday', 'day_of_week', 'winsor_dist', 'increased_Late',
                   'time_of_day', 'is_midweek', 'sin_hour', 'cos_hour', 'sin_day_of_week', 'cos_day_of_week',
                    'rush_hour',  'winVL_to_Dest', 'winVL_to_Origin','NextStopPointName',
                   'winDest_to_Origin','VL_geohash', 'O_geohash', 'D_geohash']] 
 
dummies = ['time_of_day', 'VL_geohash', 'O_geohash', 
           'D_geohash','PublishedLineName','weekday']


counts = ['NextStopPointName']

# one-hot-encoding using pandas get_dummies 
modeling_df = pd.concat([modeling_df.drop(dummies,1), pd.get_dummies(modeling_df[dummies],drop_first=True)], axis=1)
 
X  = modeling_df 
Y = modeling_df.Late_Bus

# split the data 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=20)

# %%
X_train.shape
# Out:
# (137585, 442)

# %%
# count transformation 
X_train, X_test  = cat_to_count(X_train,X_test,counts)
X_train.sample(frac=.001)[:10]
# Out:
#        DirectionRef  Late_Bus  day_of_week  winsor_dist  increased_Late  \
# 166888            1         1            4         24.0               1
# 64999             1         0            0        142.0               1
# 156721            0         0            2        249.0               1
# 102553            0         0            0         83.0               0
# 101453            0         0            6        117.0               1
# 17542             1         0            5         49.0               0
# 98287             0         0            5         41.0               1
# 154701            0         0            2        169.0               1
# 1780              0         1            3         54.0               1
# 36112             0         0            2         18.0               1
#
#         is_midweek      sin_hour      cos_hour  sin_day_of_week  \
# 166888           0  8.660254e-01 -5.000000e-01        -0.433884
# 64999            0  1.224647e-16 -1.000000e+00         0.000000
# 156721           0 -5.000000e-01 -8.660254e-01         0.974928
# 102553           0  7.071068e-01  7.071068e-01         0.000000
# 101453           0 -9.659258e-01 -2.588190e-01        -0.781831
# 17542            1 -5.000000e-01  8.660254e-01        -0.974928
# 98287            0 -1.000000e+00 -1.836970e-16        -0.974928
# 154701           0  8.660254e-01 -5.000000e-01         0.974928
# 1780             1  7.071068e-01 -7.071068e-01         0.433884
# 36112            1  7.071068e-01 -7.071068e-01         0.974928
#
#         cos_day_of_week  rush_hour  winVL_to_Dest  winVL_to_Origin  \
# 166888        -0.900969          1       8.625781         3.170827
# 64999          1.000000          0       5.811807         8.279307
# 156721        -0.222521          0       6.412661         0.322108
# 102553         1.000000          0       1.912947         4.255323
# 101453         0.623490          1       7.439935         4.000259
# 17542         -0.222521          0       7.465205         1.793916
# 98287         -0.222521          1       0.042505         3.247827
# 154701        -0.222521          1       9.531770         1.744823
# 1780          -0.900969          1       4.201243         2.525293
# 36112         -0.222521          1       9.531770         0.515957
#
#         NextStopPointName  winDest_to_Origin  time_of_day_evening  \
# 166888                 69          11.796418                    0
# 64999                  55          13.830714                    0
# 156721                 26           6.726535                    0
# 102553                 40           6.057227                    0
# 101453                 14          11.348658                    1
# 17542                  16           8.924495                    0
# 98287                  39           3.281652                    1
# 154701                  4          14.327418                    0
# 1780                   28           6.726535                    0
# 36112                  26          12.363562                    0
#
#         time_of_day_morning  time_of_day_night  VL_geohash_dr5nr  \
# 166888                    1                  0                 0
# 64999                     0                  0                 0
# 156721                    0                  0                 0
# 102553                    0                  1                 0
# 101453                    0                  0                 0
# 17542                     0                  1                 0
# 98287                     0                  0                 0
# 154701                    1                  0                 0
# 1780                      1                  0                 0
# 36112                     1                  0                 0
#
#         VL_geohash_dr5nw  VL_geohash_dr5nx  VL_geohash_dr5nz  \
# 166888                 0                 0                 0
# 64999                  0                 0                 0
# 156721                 0                 0                 0
# 102553                 0                 0                 0
# 101453                 0                 0                 0
# 17542                  0                 0                 0
# 98287                  0                 0                 0
# 154701                 0                 0                 1
# 1780                   0                 0                 0
# 36112                  0                 0                 0
#
#         VL_geohash_dr5pp  VL_geohash_dr5pr  VL_geohash_dr5q8  \
# 166888                 0                 0                 0
# 64999                  0                 0                 0
# 156721                 0                 0                 0
# 102553                 0                 0                 0
# 101453                 0                 0                 0
# 17542                  0                 0                 0
# 98287                  0                 0                 0
# 154701                 0                 0                 0
# 1780                   0                 0                 0
# 36112                  0                 0                 0
#
#               ...          PublishedLineName_X21  PublishedLineName_X22  \
# 166888        ...                              0                      0
# 64999         ...                              0                      0
# 156721        ...                              0                      0
# 102553        ...                              0                      0
# 101453        ...                              0                      0
# 17542         ...                              0                      0
# 98287         ...                              0                      0
# 154701        ...                              0                      0
# 1780          ...                              0                      0
# 36112         ...                              0                      0
#
#         PublishedLineName_X22A  PublishedLineName_X27  PublishedLineName_X28  \
# 166888                       0                      0                      0
# 64999                        0                      0                      0
# 156721                       0                      0                      0
# 102553                       0                      0                      0
# 101453                       0                      0                      0
# 17542                        0                      0                      0
# 98287                        0                      0                      0
# 154701                       0                      0                      0
# 1780                         0                      0                      0
# 36112                        0                      0                      0
#
#         PublishedLineName_X3  PublishedLineName_X30  PublishedLineName_X31  \
# 166888                     0                      0                      0
# 64999                      0                      0                      0
# 156721                     0                      0                      0
# 102553                     0                      0                      0
# 101453                     0                      0                      0
# 17542                      0                      0                      0
# 98287                      0                      0                      0
# 154701                     0                      0                      0
# 1780                       0                      0                      0
# 36112                      0                      0                      0
#
#         PublishedLineName_X37  PublishedLineName_X38  PublishedLineName_X4  \
# 166888                      0                      0                     0
# 64999                       0                      0                     0
# 156721                      0                      0                     0
# 102553                      0                      0                     0
# 101453                      0                      0                     0
# 17542                       0                      0                     0
# 98287                       0                      0                     0
# 154701                      0                      0                     0
# 1780                        0                      0                     0
# 36112                       0                      0                     0
#
#         PublishedLineName_X42  PublishedLineName_X5  PublishedLineName_X63  \
# 166888                      0                     0                      0
# 64999                       0                     0                      0
# 156721                      0                     0                      0
# 102553                      0                     0                      0
# 101453                      0                     0                      0
# 17542                       0                     0                      0
# 98287                       0                     0                      0
# 154701                      0                     0                      0
# 1780                        0                     0                      0
# 36112                       0                     0                      0
#
#         PublishedLineName_X64  PublishedLineName_X68  PublishedLineName_X7  \
# 166888                      0                      0                     0
# 64999                       0                      0                     0
# 156721                      0                      0                     0
# 102553                      0                      0                     0
# 101453                      0                      0                     0
# 17542                       0                      0                     0
# 98287                       0                      0                     0
# 154701                      0                      0                     0
# 1780                        0                      0                     0
# 36112                       0                      0                     0
#
#         PublishedLineName_X8  PublishedLineName_X9  weekday_Monday  \
# 166888                     0                     0               0
# 64999                      0                     0               1
# 156721                     0                     0               0
# 102553                     0                     0               1
# 101453                     0                     0               0
# 17542                      0                     0               0
# 98287                      0                     0               0
# 154701                     0                     0               0
# 1780                       0                     0               0
# 36112                      0                     0               0
#
#         weekday_Saturday  weekday_Sunday  weekday_Thursday  weekday_Tuesday  \
# 166888                 0               0                 0                0
# 64999                  0               0                 0                0
# 156721                 0               0                 0                0
# 102553                 0               0                 0                0
# 101453                 0               1                 0                0
# 17542                  1               0                 0                0
# 98287                  1               0                 0                0
# 154701                 0               0                 0                0
# 1780                   0               0                 1                0
# 36112                  0               0                 0                0
#
#         weekday_Wednesday
# 166888                  0
# 64999                   0
# 156721                  1
# 102553                  0
# 101453                  0
# 17542                   0
# 98287                   0
# 154701                  1
# 1780                    0
# 36112                   1
#
# [10 rows x 442 columns]

# %% [markdown]
# Next we'll take at a look at the correlations of the variables to the target. And start cutting down some of the dimentionality.

# %%
# find correlations to target
corr_matrix = X_train.corr().abs()
corr_to_target = corr_matrix['Late_Bus'].sort_values(ascending=False)

# %%
# top 30 features with the highest correlations to target
corr_to_target[:30]
# Out:
# Late_Bus                     1.000000
# winVL_to_Origin              0.214330
# sin_hour                     0.166568
# winVL_to_Dest                0.137789
# time_of_day_morning          0.125750
# time_of_day_evening          0.097358
# increased_Late               0.089859
# winDest_to_Origin            0.088780
# NextStopPointName            0.069851
# O_geohash_dr5ru              0.056821
# day_of_week                  0.054120
# weekday_Monday               0.052101
# VL_geohash_dr5x9             0.049073
# PublishedLineName_B41        0.048084
# PublishedLineName_B35        0.042909
# PublishedLineName_M60-SBS    0.042176
# VL_geohash_dr5xb             0.040572
# PublishedLineName_Q32        0.039691
# VL_geohash_dr72j             0.038338
# cos_day_of_week              0.038337
# PublishedLineName_M7         0.037052
# PublishedLineName_B15        0.034504
# O_geohash_dr5rs              0.034257
# D_geohash_dr72w              0.033640
# O_geohash_dr5re              0.033161
# O_geohash_dr5rt              0.032552
# PublishedLineName_M1         0.031747
# VL_geohash_dr72w             0.031379
# D_geohash_dr5r4              0.031075
# O_geohash_dr72w              0.030942
# Name: Late_Bus, dtype: float64

# %%
plt.figure(figsize=(10,3))
plt.subplot(121)
plt.plot(corr_to_target.values[1:])
plt.subplot(122)
plt.plot(corr_to_target.values[10:])
plt.show()

# %% [markdown]
# The correlation to target drops off pretty steep at around 25 features. But the first 10 features are numerical features and the rest are the dummies. On the left if we look at just the dummies variables then we can see that the elbow doesnt make a turn until between 150 and 200 features. This is were I will minimize the feature set to.
# Well start with order the features by their correlation to the target and the use sklearn's recursive feature selction tool and use logistic regression as the model for the feature elimination.

# %%
# drop correlations that were nan and order feature columns from decending correlation scores
corr_to_target = dict(corr_to_target.dropna())  
X_train = X_train.loc[:,corr_to_target.keys()]
X_test = X_test.loc[:,corr_to_target.keys()]

# %%
# drop the target from independent features
X_train.drop('Late_Bus',1,inplace=True)
X_test.drop('Late_Bus',1,inplace=True)

# %%
# recusive feature selection using logistic regression 
lr = LogisticRegression(max_iter=300, solver= 'liblinear', warm_start= True)

from sklearn.feature_selection import RFE
# feature extraction
start_time = time.time()

rfe = RFE(lr, n_features_to_select=200)
# fit on train set
fit = rfe.fit(X_train, y_train)
print("--- %s seconds ---" % (time.time() - start_time))

# transform train set
recursive_features = fit.transform(X_train)
# Out:
# --- 893.5786497592926 seconds ---

# %%
X_train = X_train.iloc[:,pd.DataFrame(recursive_features).columns] 
X_test = X_test.iloc[:,pd.DataFrame(recursive_features).columns]

# %%
X_train.shape
# Out:
# (137585, 200)

# %% [markdown]
# Next I'll take a look at the heatmap of the correlation matrix to see if any features are highly correlated. If so Well drop one of the correlated features and keep the one that is most highly correlated with the target.

# %%
corr_matrix = X_train.corr().abs().where(np.triu(np.ones(X_train.corr().abs().shape), k=1).astype(np.bool))
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix,annot=False)
plt.show()

# %%
to_drop = [column for column in corr_matrix.columns if any(corr_matrix[column] > 0.50)]
print('Columns to drop: ' , (len(to_drop)))
to_drop
# Out:
# Columns to drop:  14
# ['time_of_day_morning',
#  'time_of_day_evening',
#  'weekday_Monday',
#  'cos_day_of_week',
#  'O_geohash_dr5ry',
#  'D_geohash_dr5ry',
#  'time_of_day_night',
#  'sin_day_of_week',
#  'weekday_Sunday',
#  'PublishedLineName_Bx16',
#  'O_geohash_dr5r0',
#  'O_geohash_dr781',
#  'O_geohash_dr5xb',
#  'weekday_Wednesday']

# %%
# Drop one of each pair of correlated features
X_train.drop(to_drop,1,inplace=True)
X_test.drop(to_drop,1,inplace=True)

# %%
corr_matrix = X_train.corr().abs().where(np.triu(np.ones(X_train.corr().abs().shape), k=1).astype(np.bool))
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix,annot=False)
plt.show()

# %%
print(X_train.shape) 
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (137585, 186)
# (137585,)
# (34397, 186)
# (34397,)

# %% [markdown]
# Since we are dealing with and imbalanced dataset I'll use a random oversampler function to create more random instances of the minority class to balance the training set only.

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=20)
X_trainB, y_trainB = ros.fit_sample(X_train, y_train)
# Out:
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
plt.hist(y_train)
plt.title('Before Over-sampling')
plt.show()
plt.hist(y_trainB)
plt.title('After Over-sampling')
plt.show()

# %%
# scale the data
from sklearn.preprocessing import StandardScaler
sclr = StandardScaler()
sclr.fit(X_trainB)
X_trainS = sclr.transform(X_trainB)
X_testS = sclr.transform(X_test)

# %% [markdown]
# # Modeling

# %% [markdown]
# The metric I want to look at is the recall score since we are looking specifically for late buses. It's better to have misclassified an on-time bus as late than a late-bus as on-time

# %% [markdown]
# ### Random Forest and Gradient Boost algorithms.

# %%
# run random forrest and gradient boost algorithms
base_scores = {}

models = []  
models.append(('Random_Forest' , ensemble.RandomForestClassifier(n_jobs=-1,n_estimators=10,class_weight='balanced'
                                                                 ,random_state=20)))  

models.append(('Gradient_Boost' , ensemble.GradientBoostingClassifier()))
 
 
 
for name ,model in models:
    
    print(str(name))
    print()
    startTime = datetime.now()  
 
    recall_s = Metrics(model, X_trainS , y_trainB, X_testS, y_test) 

    base_scores.update({name:recall_s})
# Out:
# Random_Forest
#
#
# Consfusion Matrix
# col_0         0     1
# Late_Bus
# 0         21843  3619
# 1          5580  3355
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.80      0.86      0.83     25462
#         Late       0.48      0.38      0.42      8935
#
#     accuracy                           0.73     34397
#    macro avg       0.64      0.62      0.62     34397
# weighted avg       0.71      0.73      0.72     34397
#
# Train Score 0.9950834385355847
# Test Score 0.7325638863854406
# Recall Score 0.37548964745383323
# AUC: 0.703
# Gradient_Boost
#
#
# Consfusion Matrix
# col_0         0     1
# Late_Bus
# 0         16521  8941
# 1          2726  6209
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.86      0.65      0.74     25462
#         Late       0.41      0.69      0.52      8935
#
#     accuracy                           0.66     34397
#    macro avg       0.63      0.67      0.63     34397
# weighted avg       0.74      0.66      0.68     34397
#
# Train Score 0.6747179264636263
# Test Score 0.6608134430328226
# Recall Score 0.6949076664801344
# AUC: 0.735

# %% [markdown]
# Initally there is overfitting on both models. The AUC scores aren't terrible but the Random Forest is not picking up very many late busses. Possibly tuning the hyperparameter can fix some of these issues.

# %% [markdown]
# ### Logistic regression alogrithim.

# %%
lr = LogisticRegression( solver='liblinear',class_weight='balanced')
AUCscore = {}
Recallscore = {}
 
print('Logistic Regression')
print()
startTime = datetime.now()  

recall_s = Metrics(lr, X_trainS , y_trainB, X_testS, y_test) 

base_scores.update({'Logistic Regression':recall_s})
# Out:
# Logistic Regression
#
#
# Consfusion Matrix
# col_0         0     1
# Late_Bus
# 0         16795  8667
# 1          2910  6025
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.85      0.66      0.74     25462
#         Late       0.41      0.67      0.51      8935
#
#     accuracy                           0.66     34397
#    macro avg       0.63      0.67      0.63     34397
# weighted avg       0.74      0.66      0.68     34397
#
# Train Score 0.6657823102414392
# Test Score 0.6634299502863622
# Recall Score 0.6743144935646335
# AUC: 0.727

# %% [markdown]
# The first run looks pretty good. The score is still low but it is consistent in the training set, test set and cross validataion. I'll print the first 20 coefficients

# %% [markdown]
# ### Tuning hyperparameters using GridsearchCV

# %%
# define a function to extract best params from GridsearchCV
from sklearn.model_selection import GridSearchCV
def gridsearch(model, X_trainS , y_trainB, param_grid):    
    grid = GridSearchCV(model, param_grid, cv=3, scoring='roc_auc', return_train_score=True,verbose=1,n_jobs=-2)
    grid.fit(X_trainS , y_trainB)
    print(grid.best_params_)
    print(grid.best_score_)
    return grid.best_params_;

# %% [markdown]
# #### Random forest

# %%
rfc = ensemble.RandomForestClassifier(n_jobs=-1,n_estimators=10,class_weight='balanced',random_state=20)
param_grid = { 'n_estimators': range(2,30),'max_depth' : range(1,10)}
# gridsearch
rfc_best_params = gridsearch(rfc, X_trainS , y_trainB, param_grid)
# Out:
# Fitting 3 folds for each of 252 candidates, totalling 756 fits
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-2)]: Done 436 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-2)]: Done 756 out of 756 | elapsed: 17.1min finished
# {'max_depth': 9, 'n_estimators': 25}
# 0.7334946271670039

# %%
# holds final scores of each alrorithm
final_scores = {}

# run classifer with new params
print('Random Forest')
rfc = ensemble.RandomForestClassifier(**rfc_best_params,random_state=20)
recall_s = Metrics(rfc, X_trainS , y_trainB, X_testS, y_test)
rfc_scores = cross_val_score(rfc, X_trainS, y_trainB, cv=10)
final_scores.update({'Random Forest':recall_s})
print('Cross validataion scores:',rfc_scores)
# Out:
# Random Forest
#
# Consfusion Matrix
# col_0         0     1
# Late_Bus
# 0         16792  8670
# 1          3001  5934
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.85      0.66      0.74     25462
#         Late       0.41      0.66      0.50      8935
#
#     accuracy                           0.66     34397
#    macro avg       0.63      0.66      0.62     34397
# weighted avg       0.73      0.66      0.68     34397
#
# Train Score 0.6725481300299826
# Test Score 0.6606971538215543
# Recall Score 0.664129826524902
# AUC: 0.723
# Cross validataion scores: [0.6627712  0.66987179 0.66490778 0.66993786 0.67255153 0.67511589
#  0.67038169 0.66954335 0.66584476 0.67422823]

# %% [markdown]
# Not as much  over-fitting and the algorithim is picking up more of the late busses!! Let's take a look at the feature importances.

# %%
#plot feature importances
feature_importance = rfc.feature_importances_

# Make importances relative to max importance.
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.figure(figsize=(10,20))
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X_train.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# It looks like I could have left out more features in the selection process, however since there hasn't been any modeling of this data set online so there is no benchmark to compare the scores so I'll take no more action and leave it as it is. I'll move on to the other tune the other models.

# %% [markdown]
# #### Gradient Boost

# %%
clf = ensemble.GradientBoostingClassifier()
param_grid = {'n_estimators':(3,5),'random_state':[20],'learning_rate':np.arange(.05,.1,.01),'max_depth':(2,5,10)}
clf_best_params = gridsearch(clf, X_trainS , y_trainB, param_grid)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-2)]: Done  90 out of  90 | elapsed: 19.6min finished
# {'learning_rate': 0.09000000000000001, 'max_depth': 10, 'n_estimators': 5, 'random_state': 20}
# 0.7503197700089512

# %%
# run classifer with new params
print('Gradient Boost')
clf = ensemble.GradientBoostingClassifier(**clf_best_params,)
recall_s = Metrics(clf, X_trainS , y_trainB, X_testS, y_test)
clf_scores = cross_val_score(clf, X_trainS, y_trainB, cv=10)

final_scores.update({'Gradient Boost':recall_s})
print('Cross validataion score:',clf_scores)
# Out:
# Gradient Boost
#
# Consfusion Matrix
# col_0         0     1
# Late_Bus
# 0         17227  8235
# 1          3113  5822
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.85      0.68      0.75     25462
#         Late       0.41      0.65      0.51      8935
#
#     accuracy                           0.67     34397
#    macro avg       0.63      0.66      0.63     34397
# weighted avg       0.73      0.67      0.69     34397
#
# Train Score 0.7031126716111725
# Test Score 0.6700875076314795
# Recall Score 0.6515948517067711
# AUC: 0.725
# Cross validataion score: [0.67608481 0.68653846 0.68132952 0.68655686 0.69336226 0.68966367
#  0.68843081 0.68734589 0.68714863 0.68991025]

# %%
#plot feature importances
feature_importance = clf.feature_importances_

# Make importances relative to max importance.
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.figure(figsize=(10,20))
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X_train.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# #### Logistic regression

# %%
param_grid = param_grid = {'solver':['sag','lbfgs', 'liblinear'],'max_iter':[1000],  'warm_start' :[True]}
lr_best_params = gridsearch(lr, X_trainS , y_trainB, param_grid)
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   6 out of   9 | elapsed:   18.4s remaining:    9.2s
# [Parallel(n_jobs=-2)]: Done   9 out of   9 | elapsed:   22.4s finished
# {'max_iter': 1000, 'solver': 'liblinear', 'warm_start': True}
# 0.7266801780628082

# %%
# run lr with best params
print('Logistic Regression')
lr = LogisticRegression(**lr_best_params)
lr.fit(X_trainS, y_trainB) 
recall_s = Metrics(lr, X_trainS , y_trainB, X_testS, y_test)
final_scores.update({'Logistic Regression':recall_s})
lr_scores = cross_val_score(lr, X_trainS, y_trainB, cv=10)
print('Cross validataion score:',lr_scores)
# Out:
# Logistic Regression
#
# Consfusion Matrix
# col_0         0     1
# Late_Bus
# 0         16795  8667
# 1          2910  6025
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.85      0.66      0.74     25462
#         Late       0.41      0.67      0.51      8935
#
#     accuracy                           0.66     34397
#    macro avg       0.63      0.67      0.63     34397
# weighted avg       0.74      0.66      0.68     34397
#
# Train Score 0.6657823102414392
# Test Score 0.6634299502863622
# Recall Score 0.6743144935646335
# AUC: 0.727
# Cross validataion score: [0.66434911 0.6688856  0.66352698 0.66535161 0.66120919 0.66466121
#  0.66717625 0.66431601 0.66337903 0.66924746]

# %%
LR_coeff_df = { 'Features': X_train.columns,'Coefficients': lr.coef_[0]}
LR_coeff_df = pd.DataFrame(data=LR_coeff_df)
print('First 15 Coefficients')
LR_coeff_df.sort_values(by='Coefficients',ascending=False)[:15]
# Out:
# First 15 Coefficients
#                      Features  Coefficients
# 0             winVL_to_Origin      0.299611
# 7                 day_of_week      0.135081
# 5           NextStopPointName      0.130118
# 3              increased_Late      0.128586
# 10      PublishedLineName_B35      0.103433
# 4           winDest_to_Origin      0.102913
# 11  PublishedLineName_M60-SBS      0.094823
# 35      PublishedLineName_B12      0.084614
# 6             O_geohash_dr5ru      0.083012
# 66      PublishedLineName_B82      0.079128
# 13      PublishedLineName_Q32      0.079119
# 9       PublishedLineName_B41      0.074221
# 53     PublishedLineName_Bx15      0.066140
# 51            O_geohash_dr72m      0.063446
# 46      PublishedLineName_B25      0.059882

# %% [markdown]
# Next I want to see how LASSO scores hold up compared to the score I got with ordinary feature selection.

# %% [markdown]
# ### LASSO

# %%
modeling_df = mta[['DirectionRef','Late_Bus', 'PublishedLineName',
                   'weekday', 'day_of_week', 'winsor_dist', 'increased_Late',
                   'time_of_day', 'is_midweek', 'sin_hour', 'cos_hour', 'sin_day_of_week', 'cos_day_of_week',
                   'rush_hour',  'winVL_to_Dest', 'winVL_to_Origin','NextStopPointName',
                   'winDest_to_Origin','VL_geohash', 'O_geohash', 'D_geohash']]
         
dummies = ['PublishedLineName', 'time_of_day', 'VL_geohash', 'O_geohash', 'D_geohash','weekday']
 
counts = ['NextStopPointName']

modeling_df = pd.concat([modeling_df.drop(dummies,1), pd.get_dummies(modeling_df[dummies],drop_first=True)], axis=1)
 
X = modeling_df
Y = modeling_df.Late_Bus


 

# split the data 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=20)  
# count encoding 
X_train, X_test = cat_to_count(X_train,X_test,counts) 

X_train.drop('Late_Bus',1,inplace=True)
X_test.drop('Late_Bus',1,inplace=True)

# balance class
import imblearn
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=20)
X_trainB, y_trainB = ros.fit_sample(X_train, y_train)
 


# scale
from sklearn.preprocessing import StandardScaler
sclr = StandardScaler()
sclr.fit(X_trainB)
X_trainS = sclr.transform(X_trainB)
X_testS = sclr.transform(X_test)

# %%
Train_Score = []
Test_Score = []
Recall_Score = []
alphas = []
for alpha in np.arange(.0001,.02,.0011):
    lr = LogisticRegression(penalty='l1',solver='liblinear',max_iter=50,C=alpha, warm_start=True)
    lr.fit(X_trainS, y_trainB)
    y_pred = lr.predict(X_testS) 
    print("Train Score",lr.score(X_trainS, y_trainB))
    print("Test Score",lr.score(X_testS, y_test))
    print("Recall Score",recall_score(y_test,y_pred))
    print(alpha)
    Train_Score.append(lr.score(X_trainS, y_trainB))
    Test_Score.append(lr.score(X_testS, y_test))
    Recall_Score.append(recall_score(y_test,y_pred))
    alphas.append(alpha)
    print()
    #Metrics(lr, X_trainS , y_trainB, X_testS, y_test)
# Out:
# Train Score 0.6242701593814107
# Test Score 0.6318574294269849
# Recall Score 0.6138780078343593
# 0.0001
#
# Train Score 0.6630848587659776
# Test Score 0.6613367444835305
# Recall Score 0.6716284275321769
# 0.0012000000000000001
#
# Train Score 0.6671187075903424
# Test Score 0.6621798412652267
# Recall Score 0.6773363178511472
# 0.0023
#
# Train Score 0.669263847246331
# Test Score 0.6637206733145332
# Recall Score 0.6804700615556799
# 0.0034
#
# Train Score 0.669806296354742
# Test Score 0.6645346977934122
# Recall Score 0.6797985450475658
# 0.0045000000000000005
#
# Train Score 0.6702649124191258
# Test Score 0.6651161438497544
# Recall Score 0.6796866256295467
# 0.005600000000000001
#
# Train Score 0.6705607937509863
# Test Score 0.665290577666657
# Recall Score 0.6800223838836038
# 0.0067
#
# Train Score 0.6707235284835096
# Test Score 0.6653777945751083
# Recall Score 0.6803581421376609
# 0.0078000000000000005
#
# Train Score 0.6708862632160328
# Test Score 0.6653196499694741
# Recall Score 0.6803581421376609
# 0.0089
#
# Train Score 0.6711377623481143
# Test Score 0.6652324330610228
# Recall Score 0.6804700615556799
# 0.01
#
# Train Score 0.6712955657251065
# Test Score 0.6653196499694741
# Recall Score 0.6804700615556799
# 0.0111
#
# Train Score 0.6714533691020987
# Test Score 0.6651742884553885
# Recall Score 0.6803581421376609
# 0.0122
#
# Train Score 0.671601309768029
# Test Score 0.6652324330610228
# Recall Score 0.6801343033016228
# 0.0133
#
# Train Score 0.6716555546788702
# Test Score 0.6650579992441201
# Recall Score 0.6802462227196419
# 0.0144
#
# Train Score 0.6716950055231182
# Test Score 0.6649707823356688
# Recall Score 0.6804700615556799
# 0.0155
#
# Train Score 0.6717541817894903
# Test Score 0.6649998546384859
# Recall Score 0.6802462227196419
# 0.0166
#
# Train Score 0.6718528089001105
# Test Score 0.6649707823356688
# Recall Score 0.6801343033016228
# 0.0177
#
# Train Score 0.6718774656777655
# Test Score 0.6649417100328517
# Recall Score 0.6799104644655848
# 0.0188
#
# Train Score 0.6718330834779864
# Test Score 0.6650579992441201
# Recall Score 0.6797985450475658
# 0.0199

# %%
plt.plot(alphas,Train_Score) 
plt.plot(alphas,Test_Score)
plt.plot(alphas,Recall_Score)

# %%
print('LASSO Logistic Regression')
LASSO_lr = LogisticRegression(penalty='l1',solver='liblinear',max_iter=20,C=.004, warm_start=True)
recall_s = Metrics(LASSO_lr, X_trainS , y_trainB, X_testS, y_test)

final_scores.update({'LASSO lr':recall_s})
 
LASSO_lr_scores = cross_val_score(LASSO_lr, X_trainS, y_trainB, cv=10)
print('Cross validataion score:',LASSO_lr_scores)
# Out:
# LASSO Logistic Regression
#
# Consfusion Matrix
# col_0         0     1
# Late_Bus
# 0         16766  8696
# 1          2862  6073
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.85      0.66      0.74     25462
#         Late       0.41      0.68      0.51      8935
#
#     accuracy                           0.66     34397
#    macro avg       0.63      0.67      0.63     34397
# weighted avg       0.74      0.66      0.68     34397
#
# Train Score 0.669786570932618
# Test Score 0.6639823240398872
# Recall Score 0.6796866256295467
# AUC: 0.731
# Cross validataion score: [0.66489152 0.67164694 0.66402012 0.66762008 0.66500641 0.66648585
#  0.66964198 0.66757077 0.66757077 0.67486932]

# %%
d = { 'Features': X_train.columns,'Coefficients': lr.coef_[0]}
df = pd.DataFrame(data=d)
df.sort_values(by='Coefficients',ascending=False)
coeffs = df[df.Coefficients!=0] 
coeffs[:15]
# Out:
#                  Features  Coefficients
# 0            DirectionRef      0.043055
# 1             day_of_week      0.073791
# 2             winsor_dist     -0.071400
# 3          increased_Late      0.155755
# 4              is_midweek     -0.007233
# 5                sin_hour     -0.467969
# 6                cos_hour      0.017687
# 8         cos_day_of_week     -0.032851
# 9               rush_hour     -0.060317
# 10          winVL_to_Dest     -0.303322
# 11        winVL_to_Origin      0.296034
# 12      NextStopPointName      0.136869
# 13      winDest_to_Origin      0.230158
# 14  PublishedLineName_B11      0.018350
# 15  PublishedLineName_B12      0.081046

# %% [markdown]
# ### PCA

# %%
modeling_df = mta[['DirectionRef','Late_Bus', 'PublishedLineName',
                   'weekday', 'day_of_week', 'winsor_dist', 'increased_Late',
                   'time_of_day', 'is_midweek', 'sin_hour', 'cos_hour', 'sin_day_of_week', 'cos_day_of_week',
                   'rush_hour',  'winVL_to_Dest', 'winVL_to_Origin','NextStopPointName',
                   'winDest_to_Origin','VL_geohash', 'O_geohash', 'D_geohash']]
         
dummies = ['PublishedLineName', 'time_of_day', 'VL_geohash', 'O_geohash', 'D_geohash','weekday']
 
counts = ['NextStopPointName']

modeling_df = pd.concat([modeling_df.drop(dummies,1), pd.get_dummies(modeling_df[dummies],drop_first=True)], axis=1)
 
X = modeling_df
Y = modeling_df.Late_Bus


 

# split the data 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=20)  

# count encoding 
X_train, X_test = cat_to_count(X_train,X_test,counts) 

X_train.drop('Late_Bus',1,inplace=True)
X_test.drop('Late_Bus',1,inplace=True)

# balance class
ros = RandomOverSampler(random_state=20)
X_trainB, y_trainB = ros.fit_sample(X_train, y_train)
 


# scale
sclr = StandardScaler()
sclr.fit(X_trainB)
X_trainS = sclr.transform(X_trainB)
X_testS = sclr.transform(X_test)

# %%
X_train.shape
# Out:
# (137585, 441)

# %% [markdown]
# Here I'll plot the explained variance to get the minimum number of PCA components to use as the final feature set.

# %%
# plot cumulative sum of explained variance
pca = PCA(random_state=20)
pca.fit(X_trainS)  
plt.ylabel('% Variance Explained')
plt.xlabel('Components')
plt.title('PCA Summed Variance') 
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.show()

# %% [markdown]
# It looks like the percentage of explained variance levels off at around 370 components.

# %%
#percentage of varaince explained
np.cumsum(pca.explained_variance_ratio_).max()
# Out:
# 0.9999999999999998

# %%
# fit and transform with 370 components
pca = PCA(n_components=370,random_state=20)
pca.fit(X_trainS)  
X_train = pca.transform(X_trainS)
X_test = pca.transform(X_testS)

# %%
# run lr with best params
print('Logistic Regression')
PCA_lr = LogisticRegression()
PCA_lr.fit(X_trainS, y_trainB) 
recall_s = Metrics(PCA_lr, X_trainS , y_trainB, X_testS, y_test)

final_scores.update({'PCA_lr':recall_s})

PCA_lr_scores = cross_val_score(PCA_lr, X_trainS, y_trainB, cv=10)
print('Cross validataion score:',PCA_lr_scores)
# Out:
# Logistic Regression
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Consfusion Matrix
# col_0         0     1
# Late_Bus
# 0         16805  8657
# 1          2868  6067
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.85      0.66      0.74     25462
#         Late       0.41      0.68      0.51      8935
#
#     accuracy                           0.66     34397
#    macro avg       0.63      0.67      0.63     34397
# weighted avg       0.74      0.66      0.68     34397
#
# Train Score 0.6719563673662616
# Test Score 0.6649417100328517
# Recall Score 0.6790151091214326
# AUC: 0.732
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Cross validataion score: [0.66646943 0.6699211  0.66308314 0.66944472 0.66589407 0.66589407
#  0.66742282 0.668705   0.66540093 0.67462274]

# %%
base_scores_df = pd.DataFrame([base_scores]).T
base_scores_df.columns = ({'Recall_scores':0})
print('Recall Base Scores')
base_scores_df
# Out:
# Recall Base Scores
#                      Recall_scores
# Gradient_Boost            0.694908
# Logistic Regression       0.674314
# Random_Forest             0.375490

# %%
final_scores_df = pd.DataFrame([final_scores]).T
final_scores_df.columns = ({'Recall_scores':0})
print('Final Recall Scores')
final_scores_df.sort_index()
# Out:
# Final Recall Scores
#                      Recall_scores
# Gradient Boost            0.651595
# LASSO lr                  0.679687
# Logistic Regression       0.674314
# PCA_lr                    0.679015
# Random Forest             0.664130

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Using LASSO linear regression turned out to be just a little bit better than the maually feature selected model. It also beat out PCA by just a hair. Although, I looked at tree based methods linear regression is the best model for this project. It is easier to explain since the coefficients of the model can tell you how a particualr feature affects the prediction. This could help when lookin at specific locations to concentrate efforts to make the bus routes more efficient.

# %% [markdown]
# If MTA found it useful the model probabilities could be adjusted to caprture more of the Late buses at the expense of misclassifying the on-time buses and vice-versa. Below is an example of how that could be achieved.

# %%
# fuction for prcision recall plot 
def precision_recall_plot (model,X,y):
    y_prob = cross_val_predict(model, X, y, method='predict_proba',cv=10)
    precisions, recalls,thresholds=precision_recall_curve(y, y_prob[:,1])
    plt.plot(thresholds,precisions[:-1],"b--",label="Precision")
    plt.plot(thresholds,recalls[:-1],"g-",label="Recall")
    plt.title('Precision-Recall vs Threshold')
    plt.xlabel("Threshold")
    plt.legend(loc="best")
    plt.ylim([0,1])
precision_recall_plot (LASSO_lr,X_testS,y_test) 
plt.show()

# %%
y_prob = lr.predict_proba(X_testS)
y_pred_class = binarize(y_prob,0.49)
y_pred_class = y_pred_class[:,1]
 
 
print('Confusion Matrix with binarized class:')
print(pd.crosstab( y_test,y_pred_class))
print()
print('Classification report with binarized class:') 
print(classification_report(y_test ,y_pred_class))
# Out:
# Confusion Matrix with binarized class:
# col_0       0.0   1.0
# Late_Bus
# 0         16380  9082
# 1          2723  6212
#
# Classification report with binarized class:
#               precision    recall  f1-score   support
#
#            0       0.86      0.64      0.74     25462
#            1       0.41      0.70      0.51      8935
#
#     accuracy                           0.66     34397
#    macro avg       0.63      0.67      0.62     34397
# weighted avg       0.74      0.66      0.68     34397

# %% [markdown]
# #### Limitations  and future work

# %% [markdown]
# There are several limitations with the model that should be considered. The first being that the dataset was only from one month, June. Although, there were six million observations they only tell us about the month of June. It would be better to have samples from every month of the year. This way we could look annual patterns such as seasonal traffic and weather. Another imitation is that, because of time, there wasn't much spent on reseaching patterns that effect traffic or into what actually causes a bus to be late in the first place(it may not always be traffic). Data collection on volume of riders in particular areas could possible benificial as well. There is also the matter of the limitations of my local machine to run the algorithms. I would have liked to have used much more of the data if I could have but time and resouces limited me to the small sample that was used.
