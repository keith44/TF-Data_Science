# 932           0
# 933           0
# 935           0
# 936           0
# 942           0
# 943           0
# 944           0
# 949           0
# 951           0
# 953           0
# 955           0
# 959           0
# 965           0
# 966           0
# 968           0
# 969           0
# 970           0
# 972           0
# 973           0
# 974           0
# 979           0
# 980           0
# 981           0
# 982           0
# 983           0
# 984           0
# 985           0
# 986           0
# 987           0
# 988           0
# 989           0
# 990           0
# 991           0
# 992           0
# 993           0
# 994           0
# 995           0
# 996           0
# 997           0
# 998           0
# 999           0
#
#                                                                                                                                                    reviews
# 0                                                                       So there is no way for me to plug it in here in the US unless I go by a converter.
# 3                                                                          Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!
# 5                                                                               I have to jiggle the plug to get it to line up right to get decent volume.
# 6                                          If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.
# 8                                                                                                                      Needless to say, I wasted my money.
# 9                                                                                                                         What a waste of money and time!.
# 12                                      If the two were seperated by a mere 5+ ft I started to notice excessive static and garbled sound from the headset.
# 14                                                                               The design is very odd, as the ear "clip" is not very comfortable at all.
# 16                                                                                                                     I advise EVERYONE DO NOT BE FOOLED!
# 19                                                                 It clicks into place in a way that makes you wonder how long that mechanism would last.
# 20                                                           I went on Motorola's website and followed all directions, but could not get it to pair again.
# 22                                                                                                                The commercials are the most misleading.
# 24                                                                                       I bought it for my mother and she had a problem with the battery.
# 27                                                                                       I didn't think that the instructions provided were helpful to me.
# 28                                                                   People couldnt hear me talk and I had to pull out the earphone and talk on the phone.
# 29                                                                                                                                    Doesn't hold charge.
# 30                                                                                 This is a simple little phone to use, but the breakage is unacceptible.
# 32                                                                                                        It is unusable in a moving car at freeway speed.
# 33                                                                                      I have two more years left in this contract and I hate this phone.
# 35                                     You need at least 3 mins to get to your phone book from the time you first turn on the phone.Battery life is short.
# 37                                                                                                                             Poor Talk Time Performance.
# 39                                                                                                                                      worthless product.
# 41                                                                                                                    I was not impressed by this product.
# 43                                                                                                                          I only hear garbage for audio.
# 46                                                                                                     Who in their right mind is gonna buy this battery?.
# 47                                                           AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS.
# 49                                                                                                                              Disappointed with battery.
# 50                                                                                                     Not loud enough and doesn't turn on like it should.
# 56                                                                                                                                      VERY DISAPPOINTED.
# 59                                                                                                                     The buttons for on and off are bad.
# 60                                                                                                    Essentially you can forget Microsoft's tech support.
# 63                                                                                                                   Buy a different phone - but not this.
# 64                                                               You have to hold the phone at a particular angle for the other party to hear you clearly.
# 65   The one big drawback of the MP3 player is that the buttons on the phone's front cover that let you pause and skip songs lock out after a few seconds.
# 66                                                                                                    A week later after I activated it, it suddenly died.
# 70                                                                                                                                       Mic Doesn't work.
# 71                                                  Even in my BMW 3 series which is fairly quiet, I have trouble hearing what the other person is saying.
# 76                                                                                                      Do Not Buy for D807...wrongly advertised for D807.
# 79                                                                                    I purchased this and within 2 days it was no longer working!!!!!!!!!
# 81                                                                                                                                     Not a good bargain.
# 83                                                                                                                          The battery runs down quickly.
# 84                                                                                             This item worked great, but it broke after 6 months of use.
# 87                                                                                                               The construction of the headsets is poor.
# 90                           For a product that costs as much as this one does, I expect it to work far better and with greater ease than this thing does.
# 93                                                                                                                The ear buds only play music in one ear.
# 94                                                                                                                                Dont waste your money...
# 96                                                                                                       If you plan to use this in a car forget about it.
# 97                                                                                                               I found this product to be waaay too big.
# 99                                                                                                                 I'm very disappointed with my decision.
# 101                                                                                             Buyer Beware, you could flush money right down the toilet.
# 104                                      I received my supposedly new motorola 375 and apparently there was not a match between the phone and the charger.
# 106                                                        That's a huge design flaw (unless I'm not using it correctly, which I don't think is the case).
# 108     The camera, although rated at an impressive 1.3 megapixels, renders images that fall well below expectations of such a relatively high resolution.
# 109                                                                                             I purcashed this for the car charger and it does not work.
# 116                                                                             i got this phone around the end of may and i'm completely unhappy with it.
# 121                                                                                                                    Could not get strong enough signal.
# 123                                                                                                                                           Bad Quality.
# 126                                                                                                                    Basically the service was very bad.
# 127                                                                              it did not work in my cell phone plug i am very up set with the charger!.
# 129                                                                                                                The BT headset was such a disapoinment.
# 134                                                                                                                           Buyer--Be Very Careful!!!!!.
# 135                                                                                                   The majority of the Logitech earbud headsets failed.
# 138                                                                    In my house I was getting dropped coverage upstairs and no coverage in my basement.
# 140                                                                                                                                          What a waste.
# 141                                                  During several different 2 minute calls, I experienced 5 drops and it was in an area that had 5 bars.
# 142                                                                                                                        I was not happy with this item.
# 143                                                                                                                                     very disappointed.
# 144                                                                                         The phone takes FOREVER to charge like 2 to 5 hours literally.
# 146                                                                                                                                  What a waste of time!
# 147                                                                                                                       Its reception is very very poor.
# 148                                                                                        Items stated as included from the description ARE NOT INCLUDED.
# 149                                                                                                After 3 months, screen just went black all of a sudden.
# 150                                                                                                                                 I Was Hoping for More.
# 151                                                                                                                      Audio Quality is poor, very poor.
# 154                                                                                          I've bought $5 wired headphones that sound better than these.
# 160                                                    All I can do is whine on the Internet, so here it goes.The more I use the thing the less I like it.
# 162                                                                                   This is essentially a communications tool that does not communicate.
# 164                   I still maintain that monkeys shouldn't make headphones, we just obviously don't share enough DNA to copy the design over to humans.
# 166                                                                                      Doesn't work at all.. I bougth it for my L7c and its not working.
# 168                                                                                                                                     doesn't last long.
# 169                                                                                                   One thing I hate is the mode set button at the side.
# 171                                                                                                                        Thank you for wasting my money.
# 172                                                                                                             How can that be?The audio quality is poor.
# 177                                             I put the latest OS on it (v1.15g), and it now likes to slow to a crawl and lock up every once in a while.
# 178                                                                                                    It only recognizes the Phone as its storage device.
# 179                                                             If you like a loud buzzing to override all your conversations, then this phone is for you!
# 180                                                                                                                                Don't buy this product.
# 181                                          I've had this bluetoooth headset for some time now and still not comfortable with the way it fits on the ear.
# 183                                                                                     I have this phone and it is a thorn in my side, I really abhor it.
# 184                                           I recently had problems where I could not stay connected for more than 10 minutes before being disconnected.
# 186                                                                                                                                          Design Flaw?.
# 188                                                                                                                                     Waste of 13 bucks.
# 189                          But when I check voice mail at night, the keypad backlight turns off a few seconds into the first message, and then I'm lost.
# 190                                                                                                                   The replacement died in a few weeks.
# 193                                                                                                  I have had problems wit hit dropping signal and more.
# 194                                                                                                                                         Not impressed.
# 197                                                                                                                                            Bad Choice.
# 198                                                                                                                         The pleather case doesn't fit.
# 199                                                                                                                            useless phone, simply deaf.
# 202                                                                                          It makes very strange ticking noises before it ends the call.
# 204                                                                                                                        Battery lasts only a few hours.
# 209                                                                                                                                We are sending it back.
# 210         I did not bother contacting the company for few dollar product but I learned the lesson that I should not have bought this form online anyway.
# 211                                                                                                    If you hate earbugs, avoid this phone by all means.
# 217                                                                              I also didn't like the "on" button, it felt like it would crack with use.
# 218                                                                                                                                      WORST PHONE EVER.
# 220                                                                                                                                   Freezes frequently4.
# 221                                   It's kind of embarrassing to use because of how it looks and mostly it's embarrassing how child-like the company is.
# 223                                                                                   All in all, I'd expected a better consumer experience from Motorola.
# 224                                                  There's a horrible tick sound in the background on all my calls that I have never experienced before.
# 227                                                                                                                                I'm a bit disappointed.
# 228                                                                    I have had this phone for over a year now, and I will tell you, its not that great.
# 229                                                   I ordered this for sony Ericsson W810i but I think it only worked once (thats when I first used it).
# 230                                                                                                               The battery is completely useless to me.
# 231                                                                                                                              What a big waste of time.
# 232                                                                                                                      Don't waste your $$$ on this one.
# 239                                                                                                                    Do not make the same mistake as me.
# 240                                                                                                                 Big Disappointment with calendar sync.
# 241                                                                                                                the phone was unusable and was not new.
# 242                                                                                                                           Worst Customer Service Ever.
# 243                                                                                       No additional ear gels provided, and no instructions whatsoever.
# 244                                                                                                         It defeats the purpose of a bluetooth headset.
# 248                                                                                                                       Internet is excrutiatingly slow.
# 254                                          This product had a strong rubber/petroleum smell that was unbearable after a while and caused me to return it
# 255                                                                                                                              poor quality and service.
# 256                                                                                                       The cable looks so thin and flimsy, it is scary.
# 263                                                                                                                                        Absolutel junk.
# 264                                                                                                                           THAT one didn't work either.
# 266                                                                                                                                Returned 8 hours later.
# 268                                                                                                                               Don't waste your money!.
# 270                                                                                   Not only will it drain your player, but may also potentially fry it.
# 272                                                                                                                            Unreliable - I'm giving up.
# 274                                                                                                                             Avoid this one if you can.
# 276                                                                                                           I wasted my little money with this earpiece.
# 282                                                                                                                    First of all, it doesn't wear well.
# 286                                                                                                              I wouldn't recommend buying this product.
# 287                                                                                                                                         Piece of Junk.
# 288                                                                                                                               Poorly contstruct hinge.
# 291                                                                                                                                          Don't buy it.
# 293                                                                                                                            DO NOT PURCHASE THIS PHONE.
# 298                                                                                                                         Customer service was terrible.
# 299                                                                                              Battery life still not long enough in Motorola Razor V3i.
# 300                                                                                                                                       Sending it back.
# 307                                                                            As many people complained, I found this headset's microphone was very weak.
# 308                                                                        My 5-year old Nokia 2160 from Tracfone holds the charge a lot better than this.
# 309                                                                                                           They do not care about the consumer one bit.
# 311                                                                                                                     The instruction manual is lacking.
# 314                                                                                           The battery is unreliable as well as the service use antena.
# 315     It's uncomfortable and the sound quality is quite poor compared with the phone (Razr) or with my previous wired headset (that plugged into an LG).
# 318                                                                                                                                  I want my money back.
# 321                                                                                      I ordered this product first and was unhappy with it immediately.
# 322                                                                                                                 The Ngage is still lacking in earbuds.
# 324                                                                       I have 2-3 bars on my cell phone when I am home, but you cant not hear anything.
# 326                                                                                    However-the riingtones are not the best, and neither are the games.
# 327                                                                                                                       The plug did not work very well.
# 328                                                                                                                                          AMAZON SUCKS.
# 329                                                                                                                      Rip off---- Over charge shipping.
# 335                                                    1. long lasting battery (you don't have to recharge it as frequentyly as some of the flip phones)2.
# 336                                                                                                        Obviously there is a problem with the adhesive.
# 337                                                                                                                                    Very disappointing.
# 338                                                                           It was an inexpensive piece, but I would still have expected better quality.
# 339                                                         It is practically useless and did not add any kind of boost to my reception after I bought it.
# 341                                                                                                                                         Was not happy.
# 342                                                                                       A PIECE OF JUNK THAT BROKE AFTER BEING ON MY PHONE FOR 2 DAYS!!!
# 344                                                                                                                                Worst customer service.
# 346                                                                                                              Reception is terrible and full of static.
# 349                                                                  I was sitting in my vehicle, with the cradle on my belt, and the headset lost signal.
# 350                                                                                                                               Were JERKS on the phone.
# 353                                                                                                     Their network coverage in Los Angeles is horrible.
# 354                                                                                                                    Excellent starter wireless headset.
# 355                                                                    The loudspeaker option is great, the bumpers with the lights is very ... appealing.
# 356                                                                     The only thing that I think could improve is the sound leaks out from the headset.
# 357                                                                                First off the reception sucks, I have never had more than 2 bars, ever.
# 358                                                                                                                          The phone gets EXTREMELY HOT!
# 361                                                   Also, if your phone is dropped, this case is not going to save it, specially when dropped face down.
# 363                                                                                                                                  bad fit, way too big.
# 366                                                                                                                                        Waste of money.
# 370                                                                                     I'll be drivng along, and my headset starts ringing for no reason.
# 373                                                                                        The worst phone I've ever had.... Only had it for a few months.
# 374                                                   Not a good item.. It worked for a while then started having problems in my auto reverse tape player.
# 375                                                                This is so embarassing and also my ears hurt if I try to push the ear plug into my ear.
# 377                                                                    This is a VERY average phone with bad battery life that operates on a weak network.
# 379                                                                                                                                 Soyo technology sucks.
# 382                                                                                                                 Same problem as others have mentioned.
# 385                                                                                  The worst piece of crap ever along with the Verizon customer service.
# 386                                                                                                                                    Poor sound quality.
# 391                                                            The picture resolution is far below what other comparably-priced phones are offering today.
# 396                                                                                Using all earpieces, left or right, this thing will not stay on my ear.
# 399                                                                         Still Waiting...... I'm sure this item would work well.. if I ever recieve it!
# 400                                                                                                                                  what a disappointment
# 404                                                                                                                       don't waste your money and time.
# 406                   It's so stupid to have to keep buying new chargers, car chargers, cradles, headphones and car kits every time a new phone comes out.
# 409                             I came over from Verizon because cingulair has nicer cell phones.... the first thing I noticed was the really bad service.
# 410                                                                                                                    I'll be looking for a new earpiece.
# 413   We received a WHITE colored battery that goes DEAD after a couple hoursTHe original used to last a week - but still lasts longer than thereplacement
# 414                                                                                           After a year the battery went completely dead on my headset.
# 417                                                                                        This is the first phone I've had that has been so cheaply made.
# 418                                                                          Att is not clear, sound is very distorted and you have to yell when you talk.
# 419                                                                                                           The plastic breaks really easy on this clip.
# 421                                                                                                                     Don't make the same mistake I did.
# 422                                                                           Oh and I forgot to also mention the weird color effect it has on your phone.
# 424                                                                           Also the area where my unit broke).- I'm not too fond of the magnetic strap.
# 427                                    Another note about this phone's appearance is that it really looks rather bland, especially in the all black model.
# 432                                                                                                                                           Low Quality.
# 435                                                                                                                                   Warning - Stay away.
# 436                                                                                                  I wish I could return the unit and get back my money.
# 438                                                         I used to talk on it for 1 - 1 1/2 hours and the battery would be literally drained and dying.
# 439                                      If you don't find it, too bad, as again the unit comes with one earpad only.I would not recommend this to anyone.
# 440                                                                                                                                       Very Displeased.
# 441                                                 I might have gotten a defect, but I would not risk buying it again because of the built quality alone.
# 442                                                                                        They made this case too small and is very difficult to install.
# 446                                                                                                                                          Does not fit.
# 449                                                                                               There's really nothing bad I can say about this headset.
# 453                I even fully charged it before I went to bed and turned off blue tooth and wi-fi and noticed that it only had 20 % left in the morning.
# 454                                         I've also had problems with the phone reading the memory card in which I always turn it on and then off again.
# 455                                                                                                             Not good when wearing a hat or sunglasses.
# 459                                                                                                                                        Horrible phone.
# 460                                                                                                                                    BT50 battery junk!.
# 462                                                                                                        Cant get the software to work with my computer.
# 463                                                                                                                                         Disappointed!.
# 464                                                                                                                                    poor voice clarity.
# 466                                                                                                                        No buyers remorse on this one!.
# 467                                                                                                                     Very disappointed in AccessoryOne.
# 468                                                    I find this inexcusable and so will probably be returning this phone and perhaps changing carriers.
# 471                                                                                                      The update procedure is difficult and cumbersome.
# 472                                                                                                  Disappointment.. I hate anything that goes in my ear.
# 476                                                                                              Uncomfortable In the Ear, Don't use with LG VX9900 (EnV).
# 477                                                                                   The volume switch rocketed out of the unit to a destination unknown.
# 479                                                                                                                                 I'd like to return it.
# 481                                                      Verizon's bills, however, are difficult to understand even though their pricing plans are simple.
# 485                                                                                                                                      A Disappointment.
# 486                                                                                                                                 Its not user friendly.
# 487           Unfortunately the ability to actually know you are receiving a call is a rather important feature and this phone is pitiful in that respect.
# 488                                                                                   Then I exchanged for the same phone, even that had the same problem.
# 489                                                                                    This results in the phone being either stuck at max volume or mute.
# 494                                                                                                                                  Pretty piece of junk.
# 495                                                                                                                               Plug was the wrong size.
# 497                                                                                              Save your money.... I've had this item for 11 months now.
# 498                                                                                                                                          Bad Purchase.
# 502                                                                                                                                        Defective crap.
# 503                                                                                                              I would have given no star if I was able.
# 505                                       The sound quality for the device is unacceptable.Unless you are in a really quiet area, you almost hear nothing.
# 506                                                                                                             I would not recommend this item to anyone.
# 507                                                                                            The holster that arrived did not match the photo in the ad.
# ...
# 826                                                                                                                            Not as good as I had hoped.
# 828                                                                                                                                          Doesn't Work.
# 830                                                                                                                         Unfortunately it did not work.
# 831                                                                                                              All three broke within two months of use.
# 832                                                                                                                                           dont buy it.
# 833                                                                                                      My father has the V265, and the battery is dying.
# 834                                                                              However, the ear pads come off easily and after only one week I lost one.
# 835                        The calls drop, the phone comes on and off at will, the screen goes black and the worst of all it stops ringing intermittently.
# 836                                                                                                                          Horrible, horrible protector.
# 837                                                                                                                        I don't like this Nokia either.
# 838                                           Reaching for the bottom row is uncomfortable, and the send and end keys are not where I expect them to be.3.
# 839                                                                            I have bought this Nokia cell phone a few weeks ago and it was a nightmare.
# 840                                                        It would take too long to describe how bad my customer service experience has been with Amazon.
# 841                                                                                    the only VERY DISAPPOINTING thing was there was NO SPEAKERPHONE!!!!
# 842                                                                                                       Terrible.. My car will not accept this cassette.
# 843                           Product is useless, since it does not have enough charging current to charge the 2 cellphones I was planning to use it with.
# 844                                                                                                                           It's not what it says it is.
# 845                                                                                                                                 Stay Away From the Q!.
# 846                                                                                                                                        Used and dirty.
# 847                                                                                                                Very unreliable service from T-mobile !
# 848                                                                                                                         Not good enough for the price.
# 849                                                                                                          I bought two of them and neither will charge.
# 853                                                                               These products cover up the important light sensor above the ear outlet.
# 855                                                                                                                                    Just does not work.
# 856                                                                                                                                      Poor Reliability.
# 858                                                          If I take a picture, the battery drops a bar, and starts beeping, letting me know its dieing.
# 859                                                                                                                  Terrible product, and waste of money!
# 860                                                                                                                             Last time buying from you.
# 861                                                                                                                            It was a waste of my money.
# 868                                                                                                                     The item received was Counterfeit.
# 875                                                                                                 This is by far the worst purchase I've made on Amazon.
# 878                                                                                           Does not work for listening to music with the cingular 8125.
# 880                                                                                       The bottowm line...another worthless, cheap gimmick from Sprint.
# 881                                                                                                                            Having trouble with volume.
# 883                                                                                                                                WARNING - DO NOT BUY!!.
# 885                                                                          When it opens, the battery connection is broken and the device is turned off.
# 886                                                                               I didn't want the clip going over the top of my ear, causing discomfort.
# 888                                                                                        Don't trust their website and don't expect any helpful support.
# 890                                                                            The speaker is of low quality so as making the ring tones sound very cheap.
# 893                                                                                                                                         Bad Reception.
# 894                                                                                                   This product is very High quality Chinese CRAP!!!!!!
# 897                                                                                                                    Don't buy this product - It fails!.
# 898                                                                                                           Everything about this product is wrong.First
# 900                                                This was utterly confusing at first, which caused me to lose a couple of very, very important contacts.
# 901                                                                                                                                 Terrible phone holder.
# 904                                                                              Problem is that the ear loops are made of weak material and break easily.
# 905                                                                                        Not nearly as good looking as the AMAZON picture makes it look.
# 907                                                                                                                                    How stupid is that?
# 912                                                                           It always cuts out and makes a beep beep beep sound then says signal failed.
# 913                                                                                                                                 Couldn't figure it out
# 914         My phone sounded OK ( not great - OK), but my wife's phone was almost totally unintelligible, she couldn't understand a word being said on it.
# 915                                                            So I had to take the battery out of the phone put it all back together and then restart it.
# 916                            While I managed to bend the leaf spring back in place, the metal now has enough stress that it will break on the next drop.
# 919                                                                                                                           Saggy, floppy piece of junk.
# 921                                                                                                                             It also had a new problem.
# 926                                                                It looses connection to the phone even when it is within a couple feet between the two.
# 928                                                                                  Makes it easier to keep up with my bluetooth when I'm not wearing it.
# 929                                                                                                                     As I said above....PRETTY USELESS!
# 930                                                                                                                                      Never got it!!!!!
# 931                                                                                  This pair of headphones is the worst that I have ever had sound-wise.
# 932                                                                                                           [...] down the drain because of a weak snap!
# 933                                                                                                         Does not charge the Cingular (ATT) 8525 phone.
# 935   However, after about a year, the fliptop started to get loose and wobbly and eventually my screen went black and I couldn't receive and place calls.
# 936                                                            I kept catching the cable on the seat and I had to pull the phone out to turn it on an off.
# 942                                                                                                  The mic there is a joke, and the volume is quite low.
# 943                                                                                                                                    I'm returning them.
# 944                                                                              I does not maintain a connection with the computer while it is on my lap.
# 949                                                                                                                    I had to purchase a different case.
# 951                                                                                                              Very much disappointed with this company.
# 953                                                                                                                               It didn't charge for me.
# 955                                                                                                                                 Buttons are too small.
# 959                                                                            However, the keypads are so tinny that I sometimes reach the wrong buttons.
# 965                                                                                                                 I cannot make calls at certain places.
# 966                                                         however, my girl was complain that some time the phone doesn't wake up like normal phone does.
# 968                                                                         This company charge me a restocking fee and still not given me my refund back.
# 969                                                                                                                  I'm trying to return it for a refund.
# 970                                                                                              I plugged it in only to find out not a darn thing worked.
# 972                                                                                                                            Earbud piece breaks easily.
# 973                                                                                                                                         Lousy product.
# 974                                                              This phone tries very hard to do everything but fails at it's very ability to be a phone.
# 979                                                                                                                                     Not enough volume.
# 980                                                                                                                    Echo Problem....Very unsatisfactory
# 981                                                                                  you could only take 2 videos at a time and the quality was very poor.
# 982                                                                                                                                don't waste your money.
# 983                                                                                  I am going to have to be the first to negatively review this product.
# 984                                                                                                      Adapter does not provide enough charging current.
# 985                                                                     There was so much hype over this phone that I assumed it was the best, my mistake.
# 986                                                                        You also cannot take pictures with it in the case because the lense is covered.
# 987                                                                                                                                Phone falls out easily.
# 988                                                                                                    It didn't work, people can not hear me when I talk.
# 989                                                                                                    The text messaging feature is really tricky to use.
# 990                                                                                 I'm really disappointed all I have now is a charger that doesn't work.
# 991                                                                                                                                    Painful on the ear.
# 992                                                                                                                       Lasted one day and then blew up.
# 993                                                                                                                                          disappointed.
# 994                                                                                                                                  Kind of flops around.
# 995                                                                               The screen does get smudged easily because it touches your ear and face.
# 996                                                                                                What a piece of junk.. I lose more calls on this phone.
# 997                                                                                                                           Item Does Not Match Picture.
# 998                                                                                        The only thing that disappoint me is the infra red port (irda).
# 999                                                                                             You can not answer calls with the unit, never worked once!

# %%
keywords = ['disappointment','is not', 'broke','poor']

for key in keywords:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    df[str(key)] = df.reviews.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

# %%
df['neg_rating'] = (df['neg_rating'] == 0)

# %%
sns.heatmap(df.corr())
plt.show()

# %%
data = df[keywords]
target = df['neg_rating']

# %%
#importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB()
# Fit our model to the data.
bnb.fit(data, target)
#storing the result in a new variable.
y_pred = bnb.predict(data)
# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 1000 points : 491

# %%
a = list(y_pred==target)
Accuracy = (1-(a.count(False)/df.neg_rating.count()))*100
Accuracy
# Out:
# 50.9

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(target, y_pred))
print ('This will show the counts for when a review was negative and we predicted negative, when a message was negative')
print   ('and we predicted positive,when a message was positive and we predicted negative, and when a message was positive and we predicted positive.')
# Out:
# [[498   2]
#  [489  11]]
# This will show the counts for when a review was negative and we predicted negative, when a message was negative
# and we predicted positive,when a message was positive and we predicted negative, and when a message was positive and we predicted positive.

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(bnb, data, target, cv=10))
# Out:
# [0.51 0.5  0.5  0.51 0.5  0.5  0.51 0.5  0.51 0.5 ]

# %% [markdown]
# ## Test Classifiers

# %%
test_words = ['disappointment','is not','broke','poor','not','broken','waste','time and money']
neg_caps = []
for word in test_words:
    for review in df[df['neg_rating']==True].reviews:
        if word.upper() in review.split():
              
             neg_caps.append(word.upper())

# %%
neg_caps
# Out:
# ['BROKE', 'NOT', 'NOT', 'NOT', 'NOT', 'NOT', 'NOT', 'NOT', 'NOT']

# %%
test_words = test_words+['NOT','BROKE']

# %%
for key in test_words:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    df[str(key)] = df.reviews.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

# %%
data = df[test_words]
target = df['neg_rating']

# %%
#importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB()
# Fit our model to the data.
bnb.fit(data, target)
#storing the result in a new variable.
y_pred = bnb.predict(data)
# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 1000 points : 410

# %%
print(confusion_matrix(target, y_pred))
print(cross_val_score(bnb, data, target, cv=10))
# Out:
# [[488  12]
#  [398 102]]
# [0.58 0.62 0.6  0.58 0.58 0.53 0.61 0.58 0.62 0.57]

# %% [markdown]
# 1. Do any of your classifiers seem to overfit?
# <p>Yes. The classifiers that have several words and words that are the same but capitalized. Most likely because they are mre complicated and some of the same words are in the same review.
# <p>2. Which seem to perform the best? Why?
# <p>I could never get performance above 60%. But I feel like the iterations with fewer features perfomed the best. Im assuming less correlation between features.
# <p>3. Which features seemed to be most impactful to performance?
# <p>The words that were excluively found only in the negative reviews.

# %%
from sklearn.model_selection import train_test_split
# Create the necessary training and test groups
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=20)
print('Holdout: ' + str(bnb.fit(X_train, y_train).score(X_train, y_train)))
print('Sample: ' + str(bnb.fit(data, target).score(data, target)))
# Out:
# Holdout: 0.585
# Sample: 0.59
