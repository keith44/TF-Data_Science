# %%
import re
import time
import math
import pandas as pd
import numpy as np
import seaborn as sns
#plt.style.use('seaborn')
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy import stats
from scipy.stats.mstats import winsorize
from scipy.stats import boxcox
from matplotlib import pyplot
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.preprocessing import binarize
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.decomposition import PCA

# %%
# Load data 
#mta = pd.read_csv('C:/Users/keith/Desktop/Thinkful/mta_1706.csv',encoding = "ISO-8859-1",error_bad_lines=False)
mta = pd.read_csv('C:/Users/keith/Desktop/Thinkful/mta_1706_1.csv',encoding = "ISO-8859-1",error_bad_lines=False)
pd.set_option('display.max_columns', 50)
# Out:
# b'Skipping line 53192: expected 17 fields, saw 18\nSkipping line 56712: expected 17 fields, saw 18\nSkipping line 64874: expected 17 fields, saw 18\n'
# b'Skipping line 80636: expected 17 fields, saw 18\nSkipping line 97072: expected 17 fields, saw 18\n'
# b'Skipping line 107697: expected 17 fields, saw 18\nSkipping line 109317: expected 17 fields, saw 18\nSkipping line 119951: expected 17 fields, saw 18\n'
# b'Skipping line 134667: expected 17 fields, saw 18\nSkipping line 139923: expected 17 fields, saw 18\nSkipping line 144309: expected 17 fields, saw 18\nSkipping line 157927: expected 17 fields, saw 18\nSkipping line 158907: expected 17 fields, saw 18\nSkipping line 161424: expected 17 fields, saw 18\n'
# b'Skipping line 173221: expected 17 fields, saw 18\nSkipping line 173623: expected 17 fields, saw 18\nSkipping line 177253: expected 17 fields, saw 18\nSkipping line 181883: expected 17 fields, saw 18\nSkipping line 186684: expected 17 fields, saw 18\nSkipping line 191267: expected 17 fields, saw 18\nSkipping line 192638: expected 17 fields, saw 18\n'
# b'Skipping line 198582: expected 17 fields, saw 18\nSkipping line 207576: expected 17 fields, saw 18\n'
# b'Skipping line 274978: expected 17 fields, saw 18\nSkipping line 282857: expected 17 fields, saw 18\n'
# b'Skipping line 306714: expected 17 fields, saw 18\nSkipping line 307656: expected 17 fields, saw 18\nSkipping line 308636: expected 17 fields, saw 18\nSkipping line 311964: expected 17 fields, saw 18\nSkipping line 315657: expected 17 fields, saw 18\nSkipping line 317437: expected 17 fields, saw 18\n'
# b'Skipping line 332034: expected 17 fields, saw 18\nSkipping line 336792: expected 17 fields, saw 18\n'
# b'Skipping line 360611: expected 17 fields, saw 18\nSkipping line 369173: expected 17 fields, saw 18\nSkipping line 373398: expected 17 fields, saw 18\n'
# b'Skipping line 418734: expected 17 fields, saw 18\nSkipping line 423485: expected 17 fields, saw 18\nSkipping line 425578: expected 17 fields, saw 18\n'
# b'Skipping line 442738: expected 17 fields, saw 18\nSkipping line 446894: expected 17 fields, saw 18\nSkipping line 449808: expected 17 fields, saw 18\n'
# b'Skipping line 464755: expected 17 fields, saw 18\n'
# b'Skipping line 740832: expected 17 fields, saw 18\n'
# b'Skipping line 844406: expected 17 fields, saw 18\n'
# b'Skipping line 872155: expected 17 fields, saw 18\nSkipping line 876394: expected 17 fields, saw 18\n'
# b'Skipping line 899678: expected 17 fields, saw 18\n'
# b'Skipping line 919833: expected 17 fields, saw 18\nSkipping line 929574: expected 17 fields, saw 18\nSkipping line 946011: expected 17 fields, saw 18\n'
# b'Skipping line 957396: expected 17 fields, saw 18\nSkipping line 965579: expected 17 fields, saw 18\nSkipping line 969684: expected 17 fields, saw 18\nSkipping line 976815: expected 17 fields, saw 18\nSkipping line 982269: expected 17 fields, saw 18\n'
# b'Skipping line 992521: expected 17 fields, saw 18\nSkipping line 996306: expected 17 fields, saw 18\nSkipping line 1000790: expected 17 fields, saw 18\n'
# b'Skipping line 1070414: expected 17 fields, saw 18\nSkipping line 1072055: expected 17 fields, saw 18\n'
# b'Skipping line 1101971: expected 17 fields, saw 18\nSkipping line 1106995: expected 17 fields, saw 18\n'
# b'Skipping line 1115222: expected 17 fields, saw 18\nSkipping line 1142539: expected 17 fields, saw 18\nSkipping line 1144118: expected 17 fields, saw 18\n'
# b'Skipping line 1147281: expected 17 fields, saw 18\nSkipping line 1147458: expected 17 fields, saw 18\nSkipping line 1153785: expected 17 fields, saw 18\nSkipping line 1160059: expected 17 fields, saw 18\nSkipping line 1164062: expected 17 fields, saw 18\nSkipping line 1170855: expected 17 fields, saw 18\nSkipping line 1174682: expected 17 fields, saw 18\n'
# b'Skipping line 1186903: expected 17 fields, saw 18\nSkipping line 1188705: expected 17 fields, saw 18\nSkipping line 1190863: expected 17 fields, saw 18\nSkipping line 1210933: expected 17 fields, saw 18\n'
# b'Skipping line 1217362: expected 17 fields, saw 18\nSkipping line 1230158: expected 17 fields, saw 18\nSkipping line 1232587: expected 17 fields, saw 18\nSkipping line 1236069: expected 17 fields, saw 18\n'
# b'Skipping line 1254443: expected 17 fields, saw 18\nSkipping line 1256202: expected 17 fields, saw 18\nSkipping line 1263156: expected 17 fields, saw 18\nSkipping line 1270521: expected 17 fields, saw 18\n'
# b'Skipping line 1281745: expected 17 fields, saw 18\nSkipping line 1282451: expected 17 fields, saw 18\n'
# b'Skipping line 1355578: expected 17 fields, saw 18\n'
# b'Skipping line 1377038: expected 17 fields, saw 18\nSkipping line 1388187: expected 17 fields, saw 18\nSkipping line 1390642: expected 17 fields, saw 18\nSkipping line 1401056: expected 17 fields, saw 18\n'
# b'Skipping line 1416542: expected 17 fields, saw 18\nSkipping line 1416985: expected 17 fields, saw 18\nSkipping line 1422864: expected 17 fields, saw 18\nSkipping line 1423747: expected 17 fields, saw 18\nSkipping line 1430234: expected 17 fields, saw 18\nSkipping line 1433229: expected 17 fields, saw 18\n'
# b'Skipping line 1454896: expected 17 fields, saw 18\nSkipping line 1459654: expected 17 fields, saw 18\nSkipping line 1467629: expected 17 fields, saw 18\nSkipping line 1471608: expected 17 fields, saw 18\n'
# b'Skipping line 1502344: expected 17 fields, saw 18\nSkipping line 1505312: expected 17 fields, saw 18\n'
# b'Skipping line 1525902: expected 17 fields, saw 18\n'
# b'Skipping line 1561590: expected 17 fields, saw 18\n'
# b'Skipping line 1590940: expected 17 fields, saw 18\n'
# b'Skipping line 1636897: expected 17 fields, saw 18\n'
# b'Skipping line 1655995: expected 17 fields, saw 18\nSkipping line 1660656: expected 17 fields, saw 18\n'
# b'Skipping line 1680500: expected 17 fields, saw 18\nSkipping line 1682744: expected 17 fields, saw 18\nSkipping line 1700295: expected 17 fields, saw 18\n'
# b'Skipping line 1707982: expected 17 fields, saw 18\nSkipping line 1720081: expected 17 fields, saw 18\nSkipping line 1723379: expected 17 fields, saw 18\nSkipping line 1732178: expected 17 fields, saw 18\n'
# b'Skipping line 1745701: expected 17 fields, saw 18\n'
# b'Skipping line 1849221: expected 17 fields, saw 18\nSkipping line 1860422: expected 17 fields, saw 18\nSkipping line 1864756: expected 17 fields, saw 18\n'
# b'Skipping line 1901602: expected 17 fields, saw 18\nSkipping line 1907204: expected 17 fields, saw 18\nSkipping line 1921663: expected 17 fields, saw 18\nSkipping line 1923928: expected 17 fields, saw 18\nSkipping line 1929858: expected 17 fields, saw 18\n'
# b'Skipping line 1947980: expected 17 fields, saw 18\nSkipping line 1948149: expected 17 fields, saw 18\nSkipping line 1950035: expected 17 fields, saw 18\n'
# b'Skipping line 1970713: expected 17 fields, saw 18\nSkipping line 1987045: expected 17 fields, saw 18\nSkipping line 1988365: expected 17 fields, saw 18\nSkipping line 1992639: expected 17 fields, saw 18\n'
# b'Skipping line 2000986: expected 17 fields, saw 18\nSkipping line 2019763: expected 17 fields, saw 18\nSkipping line 2020432: expected 17 fields, saw 18\nSkipping line 2028497: expected 17 fields, saw 18\n'
# b'Skipping line 2095920: expected 17 fields, saw 18\n'
# b'Skipping line 2404951: expected 17 fields, saw 18\n'
# b'Skipping line 2437013: expected 17 fields, saw 18\n'
# b'Skipping line 2458160: expected 17 fields, saw 18\n'
# b'Skipping line 2493052: expected 17 fields, saw 18\nSkipping line 2500451: expected 17 fields, saw 18\n'
# b'Skipping line 2523849: expected 17 fields, saw 18\nSkipping line 2541460: expected 17 fields, saw 18\nSkipping line 2554787: expected 17 fields, saw 18\n'
# b'Skipping line 2558302: expected 17 fields, saw 18\nSkipping line 2578372: expected 17 fields, saw 18\n'
# b'Skipping line 2589324: expected 17 fields, saw 18\nSkipping line 2591779: expected 17 fields, saw 18\n'
# b'Skipping line 2682435: expected 17 fields, saw 18\n'
# b'Skipping line 2704020: expected 17 fields, saw 18\nSkipping line 2704911: expected 17 fields, saw 18\n'
# b'Skipping line 2723063: expected 17 fields, saw 18\nSkipping line 2735017: expected 17 fields, saw 18\nSkipping line 2739993: expected 17 fields, saw 18\nSkipping line 2747034: expected 17 fields, saw 18\n'
# b'Skipping line 2787875: expected 17 fields, saw 18\nSkipping line 2796290: expected 17 fields, saw 18\nSkipping line 2798729: expected 17 fields, saw 18\nSkipping line 2800652: expected 17 fields, saw 18\nSkipping line 2808117: expected 17 fields, saw 18\nSkipping line 2813104: expected 17 fields, saw 18\nSkipping line 2815115: expected 17 fields, saw 18\n'
# b'Skipping line 2831078: expected 17 fields, saw 18\nSkipping line 2831884: expected 17 fields, saw 18\nSkipping line 2832778: expected 17 fields, saw 18\n'
# b'Skipping line 2935466: expected 17 fields, saw 18\nSkipping line 2937968: expected 17 fields, saw 18\n'
# b'Skipping line 2952504: expected 17 fields, saw 18\n'
# b'Skipping line 2982958: expected 17 fields, saw 18\nSkipping line 2991335: expected 17 fields, saw 18\nSkipping line 3006710: expected 17 fields, saw 18\nSkipping line 3013361: expected 17 fields, saw 18\n'
# b'Skipping line 3019557: expected 17 fields, saw 18\nSkipping line 3032671: expected 17 fields, saw 18\n'
# b'Skipping line 3068454: expected 17 fields, saw 18\nSkipping line 3079236: expected 17 fields, saw 18\n'
# b'Skipping line 3081942: expected 17 fields, saw 18\nSkipping line 3095240: expected 17 fields, saw 18\n'
# b'Skipping line 3166450: expected 17 fields, saw 18\nSkipping line 3178126: expected 17 fields, saw 18\n'
# b'Skipping line 3192452: expected 17 fields, saw 18\nSkipping line 3197375: expected 17 fields, saw 18\nSkipping line 3201771: expected 17 fields, saw 18\nSkipping line 3204318: expected 17 fields, saw 18\nSkipping line 3204532: expected 17 fields, saw 18\nSkipping line 3210597: expected 17 fields, saw 18\n'
# b'Skipping line 3212282: expected 17 fields, saw 18\nSkipping line 3228977: expected 17 fields, saw 18\nSkipping line 3231910: expected 17 fields, saw 18\nSkipping line 3240546: expected 17 fields, saw 18\nSkipping line 3243270: expected 17 fields, saw 18\n'
# b'Skipping line 3245772: expected 17 fields, saw 18\nSkipping line 3259252: expected 17 fields, saw 18\nSkipping line 3272379: expected 17 fields, saw 18\n'
# b'Skipping line 3280630: expected 17 fields, saw 18\nSkipping line 3281342: expected 17 fields, saw 18\nSkipping line 3291539: expected 17 fields, saw 18\nSkipping line 3300347: expected 17 fields, saw 18\n'
# b'Skipping line 3309875: expected 17 fields, saw 18\nSkipping line 3317106: expected 17 fields, saw 18\nSkipping line 3335049: expected 17 fields, saw 18\n'
# b'Skipping line 3376809: expected 17 fields, saw 18\n'
# b'Skipping line 3412350: expected 17 fields, saw 18\nSkipping line 3419390: expected 17 fields, saw 18\n'
# b'Skipping line 3446892: expected 17 fields, saw 18\nSkipping line 3456194: expected 17 fields, saw 18\nSkipping line 3458959: expected 17 fields, saw 18\nSkipping line 3459635: expected 17 fields, saw 18\nSkipping line 3472051: expected 17 fields, saw 18\n'
# b'Skipping line 3475751: expected 17 fields, saw 18\nSkipping line 3476571: expected 17 fields, saw 18\nSkipping line 3497325: expected 17 fields, saw 18\n'
# b'Skipping line 3512051: expected 17 fields, saw 18\nSkipping line 3515105: expected 17 fields, saw 18\nSkipping line 3527521: expected 17 fields, saw 18\n'
# b'Skipping line 3547380: expected 17 fields, saw 18\nSkipping line 3549855: expected 17 fields, saw 18\n'
# b'Skipping line 3572799: expected 17 fields, saw 18\nSkipping line 3590486: expected 17 fields, saw 18\nSkipping line 3596992: expected 17 fields, saw 18\n'
# b'Skipping line 3960523: expected 17 fields, saw 18\n'
# b'Skipping line 3988533: expected 17 fields, saw 18\nSkipping line 3997918: expected 17 fields, saw 18\n'
# b'Skipping line 3999453: expected 17 fields, saw 18\nSkipping line 4007138: expected 17 fields, saw 18\nSkipping line 4007920: expected 17 fields, saw 18\nSkipping line 4014103: expected 17 fields, saw 18\nSkipping line 4014583: expected 17 fields, saw 18\n'
# b'Skipping line 4037166: expected 17 fields, saw 18\nSkipping line 4058680: expected 17 fields, saw 18\n'
# b'Skipping line 4064046: expected 17 fields, saw 18\nSkipping line 4066807: expected 17 fields, saw 18\nSkipping line 4073482: expected 17 fields, saw 18\nSkipping line 4076186: expected 17 fields, saw 18\nSkipping line 4093190: expected 17 fields, saw 18\nSkipping line 4093852: expected 17 fields, saw 18\n'
# b'Skipping line 4097270: expected 17 fields, saw 18\nSkipping line 4110167: expected 17 fields, saw 18\nSkipping line 4127349: expected 17 fields, saw 18\n'
# b'Skipping line 4164525: expected 17 fields, saw 18\n'
# b'Skipping line 4201456: expected 17 fields, saw 18\nSkipping line 4211555: expected 17 fields, saw 18\n'
# b'Skipping line 4228824: expected 17 fields, saw 18\nSkipping line 4234196: expected 17 fields, saw 18\nSkipping line 4236536: expected 17 fields, saw 18\nSkipping line 4251822: expected 17 fields, saw 18\nSkipping line 4252329: expected 17 fields, saw 18\nSkipping line 4258045: expected 17 fields, saw 18\n'
# b'Skipping line 4260182: expected 17 fields, saw 18\nSkipping line 4263103: expected 17 fields, saw 18\nSkipping line 4271671: expected 17 fields, saw 18\nSkipping line 4278125: expected 17 fields, saw 18\nSkipping line 4285474: expected 17 fields, saw 18\n'
# b'Skipping line 4298761: expected 17 fields, saw 18\nSkipping line 4300543: expected 17 fields, saw 18\nSkipping line 4301790: expected 17 fields, saw 18\nSkipping line 4316570: expected 17 fields, saw 18\n'
# b'Skipping line 4338237: expected 17 fields, saw 18\nSkipping line 4354436: expected 17 fields, saw 18\n'
# b'Skipping line 4361610: expected 17 fields, saw 18\n'
# b'Skipping line 4444283: expected 17 fields, saw 18\n'
# b'Skipping line 4477147: expected 17 fields, saw 18\n'
# b'Skipping line 4492082: expected 17 fields, saw 18\nSkipping line 4495557: expected 17 fields, saw 18\nSkipping line 4501701: expected 17 fields, saw 18\nSkipping line 4510449: expected 17 fields, saw 18\nSkipping line 4513207: expected 17 fields, saw 18\nSkipping line 4521441: expected 17 fields, saw 18\n'
# b'Skipping line 4530077: expected 17 fields, saw 18\nSkipping line 4537333: expected 17 fields, saw 18\nSkipping line 4548580: expected 17 fields, saw 18\n'
# b'Skipping line 4556105: expected 17 fields, saw 18\nSkipping line 4568176: expected 17 fields, saw 18\nSkipping line 4572140: expected 17 fields, saw 18\nSkipping line 4572520: expected 17 fields, saw 18\nSkipping line 4580452: expected 17 fields, saw 18\n'
# b'Skipping line 4612265: expected 17 fields, saw 18\nSkipping line 4618925: expected 17 fields, saw 18\n'
# b'Skipping line 4624453: expected 17 fields, saw 18\nSkipping line 4639035: expected 17 fields, saw 18\n'
# b'Skipping line 4718629: expected 17 fields, saw 18\n'
# b'Skipping line 4742362: expected 17 fields, saw 18\nSkipping line 4748345: expected 17 fields, saw 18\n'
# b'Skipping line 4755233: expected 17 fields, saw 18\nSkipping line 4758047: expected 17 fields, saw 18\nSkipping line 4763645: expected 17 fields, saw 18\nSkipping line 4770279: expected 17 fields, saw 18\nSkipping line 4775067: expected 17 fields, saw 18\nSkipping line 4775823: expected 17 fields, saw 18\nSkipping line 4776025: expected 17 fields, saw 18\nSkipping line 4780525: expected 17 fields, saw 18\n'
# b'Skipping line 4801294: expected 17 fields, saw 18\n'
# b'Skipping line 4818472: expected 17 fields, saw 18\nSkipping line 4830909: expected 17 fields, saw 18\nSkipping line 4832988: expected 17 fields, saw 18\nSkipping line 4835432: expected 17 fields, saw 18\nSkipping line 4836249: expected 17 fields, saw 18\n'
# b'Skipping line 4851377: expected 17 fields, saw 18\nSkipping line 4865343: expected 17 fields, saw 18\n'
# b'Skipping line 4884503: expected 17 fields, saw 18\n'
# b'Skipping line 4958585: expected 17 fields, saw 18\nSkipping line 4961274: expected 17 fields, saw 18\nSkipping line 4974784: expected 17 fields, saw 18\n'
# b'Skipping line 5006716: expected 17 fields, saw 18\nSkipping line 5009085: expected 17 fields, saw 18\n'
# b'Skipping line 5015818: expected 17 fields, saw 18\nSkipping line 5017357: expected 17 fields, saw 18\nSkipping line 5020180: expected 17 fields, saw 18\nSkipping line 5037360: expected 17 fields, saw 18\nSkipping line 5039693: expected 17 fields, saw 18\nSkipping line 5044272: expected 17 fields, saw 18\n'
# b'Skipping line 5048007: expected 17 fields, saw 18\nSkipping line 5055144: expected 17 fields, saw 18\nSkipping line 5056368: expected 17 fields, saw 18\nSkipping line 5063196: expected 17 fields, saw 18\nSkipping line 5071921: expected 17 fields, saw 18\n'
# b'Skipping line 5082156: expected 17 fields, saw 18\n'
# b'Skipping line 5113679: expected 17 fields, saw 18\nSkipping line 5119167: expected 17 fields, saw 18\nSkipping line 5131938: expected 17 fields, saw 18\nSkipping line 5133736: expected 17 fields, saw 18\n'
# b'Skipping line 5158386: expected 17 fields, saw 18\n'
# b'Skipping line 5278636: expected 17 fields, saw 18\n'
# b'Skipping line 5389023: expected 17 fields, saw 18\nSkipping line 5393062: expected 17 fields, saw 18\n'
# b'Skipping line 5410409: expected 17 fields, saw 18\n'
# b'Skipping line 5444054: expected 17 fields, saw 18\n'
# b'Skipping line 5496628: expected 17 fields, saw 18\nSkipping line 5496629: expected 17 fields, saw 18\n'
# b'Skipping line 5510776: expected 17 fields, saw 18\n'
# b'Skipping line 5548626: expected 17 fields, saw 18\nSkipping line 5551773: expected 17 fields, saw 18\nSkipping line 5556312: expected 17 fields, saw 18\nSkipping line 5570453: expected 17 fields, saw 18\n'
# b'Skipping line 5577387: expected 17 fields, saw 18\nSkipping line 5580723: expected 17 fields, saw 18\nSkipping line 5582075: expected 17 fields, saw 18\nSkipping line 5596334: expected 17 fields, saw 18\nSkipping line 5602325: expected 17 fields, saw 18\n'
# b'Skipping line 5606005: expected 17 fields, saw 18\nSkipping line 5621782: expected 17 fields, saw 18\nSkipping line 5629873: expected 17 fields, saw 18\n'
# b'Skipping line 5639776: expected 17 fields, saw 18\nSkipping line 5662907: expected 17 fields, saw 18\n'
# b'Skipping line 5673236: expected 17 fields, saw 18\nSkipping line 5678791: expected 17 fields, saw 18\nSkipping line 5684215: expected 17 fields, saw 18\nSkipping line 5693496: expected 17 fields, saw 18\n'
# b'Skipping line 5731235: expected 17 fields, saw 18\n'
# b'Skipping line 5759128: expected 17 fields, saw 18\nSkipping line 5766555: expected 17 fields, saw 18\n'
# b'Skipping line 5775788: expected 17 fields, saw 18\nSkipping line 5779012: expected 17 fields, saw 18\n'
# b'Skipping line 5801331: expected 17 fields, saw 18\nSkipping line 5807183: expected 17 fields, saw 18\nSkipping line 5812686: expected 17 fields, saw 18\nSkipping line 5822305: expected 17 fields, saw 18\nSkipping line 5828445: expected 17 fields, saw 18\n'
# b'Skipping line 5851730: expected 17 fields, saw 18\nSkipping line 5856208: expected 17 fields, saw 18\nSkipping line 5856889: expected 17 fields, saw 18\nSkipping line 5864523: expected 17 fields, saw 18\n'
# b'Skipping line 5871637: expected 17 fields, saw 18\nSkipping line 5875905: expected 17 fields, saw 18\nSkipping line 5888949: expected 17 fields, saw 18\nSkipping line 5894274: expected 17 fields, saw 18\n'
# b'Skipping line 5901556: expected 17 fields, saw 18\nSkipping line 5908375: expected 17 fields, saw 18\nSkipping line 5928411: expected 17 fields, saw 18\n'
# b'Skipping line 5939929: expected 17 fields, saw 18\n'
# b'Skipping line 5997128: expected 17 fields, saw 18\nSkipping line 6023760: expected 17 fields, saw 18\n'
# b'Skipping line 6030761: expected 17 fields, saw 18\nSkipping line 6032844: expected 17 fields, saw 18\nSkipping line 6046718: expected 17 fields, saw 18\nSkipping line 6060288: expected 17 fields, saw 18\nSkipping line 6060477: expected 17 fields, saw 18\n'
# b'Skipping line 6065731: expected 17 fields, saw 18\nSkipping line 6067656: expected 17 fields, saw 18\nSkipping line 6072908: expected 17 fields, saw 18\nSkipping line 6079543: expected 17 fields, saw 18\nSkipping line 6088356: expected 17 fields, saw 18\nSkipping line 6094155: expected 17 fields, saw 18\n'
# b'Skipping line 6101235: expected 17 fields, saw 18\n'
# b'Skipping line 6132143: expected 17 fields, saw 18\nSkipping line 6139104: expected 17 fields, saw 18\nSkipping line 6146333: expected 17 fields, saw 18\n'
# b'Skipping line 6190077: expected 17 fields, saw 18\nSkipping line 6193015: expected 17 fields, saw 18\n'
# b'Skipping line 6262650: expected 17 fields, saw 18\nSkipping line 6284097: expected 17 fields, saw 18\n'
# b'Skipping line 6292669: expected 17 fields, saw 18\nSkipping line 6302387: expected 17 fields, saw 18\n'
# b'Skipping line 6339934: expected 17 fields, saw 18\nSkipping line 6341457: expected 17 fields, saw 18\nSkipping line 6346586: expected 17 fields, saw 18\nSkipping line 6346878: expected 17 fields, saw 18\n'
# b'Skipping line 6360199: expected 17 fields, saw 18\nSkipping line 6388811: expected 17 fields, saw 18\nSkipping line 6389583: expected 17 fields, saw 18\n'
# b'Skipping line 6401202: expected 17 fields, saw 18\n'
# b'Skipping line 6426884: expected 17 fields, saw 18\nSkipping line 6438882: expected 17 fields, saw 18\nSkipping line 6439104: expected 17 fields, saw 18\n'
# b'Skipping line 6539344: expected 17 fields, saw 18\n'
# b'Skipping line 6567952: expected 17 fields, saw 18\nSkipping line 6569797: expected 17 fields, saw 18\nSkipping line 6574347: expected 17 fields, saw 18\nSkipping line 6577542: expected 17 fields, saw 18\nSkipping line 6578318: expected 17 fields, saw 18\nSkipping line 6579562: expected 17 fields, saw 18\n'
# b'Skipping line 6595302: expected 17 fields, saw 18\nSkipping line 6597315: expected 17 fields, saw 18\nSkipping line 6602012: expected 17 fields, saw 18\nSkipping line 6610542: expected 17 fields, saw 18\n'
# b'Skipping line 6637529: expected 17 fields, saw 18\nSkipping line 6643652: expected 17 fields, saw 18\n'
# b'Skipping line 6689855: expected 17 fields, saw 18\n'

# %%
#mta.to_csv('C:/Users/keith/Desktop/Thinkful/MTA_UPDATED.csv')

# %%
mta = mta.sample(frac=.02, random_state=20)
len(mta)
# Out:
# 134609

# %% [markdown]
# # Data Description

# %%
mta.head()
# Out:
#               RecordedAtTime  DirectionRef PublishedLineName  \
# 249431   2017-06-02 00:05:00             1               Q17
# 5083624  2017-06-23 16:20:48             0           B44-SBS
# 2001707  2017-06-09 17:38:05             1               Bx9
# 2315680  2017-06-11 15:10:33             1              Bx41
# 2230060  2017-06-10 22:20:22             1                B1
#
#                             OriginName  OriginLat  OriginLong  \
# 249431                    138 ST/37 AV  40.761806  -73.829559
# 5083624             KNAPP ST/SHORE PKY  40.585033  -73.931328
# 2001707                            NaN        NaN         NaN
# 2315680  WHITE PLAINS RD/E GUN HILL RD  40.877853  -73.866669
# 2230060                     87 ST/4 Av  40.621925  -74.028496
#
#                                   DestinationName  DestinationLat  \
# 249431                          JAMAICA ARCHER AV       40.704933
# 5083624  SBS WLMSBRG BRDG PLZ via NSTRND via RGRS       40.709316
# 2001707                                WEST FARMS       40.840641
# 2315680                THE HUB 150 ST via WEBSTER       40.816887
# 2230060              MANHATTAN BEACH KINGSBORO CC       40.578094
#
#          DestinationLong VehicleRef  VehicleLocation.Latitude  \
# 249431        -73.793320  NYCT_8442                 40.712529
# 5083624       -73.959587  NYCT_5357                 40.603164
# 2001707       -73.879807  NYCT_1214                 40.879992
# 2315680       -73.917488  NYCT_5538                 40.819222
# 2230060       -73.940170  NYCT_7158                 40.576590
#
#          VehicleLocation.Longitude           NextStopPointName  \
# 249431                  -73.784314     HILLSIDE AV/EDGERTON BL
# 5083624                 -73.942410        NOSTRAND AV/KINGS HY
# 2001707                 -73.904038           BROADWAY/W 231 ST
# 2315680                 -73.916341         MELROSE AV/E 152 ST
# 2230060                 -73.968469  BRIGHTON BEACH AV/OCEAN PY
#
#         ArrivalProximityText  DistanceFromStop  ExpectedArrivalTime  \
# 249431           approaching             128.0                  NaN
# 5083624       0.9 miles away            1427.0  2017-06-23 16:26:00
# 2001707          approaching             120.0  2017-06-09 17:39:19
# 2315680        < 1 stop away             154.0  2017-06-11 15:11:24
# 2230060          approaching             104.0  2017-06-10 22:20:58
#
#         ScheduledArrivalTime
# 249431              23:58:34
# 5083624             16:26:16
# 2001707                  NaN
# 2315680             14:59:05
# 2230060             22:21:22

# %%
 mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134609 entries, 249431 to 732369
# Data columns (total 17 columns):
# RecordedAtTime               134609 non-null object
# DirectionRef                 134609 non-null int64
# PublishedLineName            134609 non-null object
# OriginName                   133313 non-null object
# OriginLat                    133313 non-null float64
# OriginLong                   133313 non-null float64
# DestinationName              134609 non-null object
# DestinationLat               134412 non-null float64
# DestinationLong              134412 non-null float64
# VehicleRef                   134609 non-null object
# VehicleLocation.Latitude     134609 non-null float64
# VehicleLocation.Longitude    134609 non-null float64
# NextStopPointName            134472 non-null object
# ArrivalProximityText         134472 non-null object
# DistanceFromStop             134472 non-null float64
# ExpectedArrivalTime          116919 non-null object
# ScheduledArrivalTime         131110 non-null object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 18.5+ MB

# %%
mta.shape
# Out:
# (134609, 17)

# %% [markdown]
# # Data cleansing

# %%
mta.duplicated().sum()
# Out:
# 0

# %%
#pd.set_option('display.max_columns', None) # disables trucated columns 
#pd.set_option('display.max_rows', None) # disables trucated rows
mta.head()
# Out:
#               RecordedAtTime  DirectionRef PublishedLineName  \
# 249431   2017-06-02 00:05:00             1               Q17
# 5083624  2017-06-23 16:20:48             0           B44-SBS
# 2001707  2017-06-09 17:38:05             1               Bx9
# 2315680  2017-06-11 15:10:33             1              Bx41
# 2230060  2017-06-10 22:20:22             1                B1
#
#                             OriginName  OriginLat  OriginLong  \
# 249431                    138 ST/37 AV  40.761806  -73.829559
# 5083624             KNAPP ST/SHORE PKY  40.585033  -73.931328
# 2001707                            NaN        NaN         NaN
# 2315680  WHITE PLAINS RD/E GUN HILL RD  40.877853  -73.866669
# 2230060                     87 ST/4 Av  40.621925  -74.028496
#
#                                   DestinationName  DestinationLat  \
# 249431                          JAMAICA ARCHER AV       40.704933
# 5083624  SBS WLMSBRG BRDG PLZ via NSTRND via RGRS       40.709316
# 2001707                                WEST FARMS       40.840641
# 2315680                THE HUB 150 ST via WEBSTER       40.816887
# 2230060              MANHATTAN BEACH KINGSBORO CC       40.578094
#
#          DestinationLong VehicleRef  VehicleLocation.Latitude  \
# 249431        -73.793320  NYCT_8442                 40.712529
# 5083624       -73.959587  NYCT_5357                 40.603164
# 2001707       -73.879807  NYCT_1214                 40.879992
# 2315680       -73.917488  NYCT_5538                 40.819222
# 2230060       -73.940170  NYCT_7158                 40.576590
#
#          VehicleLocation.Longitude           NextStopPointName  \
# 249431                  -73.784314     HILLSIDE AV/EDGERTON BL
# 5083624                 -73.942410        NOSTRAND AV/KINGS HY
# 2001707                 -73.904038           BROADWAY/W 231 ST
# 2315680                 -73.916341         MELROSE AV/E 152 ST
# 2230060                 -73.968469  BRIGHTON BEACH AV/OCEAN PY
#
#         ArrivalProximityText  DistanceFromStop  ExpectedArrivalTime  \
# 249431           approaching             128.0                  NaN
# 5083624       0.9 miles away            1427.0  2017-06-23 16:26:00
# 2001707          approaching             120.0  2017-06-09 17:39:19
# 2315680        < 1 stop away             154.0  2017-06-11 15:11:24
# 2230060          approaching             104.0  2017-06-10 22:20:58
#
#         ScheduledArrivalTime
# 249431              23:58:34
# 5083624             16:26:16
# 2001707                  NaN
# 2315680             14:59:05
# 2230060             22:21:22

# %%
mta.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation.Latitude',
#        'VehicleLocation.Longitude', 'NextStopPointName',
#        'ArrivalProximityText', 'DistanceFromStop', 'ExpectedArrivalTime',
#        'ScheduledArrivalTime'],
#       dtype='object')

# %%
mta.columns=['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
       'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
       'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
       'VehicleLocation_Long', 'NextStopPointName',
       'ArrivalProximityText', 'DistanceFromStop', 'ExpectedArrivalTime',
       'ScheduledArrivalTime']

# %%
mta.isnull().sum()
# Out:
# RecordedAtTime              0
# DirectionRef                0
# PublishedLineName           0
# OriginName               1296
# OriginLat                1296
# OriginLong               1296
# DestinationName             0
# DestinationLat            197
# DestinationLong           197
# VehicleRef                  0
# VehicleLocation_Lat         0
# VehicleLocation_Long        0
# NextStopPointName         137
# ArrivalProximityText      137
# DistanceFromStop          137
# ExpectedArrivalTime     17690
# ScheduledArrivalTime     3499
# dtype: int64

# %%
mta.isnull().sum()/mta.isnull().count()
# Out:
# RecordedAtTime          0.000000
# DirectionRef            0.000000
# PublishedLineName       0.000000
# OriginName              0.009628
# OriginLat               0.009628
# OriginLong              0.009628
# DestinationName         0.000000
# DestinationLat          0.001463
# DestinationLong         0.001463
# VehicleRef              0.000000
# VehicleLocation_Lat     0.000000
# VehicleLocation_Long    0.000000
# NextStopPointName       0.001018
# ArrivalProximityText    0.001018
# DistanceFromStop        0.001018
# ExpectedArrivalTime     0.131418
# ScheduledArrivalTime    0.025994
# dtype: float64

# %% [markdown]
# We need to drop the rows with missing arrival times. It is usless to us if we can't find the bus is late or not.

# %%
mta = mta[mta.ExpectedArrivalTime.isnull()==False]  
mta.isnull().sum()
# Out:
# RecordedAtTime             0
# DirectionRef               0
# PublishedLineName          0
# OriginName              1109
# OriginLat               1109
# OriginLong              1109
# DestinationName            0
# DestinationLat           150
# DestinationLong          150
# VehicleRef                 0
# VehicleLocation_Lat        0
# VehicleLocation_Long       0
# NextStopPointName          0
# ArrivalProximityText       0
# DistanceFromStop           0
# ExpectedArrivalTime        0
# ScheduledArrivalTime    1109
# dtype: int64

# %%
mta = mta[mta.ScheduledArrivalTime.isnull()==False]
mta.isnull().sum()
# Out:
# RecordedAtTime          0
# DirectionRef            0
# PublishedLineName       0
# OriginName              0
# OriginLat               0
# OriginLong              0
# DestinationName         0
# DestinationLat          0
# DestinationLong         0
# VehicleRef              0
# VehicleLocation_Lat     0
# VehicleLocation_Long    0
# NextStopPointName       0
# ArrivalProximityText    0
# DistanceFromStop        0
# ExpectedArrivalTime     0
# ScheduledArrivalTime    0
# dtype: int64

# %%
# reindex dataset
mta.index = range(len(mta.index))

# %% [markdown]
# That took care of all of our null values, that we can tell anyway.

# %% [markdown]
# Next we need to create a target variable. We are trying to predict if a bus is going to be late or not so we will convert the time rows in to manageable data and the find the difference in times.

# %%
# modifying "ScheduledArrivalTime" format to match "EstimatedArrivalTime"
mta.loc[list(np.where(mta.ScheduledArrivalTime=='24:00:00')[0]),'ScheduledArrivalTime'] = '00:00:01'
mta['ScheduledArrivalTime'] = pd.to_timedelta(mta.ScheduledArrivalTime)
mta['ScheduledArrivalTime'] = pd.to_timedelta(mta.ScheduledArrivalTime)
mta['ScheduledArrivalTime'] = pd.to_datetime(mta.ScheduledArrivalTime)

# converting "ExpectedArrivalTime" to datetime format and them finding the diffence between ScheduledArrivalTime
# "ExpectedArrivalTime"
mta['ExpectedArrivalTime'] = pd.to_datetime(mta.ExpectedArrivalTime)
mta['ScheduledArrivalTime'] = mta.ExpectedArrivalTime.dt.date.astype('str') +' '+ mta.ScheduledArrivalTime.dt.time.astype('str')
mta['ScheduledArrivalTime'] = pd.to_datetime(mta.ScheduledArrivalTime)
mta['ScheduledArrivalTime'] = pd.to_datetime(mta.ScheduledArrivalTime)
index = mta[(mta.ScheduledArrivalTime.dt.hour==23) & (mta.ExpectedArrivalTime.dt.hour==00)].index
mta.loc[index,'ScheduledArrivalTime'] = mta.ScheduledArrivalTime + pd.DateOffset(days=-1)

# Finally creating a binary target "Late_bus"
mta.loc[list(np.where(mta.ExpectedArrivalTime>mta.ScheduledArrivalTime)[0]),'Time_delay'] = pd.to_datetime(mta.ExpectedArrivalTime -  mta.ScheduledArrivalTime).dt.minute 
mta.loc[list(np.where(mta.ExpectedArrivalTime<mta.ScheduledArrivalTime)[0]),'Time_delay'] = pd.to_datetime(mta.ScheduledArrivalTime - mta.ExpectedArrivalTime ).dt.minute*-1
mta.loc[list(np.where(mta.Time_delay.isna()==True)[0]),'Time_delay'] = 0

mta['Late_Bus'] = np.where(mta.Time_delay>7, 1, 0)

# %%
# create time of day feature
bins=[0, 600, 115900, 170000, 200000, 235959]
bin_names = ['night','morning','afternoon','evening','Night']
mta['time_of_day'] = pd.cut(pd.to_numeric(mta.ScheduledArrivalTime.dt.time.astype(str).str.replace(':','')), bins,labels=bin_names)
mta['time_of_day'] = mta['time_of_day'].str.lower()

# %%
mta['RecordedAtTime'] = pd.to_datetime(mta.RecordedAtTime)

# %%
# checking to make sure that time is only in the month of June
mta.ScheduledArrivalTime.dt.month.unique()
# Out:
# array([6, 5], dtype=int64)

# %%
mta.drop(list(np.where(mta.ScheduledArrivalTime.dt.month==5)[0]),axis='index',inplace=True)
# reindex dataset
mta.index = range(len(mta.index))
mta.ScheduledArrivalTime.dt.month.unique()
# Out:
# array([6], dtype=int64)

# %%
# test to see if it worked from a sample
mta.sample(frac=.001).head(10)
# Out:
#             RecordedAtTime  DirectionRef PublishedLineName  \
# 13096  2017-06-12 16:33:01             1               M66
# 105593      RICHMOND AV/GENESEE AV          approaching              70.0
#
#        ExpectedArrivalTime ScheduledArrivalTime  Time_delay  Late_Bus  \
# 13096  2017-06-12 16:33:19  2017-06-12 16:20:00        13.0         1
# 16498  2017-06-09 19:58:09  2017-06-09 19:47:31        10.0         1
# 46227  2017-06-05 17:04:26  2017-06-05 17:03:12         1.0         0
# 42078  2017-06-15 06:28:55  2017-06-15 06:23:00         5.0         0
# 115676 2017-06-01 17:05:10  2017-06-01 17:02:46         2.0         0
# 22776  2017-06-25 12:44:29  2017-06-25 12:45:08         0.0         0
# 33482  2017-06-15 18:08:51  2017-06-15 18:11:24        -2.0         0
# 98819  2017-06-10 14:41:05  2017-06-10 14:36:38         4.0         0
# 95456  2017-06-07 16:05:36  2017-06-07 16:07:00        -1.0         0
# 105593 2017-06-21 19:47:36  2017-06-21 19:44:54         2.0         0
#
#        time_of_day
# 13096    afternoon
# 16498      evening
# 46227      evening
# 42078      morning
# 115676     evening
# 22776    afternoon
# 33482      evening
# 98819    afternoon
# 95456    afternoon
# 105593     evening

# %% [markdown]
# The conversion worked. We created a feature 'Time_delay' where the values are the minutes of delay ot the bus. Values that are greater than zero are the number of minutes past the scheduled arrival time. The values that are less that zero are the number of minutes the bus arrived ahead of schedule.
#
# The 'Late_Bus' feature is labels a '1' for a bus who's arrival time is greater than 15 min past the scheduled arrival time and labels a '0' for anything under that time. This is our target

# %%
mta.Late_Bus.value_counts()
# Out:
# 0    85510
# 1    30296
# Name: Late_Bus, dtype: int64

# %% [markdown]
#     Next, "ArrivalProximityText" and "DistanceFromStop" are redundant variables so one can be dropped.

# %%
mta.drop("ArrivalProximityText",1,inplace=True)

# %%
# convert the categorical variables to the correct data type
columns = ['DirectionRef','PublishedLineName','OriginName',
           'DestinationName','VehicleRef','NextStopPointName']
for col in columns:
    mta[col] = mta[col].astype('category')
mta['RecordedAtTime'] = pd.to_datetime(mta.RecordedAtTime)

# %%
mta[mta.NextStopPointName=='AMSTERDAM AV/W 112 ST']
# Out:
#             RecordedAtTime DirectionRef PublishedLineName  \
# 6397   2017-06-12 19:33:24            0               M11
# 25784  2017-06-07 15:35:23            0               M11
# 31043  2017-06-12 23:53:48            0               M11
# 70680  2017-06-16 18:19:46            0               M11
# 85305  2017-06-10 20:00:27            1               M11
# 87843  2017-06-02 13:16:07            1               M11
# 90554  2017-06-05 16:30:35            0               M11
# 96104  2017-06-20 07:05:22            1               M11
# 101003 2017-06-23 00:19:12            0               M11
# 111723 2017-06-01 11:43:54            0               M11
#
#                           OriginName  OriginLat  OriginLong  \
# 6397         BETHUNE ST/GREENWICH ST  40.736988  -74.006355
# 25784        BETHUNE ST/GREENWICH ST  40.736988  -74.006355
# 31043        BETHUNE ST/GREENWICH ST  40.736988  -74.006355
# 70680        BETHUNE ST/GREENWICH ST  40.736988  -74.006355
# 85305   RIVERBANK ST PK/CULTURAL CTR  40.826702  -73.955475
# 87843   RIVERBANK ST PK/CULTURAL CTR  40.826702  -73.955475
# 90554        BETHUNE ST/GREENWICH ST  40.736988  -74.006355
# 96104              BROADWAY/W 133 ST  40.818493  -73.955940
# 101003       BETHUNE ST/GREENWICH ST  40.736988  -74.006355
# 111723       BETHUNE ST/GREENWICH ST  40.736988  -74.006355
#
#                        DestinationName  DestinationLat  DestinationLong  \
# 6397        RIVERBANK 145 ST via 10 AV       40.826756       -73.955421
# 25784       RIVERBANK 145 ST via 10 AV       40.826756       -73.955421
# 31043                133 ST - BROADWAY       40.818256       -73.956108
# 70680       RIVERBANK 145 ST via 10 AV       40.826756       -73.955421
# 85305   WEST VILL ABINGDON SQ via 9 AV       40.737072       -74.005867
# 87843   WEST VILL ABINGDON SQ via 9 AV       40.737072       -74.005867
# 90554       RIVERBANK 145 ST via 10 AV       40.826756       -73.955421
# 96104   WEST VILL ABINGDON SQ via 9 AV       40.737072       -74.005867
# 101003               133 ST - BROADWAY       40.818256       -73.956108
# 111723      RIVERBANK 145 ST via 10 AV       40.826756       -73.955421
#
#        VehicleRef  VehicleLocation_Lat  VehicleLocation_Long  \
# 6397    NYCT_3879            40.803077            -73.963784
# 25784   NYCT_6651            40.804443            -73.962790
# 31043   NYCT_6425            40.802827            -73.963967
# 70680   NYCT_6705            40.802842            -73.963956
# 85305   NYCT_3854            40.804090            -73.963045
# 87843   NYCT_6685            40.805110            -73.962305
# 90554   NYCT_6374            40.803837            -73.963231
# 96104   NYCT_6682            40.803995            -73.963115
# 101003  NYCT_6635            40.802734            -73.964036
# 111723  NYCT_6425            40.802718            -73.964047
#
#             NextStopPointName  DistanceFromStop ExpectedArrivalTime  \
# 6397    AMSTERDAM AV/W 112 ST             193.0 2017-06-12 19:34:35
# 25784   AMSTERDAM AV/W 112 ST              19.0 2017-06-07 15:35:31
# 31043   AMSTERDAM AV/W 112 ST             225.0 2017-06-12 23:54:58
# 70680   AMSTERDAM AV/W 112 ST             223.0 2017-06-16 18:21:02
# 85305   AMSTERDAM AV/W 112 ST              12.0 2017-06-10 20:00:31
# 87843   AMSTERDAM AV/W 112 ST             141.0 2017-06-02 13:17:52
# 90554   AMSTERDAM AV/W 112 ST              96.0 2017-06-05 16:31:10
# 96104   AMSTERDAM AV/W 112 ST               0.0 2017-06-20 07:05:34
# 101003  AMSTERDAM AV/W 112 ST             236.0 2017-06-23 00:20:40
# 111723  AMSTERDAM AV/W 112 ST             238.0 2017-06-01 11:45:13
#
#        ScheduledArrivalTime  Time_delay  Late_Bus time_of_day
# 6397    2017-06-12 19:21:25        13.0         1     evening
# 25784   2017-06-07 15:32:08         3.0         0   afternoon
# 31043   2017-06-12 23:55:04         0.0         0       night
# 70680   2017-06-16 18:00:08        20.0         1     evening
# 85305   2017-06-10 20:00:05         0.0         0       night
# 87843   2017-06-02 13:15:49         2.0         0   afternoon
# 90554   2017-06-05 16:29:08         2.0         0   afternoon
# 96104   2017-06-20 07:00:57         4.0         0     morning
# 101003  2017-06-23 00:22:04        -1.0         0     morning
# 111723  2017-06-01 11:14:08        31.0         1     morning

# %% [markdown]
# # Exploratory Data Analysis

# %%
mta.describe()
# Out:
#            OriginLat     OriginLong  DestinationLat  DestinationLong  \
# count  115806.000000  115806.000000   115806.000000    115806.000000
# mean       40.729658     -73.931274       40.728954       -73.931725
# std         0.090263       0.093708        0.090452         0.094687
# min        40.506882     -74.248062       40.508106       -74.246948
# 25%        40.660664     -73.987373       40.660854       -73.988831
# 50%        40.715233     -73.932449       40.713356       -73.932266
# 75%        40.809174     -73.879936       40.809078       -73.878326
# max        40.912365     -73.701866       40.912376       -73.701385
#
#        VehicleLocation_Lat  VehicleLocation_Long  DistanceFromStop  \
# count        115806.000000         115806.000000     115806.000000
# mean             40.728719            -73.930994        244.118232
# std               0.086798              0.088389       1037.743906
# min              40.502898            -74.252305          0.000000
# 25%              40.659412            -73.979025         32.000000
# 50%              40.723281            -73.936394        104.000000
# 75%              40.804030            -73.883361        212.000000
# max              40.912340            -73.701492      33604.000000
#
#           Time_delay       Late_Bus
# count  115806.000000  115806.000000
# mean        5.331442       0.261610
# std         9.166907       0.439513
# min       -59.000000       0.000000
# 25%         0.000000       0.000000
# 50%         3.000000       0.000000
# 75%         8.000000       1.000000
# max        59.000000       1.000000

# %%
mta.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# From the histograms of our continuous features we can see that we have a very unbalanced target, which would be expected. There should definetly be more on-time busses that late ones. From here I want to look at the continuous variables for against the target.

# %%
# Test of the mean distance between stops of late and on-time busses
Late_Bus_dist = mta[mta.Late_Bus==1] 
On_Time_Bus_dist = mta[mta.Late_Bus==0] 
print(stats.ttest_ind(Late_Bus_dist.DistanceFromStop,On_Time_Bus_dist.DistanceFromStop),'\n')

# calculate correlation distance from stop and late busses
print('Correlation of distance from stops and late busses \n',mta.DistanceFromStop.corr(mta.Late_Bus))
print()
print(stats.ttest_ind(Late_Bus_dist.Time_delay,On_Time_Bus_dist.Time_delay),'\n')

# calculate correlation distance from stop and late busses
print('Correlation of time delays and late busses \n',mta.Time_delay.corr(mta.Late_Bus))
# Out:
# Ttest_indResult(statistic=6.249899310563019, pvalue=4.1214091559838564e-10)
#
# Correlation of distance from stops and late busses
#  0.01836276210680795
#
# Ttest_indResult(statistic=399.7154960095788, pvalue=0.0)
#
# Correlation of time delays and late busses
#  0.7614298752414899

# %% [markdown]
# There is a statistically significant difference in the average distance from stop of Late busses and on-time busses. There is also a positive correlation between distance from stop and late busses.

# %%
mta[['Time_delay','DistanceFromStop']].describe()
# Out:
#           Time_delay  DistanceFromStop
# count  115806.000000     115806.000000
# mean        5.331442        244.118232
# std         9.166907       1037.743906
# min       -59.000000          0.000000
# 25%         0.000000         32.000000
# 50%         3.000000        104.000000
# 75%         8.000000        212.000000
# max        59.000000      33604.000000

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.boxplot(mta.Time_delay)
plt.title('Time Delay')
plt.subplot(222)
plt.title('Distance From Stop')
plt.boxplot(mta.DistanceFromStop) 
plt.show()

# %% [markdown]
# Nothing will be done to correct the outliers in the Time Delay variable. We used this to create out target variable and it will not be used in any models. As far a the distance from stop variable we can look at winzorizing to minimize the outliers.

# %%
winsor_dist = winsorize(mta["DistanceFromStop"], (0, .1)) # one way wizorization of distance from stop 
#                                                           variable with limit set at the 90th percentile

plt.figure(figsize=(10,10))
plt.title('Distance From Stop') 
plt.subplot(221)
plt.title('Distance From Stop')
plt.boxplot(mta.DistanceFromStop) 


plt.subplot(222)
plt.title('Winsorized Distance From Stop')
plt.boxplot(winsor_dist)
plt.show()

# %%
# create a feature for winsorization of the distance from stops
mta['winsor_dist'] = winsor_dist

# %%
mta.columns

# %% [markdown]
# The "DistanceFromStop" column is a measue of how far away the bus is from the destinaion at the given time stamp. I'm going to create a feature where the value is the max distance from the stop to the origin to see if there is any relationship beween late busses and the distance the bus must travel to the next stop.

# %%
# create a column where the values are the max distances from origin
dist = dict(mta.groupby('OriginName').DistanceFromStop.max())
mta['farthest_dist'] = mta.OriginName.map(dist)

# %%
plt.figure(figsize=(5,5)) 
sns.barplot(mta.Late_Bus,mta.farthest_dist,palette="Greens_d")
plt.title('Average Distance From Stop')
plt.show()

# %%
print('The mean distance between stops is ',mta[mta.Late_Bus==1]['farthest_dist'].mean())
print('The mean distance between stops is ',mta[mta.Late_Bus==0]['farthest_dist'].mean())
print(stats.ttest_ind(mta[mta.Late_Bus==1]['farthest_dist'], 
                      mta[mta.Late_Bus==0]['farthest_dist']))

# %%
order = mta[mta.Time_delay>=0].sort_values(by='farthest_dist',ascending=False).groupby('OriginName')['OriginName'].head(1)

plt.figure(figsize=(20,4))
sns.barplot(x=mta[mta.Time_delay>=0].OriginName,y=mta[mta.Time_delay>=0].Time_delay,palette="Greens_d")
plt.title('Arrival Delay Based on Origin')
plt.show()
plt.figure(figsize=(20,4))
sns.barplot(x=mta[mta.Time_delay>=0].OriginName,y=mta[mta.Time_delay>=0].farthest_dist,palette="Greens_d",order=order)
plt.title('Distance from Destination by')
plt.show()

# %%
plt.figure(figsize=(8,10))
order = mta[mta.Time_delay>=0].sort_values(by='farthest_dist',ascending=False).groupby('OriginName')['OriginName'].head(1)[:10]
plt.subplot(211)
sns.barplot(y=mta[mta.Time_delay>=0].OriginName,x=mta[mta.Time_delay>=0].farthest_dist,palette="Greens_d",order=order)
plt.title('Distance from Destination by')
#order = mta[mta.Time_delay>=0].groupby('OriginName').Time_delay.mean().sort_values(ascending=False)[:10].index 
plt.subplot(212)
sns.barplot(y=mta[mta.Time_delay>=0].OriginName,x=mta[mta.Time_delay>=0].Time_delay,palette="Greens_d", order=order)
plt.title('Arrival Delay Based on Origin')
plt.show()

# %%
mta['start_end'] = mta.OriginName.astype(str)+''+mta.DestinationName.astype(str)

# %%
mta.sample(frac=.1)[:10]

# %%
mtaa = mta[mta.Time_delay>=0]#.sample(frac=.001)

# %% [markdown]
# # Investigate Late Busses and Time Delays by hour

# %%
plt.figure(figsize=(14,16))
plt.subplot(321)
sns.lineplot(x= mta.ScheduledArrivalTime.dt.hour, 
             y=mta.Time_delay, data=mta,)

plt.title('Average Arrival delay (24 hours)')
plt.subplot(322)
sns.countplot(mta.ScheduledArrivalTime.dt.hour,palette= "gist_gray_r")

plt.title('Number of Busses in service per Hour')
plt.subplot(323)
sns.countplot(mta[mta.Late_Bus==1].ScheduledArrivalTime.dt.hour, palette= "gist_gray_r")
plt.title('Number of Late Busses per Hour')
plt.subplot(324)
sns.countplot(mta[mta.Late_Bus==0].ScheduledArrivalTime.dt.hour, palette= "gist_gray_r")
 
plt.title('Number of On-time Busses per Hour')
plt.show()

# %%
Late_bus_mean = mta[mta.Time_delay>=0].groupby(mta.ScheduledArrivalTime.dt.weekday).Time_delay.describe()
Late_bus_mean.index = weekday_order.values()
Late_bus_mean

# %%
# t-test between the means of the percentage of late busses of the hours in the day
for i in range(len(mta.ScheduledArrivalTime.dt.hour.unique())):
        for j in range(i+1,24):
            print(mta.ScheduledArrivalTime.dt.hour.unique()[i],' vs ',mta.ScheduledArrivalTime.dt.hour
                  .unique()[j]) 
            print(stats.ttest_ind(
                mta[mta.ScheduledArrivalTime.dt.hour==mta.ScheduledArrivalTime.dt.hour.unique()[i]]['Late_Bus'], 
                mta[mta.ScheduledArrivalTime.dt.hour==mta.ScheduledArrivalTime.dt.hour.unique()[j]]['Late_Bus']))

# %% [markdown]
# # Investigate Late Busses and Time Delays by day

# %%
#mta.ScheduledArrivalTime.dt.day_name().unique()
p = mta.groupby(mta.ScheduledArrivalTime.dt.weekday).Late_Bus.mean()
p.index = p.index.map(order)
p

# %%
weekday_order={0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
plt.figure(figsize=(14,16))
plt.subplot(321)
sns.lineplot(x= mta.ScheduledArrivalTime.dt.weekday, 
             y=mta.Time_delay, data=mta,)
plt.xticks(np.arange(7),weekday_order.values())
plt.title('Average Arrival delay (24 hours)')

plt.subplot(322)
sns.countplot(mta.ScheduledArrivalTime.dt.weekday,palette= "gist_gray_r")
plt.xticks(np.arange(7),weekday_order.values())
plt.title('Number of Busses in service ')

plt.subplot(323)
sns.countplot(mta[mta.Late_Bus==1].ScheduledArrivalTime.dt.weekday, palette= "gist_gray_r")
plt.title('Number of Late Busses')
plt.xticks(np.arange(7),weekday_order.values())
plt.subplot(324)
sns.countplot(mta[mta.Late_Bus==0].ScheduledArrivalTime.dt.weekday, palette= "gist_gray_r")
plt.xticks(np.arange(7),weekday_order.values()) 
plt.title('Number of On-time Busses per Hour')
plt.show()

# %%
#t between the means of the percentage of late busses of the days of the week
for i in range(len(mta.ScheduledArrivalTime.dt.weekday.unique())):
        for j in range(i+1,7):
            print(mta.ScheduledArrivalTime.dt.day_name().unique()[i],' vs ',mta.ScheduledArrivalTime.dt.day_name().unique()[j]) 
            print(stats.ttest_ind(
                mta[mta.ScheduledArrivalTime.dt.day_name()==mta.ScheduledArrivalTime.dt.day_name().unique()[i]]['Late_Bus'], 
                mta[mta.ScheduledArrivalTime.dt.day_name()==mta.ScheduledArrivalTime.dt.day_name().unique()[j]]['Late_Bus']))

# %%
plt.figure(figsize=(17,3))
heat_weekdayhour = mta.pivot_table(index=mta.ScheduledArrivalTime.dt.day_name(), columns=mta.ScheduledArrivalTime.dt.hour, values="DistanceFromStop")
sns.heatmap(heat_weekdayhour,)
plt.yticks(np.arange(7),weekday_order.values())
plt.show()

# %% [markdown]
# # Investigate direction reference

# %% [markdown]
# Let's see if there is any difference between the number of late busses of inbound vs outbound busses.

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
sns.barplot(y=mta.Late_Bus,x=mta.DirectionRef,palette="Greens_d",orient='vertical',) 
plt.title('Avg. Late Busses per Direction')
plt.xticks(range(0,2), ['Outbound','Inbound'])

plt.subplot(222)
sns.barplot(y=mta.Time_delay,x=mta.DirectionRef,palette="Greens_d",orient='vertical',) 
plt.title('Avg. Arrival delay per Direction')
plt.xticks(range(0,2), ['Outbound','Inbound'])
plt.show()

# %%
# Test of the mean distance between stops of late and on-time busses
inbound_df = mta[mta.DirectionRef==1]
outbound_df = mta[mta.DirectionRef==0] 
print(stats.ttest_ind(inbound_df.Late_Bus, outbound_df.Late_Bus),'\n')

# calculate correlation distance from stop and late busses
print('Correlation of distance from stops and late busses \n',mta.Late_Bus.corr(mta.DirectionRef))

# %%
plt.figure(figsize=(15,8))
sns.lineplot(inbound_df.ExpectedArrivalTime.dt.day.sort_values(), inbound_df.Late_Bus, label='Inbound') 
sns.lineplot(outbound_df.ExpectedArrivalTime.dt.day.sort_values(), outbound_df.Late_Bus, label='Outbound')
plt.xticks=(np.arange(0,30,.5))
plt.show() 
plt.figure(figsize=(15,8))
sns.lineplot(inbound_df.ExpectedArrivalTime.dt.hour.sort_values(), inbound_df.Late_Bus, label='Inbound') 
sns.lineplot(outbound_df.ExpectedArrivalTime.dt.hour.sort_values(), outbound_df.Late_Bus, label='Outbound')
plt.xticks=(np.arange(0,30,.5))
plt.show()

# %% [markdown]
# # Investigate geological features

# %%
def boroughs():
    mta['boroughs'] = '0'
    mta.loc[list(np.where((mta.PublishedLineName.str.contains('x')==False) & (mta.PublishedLineName.str.startswith('B')==True))[0]),'boroughs'] = 'Brooklyn'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('Bx')==True)[0]),'boroughs'] = 'Bronx'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('Q')==True)[0]),'boroughs'] = 'Queens'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('S')==True)[0]),'boroughs'] = 'Staten Island'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('M')==True)[0]),'boroughs'] = 'Manhattan'
    mta.loc[list(np.where(mta.PublishedLineName.str.startswith('X')==True)[0]),'boroughs'] = 'X'
     
        
boroughs()

# %%
mta.columns

# %%
#create feature for counties from lat and long of Destination location
from datetime import datetime
startTime = datetime.now()

from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)
mta['col'] = mta['VehicleLocation_Lat'].astype(str)+' '+mta['VehicleLocation_Long'].astype(str)
county = {}
for i in range(len(mta['col'].unique())):     
    county.update({ mta['col'].unique()[i] : search.by_coordinates(float(mta['col'].unique()[i].split()[0]), float(mta['col'].unique()[i].split()[1]), radius=80, returns=5)[0].values()[5] })
 
mta['VehicleLocation_counties'] = mta.col.map(county)
print(datetime.now() - startTime)

# %%
mta.groupby('dest_counties').Late_Bus.mean()

# %%
for i in range(len(mta.boroughs.unique())):
        for j in range(i+1,6):
            print(mta.boroughs.unique()[i],' vs ',mta.boroughs.unique()[j]) 
            print(stats.ttest_ind(mta[mta.boroughs==mta.boroughs.unique()[i]]['Late_Bus'], 
                                  mta[mta.boroughs==mta.boroughs.unique()[j]]['Late_Bus']))

# %%
mta.boroughs.value_counts()

# %%
sns.lineplot(mta.Time_delay,mta.ScheduledArrivalTime)

# %%
mta['rush_hour'] = 0

# %%
mta.rush_hour.value_counts()

# %%
index = mta[(mta.ScheduledArrivalTime.dt.hour>=7) & (mta.ScheduledArrivalTime.dt.hour<=9)].index  
indexs = mta[(mta.ScheduledArrivalTime.dt.hour>=16) & (mta.ScheduledArrivalTime.dt.hour<=18)].index

# %%
mta.loc[index,'rush_hour'] = 1
mta.loc[indexs,'rush_hour'] = 1

# %%
sns.barplot(y=mta.Late_Bus,x=mta.rush_hour,hue=mta.DirectionRef,palette="Greens_d",orient='vertical',) 
plt.title('Avg. Arrival delay per Direction')
 
plt.show()

# %%
sns.barplot(y=mta.Late_Bus,x=mta.rush_hour,hue=mta.DirectionRef,palette="Greens_d") 
plt.title('Avg. Arrival delay per Direction')
 
plt.show()

# %%
mta.head()

# %%
a

# %%
a = mta.loc[ind,:]
plt.figure(figsize=(10,10))
sns.scatterplot(mta.VehicleLocation_Long, mta.VehicleLocation_Lat, hue=mta.boroughs)
sns.scatterplot(a.DestinationLong, a.DestinationLat, color='black')
sns.scatterplot(a.OriginLong, a.OriginLat, color='red')

plt.show()

# %%
c = mta[mta.PublishedLineName=='B44-SBS']
b = mta[mta.start_end==mta.start_end[0]].sort_values(by='DistanceFromStop')
plt.figure(figsize=(14,14))
sns.scatterplot(mta.VehicleLocation_Long, mta.VehicleLocation_Lat,color='black')
#sns.scatterplot(b.VehicleLocation_Long, b.VehicleLocation_Lat, hue=mta.Late_Bus)
sns.scatterplot(c.VehicleLocation_Long, c.VehicleLocation_Lat, hue=c.DirectionRef)

plt.show()

# %%
len(mta.stops.unique())

# %%
ind = [27530, 93583, 103577, 84999, 115184, 113898, 66842, 61242, 36859, 83009, 107851, 40240, 241, 83919, 87300, 101096, 33935, 13909, 89637]

# %%
ind = []
for i in mta.groupby('stops').Late_Bus.mean().sort_values(ascending=False)[:16].index:
    ind.append(list(np.where(mta.stops==i)[0]))

# %%
mta.groupby('stops').Late_Bus.mean().sort_values(ascending=False)[:16].index

# %%
ind = []
for i in mta.groupby('stops').Late_Bus.mean().sort_values(ascending=False)[:16].index:
     
        ind.append(mta.stops[i].index)

# %%
mta[pd.to_numeric(mta.rush_hour==1)].ExpectedArrivalTime.dt.minute.mean()

# %%
mta[pd.to_numeric(mta.rush_hour==1)].Late_Bus.value_counts()

# %%
mta[mta.rush_hour==0].Time_delay.mean()

# %%
mta_s = pd.concat([mta, pd.get_dummies(mta.day_of_week.astype('category'),drop_first=True),], axis=1)
mta_s = pd.concat([mta_s, pd.get_dummies(mta_s.time_of_day.astype('category'),drop_first=True),], axis=1)
#mta_s = pd.concat([mta_s, pd.get_dummies(mta_s.PublishedLineName.astype('category'),drop_first=True),], axis=1)
mta_s = pd.concat([mta_s, pd.get_dummies(mta_s.boroughs.astype('category'),drop_first=True),], axis=1)
#mta_s = pd.concat([mta_s, pd.get_dummies(mta_s.day_of_week.astype('category'),drop_first=True),], axis=1) 
#mta_s = pd.concat([mta_s, pd.get_dummies(mta_s.DestinationName.astype('category'),drop_first=True),], axis=1)
mta_s.head()

# %%
mta['weekday'] = mta.ScheduledArrivalTime.dt.hour

# %%
mta_sample = pd.concat([mta[['Late_Bus',]],pd.get_dummies(mta.weekday.astype('category'),drop_first=True),], axis=1)

# %%
mta_sample.columns

# %%
features

# %%
Y = mta['Late_Bus'] 
X = mta.winsor_dist.values.reshape(-1,1)  
 
 
from sklearn.model_selection import train_test_split
# Use train_test_split to create the necessary training and test groups
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=20)

# %%
import sys
np.set_printoptions(threshold=np.inf)
mta_sample.columns

# %%
#mta_sample = a #mta_s[mta_s.ScheduledArrivalTime.dt.day<27].sample(frac=.001,random_state=20)
Y = mta['Late_Bus'] 
X = mta.winsor_dist.values.reshape(-1,1) 

from sklearn.model_selection import train_test_split
# Use train_test_split to create the necessary training and test groups
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=20)

from sklearn.model_selection import train_test_split
# Use train_test_split to create the necessary training and test groups
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=20)

 # Automatic feature selection with SelectKbest
import sklearn.feature_selection 
#from sklearn.feature_selection import f_regression
select =sklearn.feature_selection.SelectKBest(k='all')
selected_features = select.fit(X_train, y_train)
indicies_selected = selected_features.get_support(indices=True)
colnames_selected = [X.columns[i] for i in indicies_selected]
X_selected = X[colnames_selected]
print(colnames_selected)
x_train_selected = X_train[colnames_selected]
x_test_selected = X_test[colnames_selected]

#X = mta_sample
#Y = mta_sample['Late_Bus']



# Standardizing data
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()

#scaler.fit(x_train_selected) 
#X_train = scaler.transform(x_train_selected)
#X_test = scaler.transform(x_test_selected)

# %%
X_train = x_train_selected
X_test = x_test_selected

# %%
sns.heatmap(pd.DataFrame(X_train).corr())

# %%
from sklearn.preprocessing import normalize
X_train = normalize(X_train)

# %%
 # Create balanced classes for the training set
import imblearn
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=20)
X_train, y_train = ros.fit_sample(X_train, y_train)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn import ensemble 
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report

# %% [markdown]
# # Modeling

# %%
mnb = MultinomialNB() 
neighbors = KNeighborsClassifier(n_neighbors=35) 
decision_tree = tree.DecisionTreeClassifier(max_leaf_nodes=100)
rfc = ensemble.RandomForestClassifier(n_estimators=100,class_weight='balanced') 
svc = SVC(probability=True, gamma='auto') 
lr = LogisticRegression(solver='lbfgs' ) 
clf = ensemble.GradientBoostingClassifier(n_estimators=100)
models = [ decision_tree]
for model in models:
    
    print(str(model))
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    print()
    print(roc_auc_score(y_test,y_pred))
    print(recall_score(y_test,y_pred))
    print(model.score(X_test, y_test))
    print()
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=100,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
#
# 0.5182424044679083
# 0.48129554655870443
# 0.5354891632846904

# %%
Metrics(clf, X_train , y_train, X_test, y_test)
# Out:
# Accuracy score : 0.538813573957344
# ROC_AUC cross validataion score:  [0.51686739 0.53657867 0.53310673 0.51911367 0.51581772]
#
# Consfusion Matrix
# col_0        0     1
# Late_Bus
# 0         9488  7499
# 1         3183  2992
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.75      0.56      0.64     16987
#         Late       0.29      0.48      0.36      6175
#
#     accuracy                           0.54     23162
#    macro avg       0.52      0.52      0.50     23162
# weighted avg       0.63      0.54      0.56     23162
#
# AUC: 0.524

# %% [markdown]
# ### Naive Bayes

# %%
# Instatiate the model
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB(fit_prior=True)

# %%
# Confusion matrix

def AUC_ROC_plot(model,X_train,y_train,X_test,y_test,color): 
    model.fit(X_train , y_train)
    y_prob = cross_val_predict(model, X_test, y_test, method='predict_proba',cv=5)    
    auc = roc_auc_score(y_test,y_prob[:,1])
    print('AUC: %.3f' % auc)
    fpr, tpr,thresholds = roc_curve(y_test,y_prob[:,1])
    plt.plot(fpr,tpr,color)    
    plt.plot([0.0,1.0],'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristics')
    plt.xlim([0.0,1.0])     
    plt.ylim([0.0,1.0])

    
def Metrics(model, X_train , y_train, X_test, y_test,):
    model.fit(X_train , y_train)
    y_pred = model.predict(X_test) 
    
    print('Accuracy score :',model.score( X_test , y_test,))
    print('ROC_AUC cross validataion score: ',cross_val_score(model, X_test , y_test, cv=5,scoring='roc_auc'))
    print()
    print("Consfusion Matrix")
    print(pd.crosstab(y_test,y_pred))
    print()

    # Classification report
    print("Classification Report")
    from sklearn.metrics import classification_report

    target_names = ['On-time','Late']
    print(classification_report(y_test,y_pred, target_names=target_names))
    AUC_ROC_plot(model,X_train,y_train,X_test,y_test,'g')
    plt.show()
Metrics(mnb, X_train , y_train, X_test, y_test)
# Out:
# Accuracy score : 0.7333995337190226
# ROC_AUC cross validataion score:  [0.5 0.5 0.5 0.5 0.5]
#
# Consfusion Matrix
# col_0         0
# Late_Bus
# 0         16987
# 1          6175
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.73      1.00      0.85     16987
#         Late       0.00      0.00      0.00      6175
#
#     accuracy                           0.73     23162
#    macro avg       0.37      0.50      0.42     23162
# weighted avg       0.54      0.73      0.62     23162
#
# AUC: 0.500
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\keith\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# initiate GridsearchCV for best parameters
from sklearn.model_selection import GridSearchCV
def gridsearch(model, X_train , y_train, param_grid):    
    grid = GridSearchCV(model, param_grid, cv=3, scoring='roc_auc', return_train_score=True)
    grid.fit(X_train , y_train)
    print(grid.best_params_)
    print(grid.best_score_)
    
    
param_grid = dict(alpha=np.arange(1,5,1),fit_prior=(True,False))    
gridsearch(mnb, X_train , y_train, param_grid)
# Out:
# {'alpha': 1, 'fit_prior': True}
# 0.6060748565405366

# %%
# refit model with new prams
mnb = MultinomialNB(alpha=1, fit_prior=True)
Metrics(mnb, X_train , y_train,X_test,y_test)
# Out:
# Accuracy score : 0.6275100401606426
# ROC_AUC cross validataion score:  [0.6195552  0.59428872 0.59257797 0.59351351 0.63290541]
#
# Consfusion Matrix
# col_0       0    1
# Late_Bus
# 0         492  251
# 1         120  133
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.80      0.66      0.73       743
#         Late       0.35      0.53      0.42       253
#
#    micro avg       0.63      0.63      0.63       996
#    macro avg       0.58      0.59      0.57       996
# weighted avg       0.69      0.63      0.65       996
#
# AUC: 0.605

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
neighbors = KNeighborsClassifier(algorithm='auto', n_neighbors=20) 
Metrics(neighbors, X_train , y_train, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-206-b9c5297371b4> in <module>
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 neighbors = KNeighborsClassifier(algorithm='auto', n_neighbors=20)
# ----> 3 Metrics(neighbors, X_train , y_train, X_test, y_test)
#       4
#
# NameError: name 'Metrics' is not defined

# %%
param_grid = 
gridsearch(neighbors, X_train , y_train, param_grid)
# Out:
#   File "<ipython-input-291-e4e2249c1885>", line 1
#     param_grid =
#                  ^
# SyntaxError: invalid syntax

# %%
# refit model with new params 
neighbors = KNeighborsClassifier(n_neighbors=2,weights='distance',p=2)
neighbors = KNeighborsClassifier(algorithm='auto', n_neighbors=20) 
Metrics(neighbors, X_train , y_train, X_test, y_test)
# Out:
# Accuracy score : 0.7439759036144579
# ROC_AUC cross validataion score:  [0.59442032 0.58560337 0.58231346 0.545      0.59621622]
#
# Consfusion Matrix
# col_0       0   1
# Late_Bus
# 0         729  14
# 1         241  12
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.75      0.98      0.85       743
#         Late       0.46      0.05      0.09       253
#
#    micro avg       0.74      0.74      0.74       996
#    macro avg       0.61      0.51      0.47       996
# weighted avg       0.68      0.74      0.66       996
#
# AUC: 0.578

# %% [markdown]
# The model did poorly when n_neighbors was set at 10. Our test set is imbalanced so the neighbors for the under-reperesented class are sparce. Increasing the n_neighbors significantly improved the results. There is still obviouly room for improvment but that could come from better preprocessing.

# %% [markdown]
# ### Desision trees

# %%
from sklearn import tree
# Initialize and train decision tree.
decision_tree = tree.DecisionTreeClassifier(max_features= 'sqrt', random_state=20,)
Metrics(decision_tree, X_train , y_train, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-207-44ae02d9a3f4> in <module>
#       2 # Initialize and train decision tree.
#       3 decision_tree = tree.DecisionTreeClassifier(max_features= 'sqrt', random_state=20,)
# ----> 4 Metrics(decision_tree, X_train , y_train, X_test, y_test)
#
# NameError: name 'Metrics' is not defined

# %%
# initiate GridsearchCV
param_grid = dict(max_depth=range(30,80,10), max_leaf_nodes=range(300,600,100) )
gridsearch(decision_tree, X_train , y_train, param_grid)
# Out:
# {'max_depth': 30, 'max_leaf_nodes': 300}
# 0.6191912596781233

# %%
# refit model with new params
decision_tree = tree.DecisionTreeClassifier(criterion='gini', max_depth=10000, max_features=None,
                                            max_leaf_nodes=2 ,random_state=20,class_weight='balanced')
Metrics(decision_tree, X_train , y_train, X_test, y_test)
# Out:
# Accuracy score : 0.5160642570281124
# ROC_AUC cross validataion score:  [0.58303724 0.56060008 0.5670483  0.55594595 0.61905405]
#
# Consfusion Matrix
# col_0       0    1
# Late_Bus
# 0         334  409
# 1          73  180
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.82      0.45      0.58       743
#         Late       0.31      0.71      0.43       253
#
#    micro avg       0.52      0.52      0.52       996
#    macro avg       0.56      0.58      0.50       996
# weighted avg       0.69      0.52      0.54       996
#
# AUC: 0.565

# %% [markdown]
# ### Random forrest

# %%
from sklearn import ensemble
from sklearn.model_selection import cross_val_score

# instantiate model
rfc = ensemble.RandomForestClassifier(n_estimators=30) 
Metrics(rfc, X_train , y_train, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-208-1c12605371a8> in <module>
#       4 # instantiate model
#       5 rfc = ensemble.RandomForestClassifier(n_estimators=30)
# ----> 6 Metrics(rfc, X_train , y_train, X_test, y_test)
#
# NameError: name 'Metrics' is not defined

# %%
# initiate GridsearchCV
param_grid = dict(max_depth=range(1,6,1), max_leaf_nodes=range(2,10,1))
gridsearch(decision_tree, X_train , y_train, param_grid)
# Out:
# {'max_depth': 4, 'max_leaf_nodes': 9}
# 0.6122879410638925

# %%
# refit model with new params
rfc = ensemble.RandomForestClassifier(n_estimators=1000, max_depth=4, max_leaf_nodes=9,class_weight='balanced') 
Metrics(rfc, X_train , y_train, X_test, y_test)
# Out:
# Accuracy score : 0.5652610441767069
# ROC_AUC cross validataion score:  [0.63929464 0.60034215 0.54967759 0.56986486 0.59682432]
#
# Consfusion Matrix
# col_0       0    1
# Late_Bus
# 0         399  344
# 1          89  164
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.82      0.54      0.65       743
#         Late       0.32      0.65      0.43       253
#
#    micro avg       0.57      0.57      0.57       996
#    macro avg       0.57      0.59      0.54       996
# weighted avg       0.69      0.57      0.59       996
#
# AUC: 0.585

# %%
precision_recall_plot (rfc,X_test,y_test) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-300-6222a0721327> in <module>
# ----> 1 precision_recall_plot (rfc,X_test,y_test)
#       2 plt.show()
#
# NameError: name 'precision_recall_plot' is not defined

# %%
y_prob = rfc.predict_proba(X_test)
y_pred_class = binarize(y_prob,0.55)
y_pred_class = y_pred_class[:,1]
 

print('Confusion Matrix:')
print(pd.crosstab( y_test,y_pred))
print()
print('Classification Report')
print(classification_report(y_test ,y_pred, target_names=target_names))
print()

print('Confusion Matrix with binarized class:')
print(pd.crosstab( y_test,y_pred_class))
print()
print('Classification report with binarized class:') 
print(classification_report(y_test ,y_pred_class, target_names=target_names))
# Out:
# Confusion Matrix:
# col_0       0    1
# Late_Bus
# 0         411  332
# 1          94  159
#
# Classification Report
#                   precision    recall  f1-score   support
#
#   positve review       0.81      0.55      0.66       743
# negative reviews       0.32      0.63      0.43       253
#
#        micro avg       0.57      0.57      0.57       996
#        macro avg       0.57      0.59      0.54       996
#     weighted avg       0.69      0.57      0.60       996
#
#
# Confusion Matrix with binarized class:
# col_0     0.0  1.0
# Late_Bus
# 0         459  284
# 1         121  132
#
# Classification report with binarized class:
#                   precision    recall  f1-score   support
#
#   positve review       0.79      0.62      0.69       743
# negative reviews       0.32      0.52      0.39       253
#
#        micro avg       0.59      0.59      0.59       996
#        macro avg       0.55      0.57      0.54       996
#     weighted avg       0.67      0.59      0.62       996

# %% [markdown]
# ### Logistic regression

# %%
# Declare a logistic regression classifier.
lr = LogisticRegression(random_state=20, fit_intercept=False ,solver='saga',max_iter=100, penalty='l1',C=1) 
 
Metrics(lr, X_train , y_train, X_test, y_test) 


# Display.
print()
print('Coefficients')
print(fit.coef_)
print(fit.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-209-4794059f2d3e> in <module>
#       2 lr = LogisticRegression(random_state=20, fit_intercept=False ,solver='saga',max_iter=100, penalty='l1',C=1)
#       3
# ----> 4 Metrics(lr, X_train , y_train, X_test, y_test)
#       5
#       6
#
# NameError: name 'Metrics' is not defined

# %%
# initiate GridsearchCV
param_grid = dict(max_iter=range(2,55,1),class_weight=(None,'balanced'))
gridsearch(lr, X_train , y_train, param_grid)
# Out:
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# {'class_weight': None, 'max_iter': 3}
# 0.6077860727888225
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
lr = LogisticRegression(random_state=20, fit_intercept=False ,solver='liblinear',class_weight='balanced', max_iter=15) 
 
# refit the model with new params.
fit = lr.fit(X_train, y_train)

Metrics(lr, X_train , y_train, X_test, y_test) 
print()

# Display 
print('Coefficients')
print(fit.coef_)
print(fit.intercept_)
y_pred = lr.predict(X_test)
# Out:
# Accuracy score : 0.6275100401606426
# ROC_AUC cross validataion score:  [0.64798    0.61468614 0.61863403 0.58256757 0.62844595]
#
# Consfusion Matrix
# col_0       0    1
# Late_Bus
# 0         492  251
# 1         120  133
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.80      0.66      0.73       743
#         Late       0.35      0.53      0.42       253
#
#    micro avg       0.63      0.63      0.63       996
#    macro avg       0.58      0.59      0.57       996
# weighted avg       0.69      0.63      0.65       996
#
# AUC: 0.612
#
# Coefficients
# [[-0.30633663  0.27808635  0.10812657  0.04000211  0.44207154 -0.5057509
#    0.03530981]]
# 0.0

# %%
precision_recall_plot (lr,X_test,y_test) 
plt.show()

# %%
y_prob = lr.predict_proba(X_test)
y_pred_class = binarize(y_prob,0.12)
y_pred_class = y_pred_class[:,1]
 

print('Confusion Matrix:')
print(pd.crosstab( y_test,y_pred))
print()
print('Classification Report')
print(classification_report(y_test ,y_pred, target_names=target_names))
print()

print('Confusion Matrix with binarized class:')
print(pd.crosstab( y_test,y_pred_class))
print()
print('Classification report with binarized class:') 
print(classification_report(y_test ,y_pred_class, target_names=target_names))
# Out:
# Confusion Matrix:
# col_0       0    1
# Late_Bus
# 0         480  353
# 1         130  198
#
# Classification Report
#                   precision    recall  f1-score   support
#
#   positve review       0.79      0.58      0.67       833
# negative reviews       0.36      0.60      0.45       328
#
#        micro avg       0.58      0.58      0.58      1161
#        macro avg       0.57      0.59      0.56      1161
#     weighted avg       0.67      0.58      0.60      1161
#
#
# Confusion Matrix with binarized class:
# col_0     1.0
# Late_Bus
# 0         833
# 1         328
#
# Classification report with binarized class:
#                   precision    recall  f1-score   support
#
#   positve review       0.00      0.00      0.00       833
# negative reviews       0.28      1.00      0.44       328
#
#        micro avg       0.28      0.28      0.28      1161
#        macro avg       0.14      0.50      0.22      1161
#     weighted avg       0.08      0.28      0.12      1161
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
svc = SVC(gamma='auto',probability=True) 
Metrics(svc, X_train , y_train, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-210-af7526b2f8a4> in <module>
#       1 from sklearn.svm import SVC
#       2 svc = SVC(gamma='auto',probability=True)
# ----> 3 Metrics(svc, X_train , y_train, X_test, y_test)
#
# NameError: name 'Metrics' is not defined

# %%
param_grid = dict(C=np.arange(.1,5,.1))
gridsearch(lr, X_train , y_train, param_grid)

# %%
# refit model with new params
svc = SVC(kernel='linear',class_weight='balanced',probability=True) 
Metrics(svc, X_train , y_train, X_test, y_test)
# Out:
# Accuracy score : 0.5160642570281124
# ROC_AUC cross validataion score:  [0.6514015  0.56652191 0.61698908 0.60648649 0.63716216]
#
# Consfusion Matrix
# col_0       0    1
# Late_Bus
# 0         334  409
# 1          73  180
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.82      0.45      0.58       743
#         Late       0.31      0.71      0.43       253
#
#    micro avg       0.52      0.52      0.52       996
#    macro avg       0.56      0.58      0.50       996
# weighted avg       0.69      0.52      0.54       996
#
# AUC: 0.588

# %%
precision_recall_plot (svc,X_test,y_test) 
plt.show()

# %%
y_prob = svc.predict_proba(X_test)
y_pred_class = binarize(y_prob,0.51)
y_pred_class = y_pred_class[:,1]
 

print('Confusion Matrix:')
print(pd.crosstab( y_test,y_pred))
print()
print('Classification Report')
print(classification_report(y_test ,y_pred, target_names=target_names))
print()

print('Confusion Matrix with binarized class:')
print(pd.crosstab( y_test,y_pred_class))
print()
print('Classification report with binarized class:') 
print(classification_report(y_test ,y_pred_class, target_names=target_names))
# Out:
# Confusion Matrix:
# col_0       0    1
# Late_Bus
# 0         368  465
# 1         87   241
#
# Classification Report
#                   precision    recall  f1-score   support
#
#   positve review       0.81      0.44      0.57       833
# negative reviews       0.34      0.73      0.47       328
#
#        micro avg       0.52      0.52      0.52      1161
#        macro avg       0.58      0.59      0.52      1161
#     weighted avg       0.68      0.52      0.54      1161
#
#
# Confusion Matrix with binarized class:
# col_0     0.0
# Late_Bus
# 0         833
# 1         328
#
# Classification report with binarized class:
#                   precision    recall  f1-score   support
#
#   positve review       0.72      1.00      0.84       833
# negative reviews       0.00      0.00      0.00       328
#
#        micro avg       0.72      0.72      0.72      1161
#        macro avg       0.36      0.50      0.42      1161
#     weighted avg       0.51      0.72      0.60      1161
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\keith\appdata\local\programs\python\python37\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Gradient boost

# %%
from sklearn import ensemble 

# Initialize and fit the model.
clf = ensemble.GradientBoostingClassifier(n_estimators=500,max_depth=2,
                                          loss='deviance', random_state=20) 
Metrics(clf, X_train , y_train, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-211-37bc24dcc4c5> in <module>
#       4 clf = ensemble.GradientBoostingClassifier(n_estimators=500,max_depth=2,
#       5                                           loss='deviance', random_state=20)
# ----> 6 Metrics(clf, X_train , y_train, X_test, y_test)
#
# NameError: name 'Metrics' is not defined

# %%
# initiate GridsearchCV
param_grid = dict(max_depth=range(1,6,1), max_leaf_nodes=range(2,10,1))
Metrics(svc, X_train , y_train, X_test, y_test)

# %%
# refit model with new params.
clf = ensemble.GradientBoostingClassifier(n_estimators=500,max_depth=2,
                                          loss='deviance', random_state=20) 
Metrics(clf, X_train , y_train, X_test, y_test)
# Out:
# Accuracy score : 0.572289156626506
# ROC_AUC cross validataion score:  [0.60442163 0.59968417 0.52954336 0.56554054 0.56628378]
#
# Consfusion Matrix
# col_0       0    1
# Late_Bus
# 0         411  332
# 1          94  159
#
# Classification Report
#               precision    recall  f1-score   support
#
#      On-time       0.81      0.55      0.66       743
#         Late       0.32      0.63      0.43       253
#
#    micro avg       0.57      0.57      0.57       996
#    macro avg       0.57      0.59      0.54       996
# weighted avg       0.69      0.57      0.60       996
#
# AUC: 0.572

# %%
precision_recall_plot (clf,X_test,y_test) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-5c18a58d8062> in <module>
# ----> 1 precision_recall_plot (clf,X_test,y_test)
#       2 plt.show()
#
# NameError: name 'precision_recall_plot' is not defined

# %%
y_prob = clf.predict_proba(X_test)
y_pred_class = binarize(y_prob,0.51)
y_pred_class = y_pred_class[:,1]
 

print('Confusion Matrix:')
print(pd.crosstab( y_test,y_pred))
print()
print('Classification Report')
print(classification_report(y_test ,y_pred, target_names=target_names))
print()

print('Confusion Matrix with binarized class:')
print(pd.crosstab( y_test,y_pred_class))
print()
print('Classification report with binarized class:') 
print(classification_report(y_test ,y_pred_class, target_names=target_names))
# Out:
# Confusion Matrix:
# col_0       0    1
# Late_Bus
# 0         492  251
# 1         120  133
#
# Classification Report
#                   precision    recall  f1-score   support
#
#   positve review       0.80      0.66      0.73       743
# negative reviews       0.35      0.53      0.42       253
#
#        micro avg       0.63      0.63      0.63       996
#        macro avg       0.58      0.59      0.57       996
#     weighted avg       0.69      0.63      0.65       996
#
#
# Confusion Matrix with binarized class:
# col_0     0.0  1.0
# Late_Bus
# 0         453  290
# 1         117  136
#
# Classification report with binarized class:
#                   precision    recall  f1-score   support
#
#   positve review       0.79      0.61      0.69       743
# negative reviews       0.32      0.54      0.40       253
#
#        micro avg       0.59      0.59      0.59       996
#        macro avg       0.56      0.57      0.55       996
#     weighted avg       0.67      0.59      0.62       996

# %%
mta['dest_county'] = mta.col.map(county)

# %%
# Out:
# 0       Kings County
# 1       Bronx County
# 2       Kings County
# 3       Kings County
# 4      Queens County
# 5    New York County
# 6       Kings County
# 7       Kings County
# 8       Kings County
# 9       Bronx County
# Name: county, dtype: object

# %%
v.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
#        'VehicleLocation_Long', 'NextStopPointName', 'DistanceFromStop',
#        'ExpectedArrivalTime', 'ScheduledArrivalTime', 'Time_delay', 'Late_Bus',
#        'time_of_day', 'winsor_dist', 'org_dest', 'counts', 'yeeeees', 'col',
#        'county', 'dest_counties'],
#       dtype='object')

# %%
v = mta[(mta.PublishedLineName=='B6')&(mta.RecordedAtTime.dt.day==14)].sort_values(by='RecordedAtTime')
#B6 14
scatter(v.VehicleLocation_Long,v.VehicleLocation_Lat,v.VehicleRef,False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f79ba4ea18e0> in <module>
# ----> 1 v = mta[(mta.PublishedLineName=='B6')&(mta.RecordedAtTime.dt.day==14)].sort_values(by='RecordedAtTime')
#       2 #B6 14
#       3 scatter(v.VehicleLocation_Long,v.VehicleLocation_Lat,v.VehicleRef,False)
#
# NameError: name 'mta' is not defined

# %%
from datetime import datetime
startTime = datetime.now()

from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)
mta['col'] = mta['VehicleLocation_Lat'].astype(str)+' '+mta['VehicleLocation_Long'].astype(str)
county = {}
for i in range(len(mta['col'].unique())):     
    county.update({ mta['col'].unique()[i] : search.by_coordinates(float(mta['col'].unique()[i].split()[0]), float(mta['col'].unique()[i].split()[1]), radius=80, returns=5)[0].values()[5] })
 
 
print(datetime.now() - startTime)
# Out:
# 5:09:08.992028

# %%
def LatLong_to_county(Lat,Long,type_county):
    from uszipcode import SearchEngine
    search = SearchEngine(simple_zipcode=True)
    result=[]
    mta['col'] = mta[Lat].astype(str)+' '+mta[Long].astype(str)
    for i in range(len(mta['col'].unique())):
        result.append(search.by_coordinates(float(mta['col'].unique()[i].split()[0]), float(mta['col'].unique()[i].split()[1]), radius=80, returns=5)[0].values()[5])
    county = {}
    county.update({'counties' : result, 'geo' : mta['col'].unique()})
    df.head()
   
    for i in mta['col'].unique():
        if i in list(df[df.counties=='Kings County'].geo):
            county.update({i:'Kings County'})
        if i in list(df[df.counties=='Westchester County'].geo):
            county.update({i:'Westchester County'})
        if i in list(df[df.counties=='Queens County'].geo):
            county.update({i:'Queens County'})
        if i in list(df[df.counties=='New York County'].geo):
            county.update({i:'New York County'})
        if i in list(df[df.counties=='Richmond County'].geo):
            county.update({i:'Richmond County'})
        if i in list(df[df.counties=='Bronx County'].geo):
            county.update({i:'Bronx County'})
        if i in list(df[df.counties=='Nassau County'].geo):
            county.update({i:'Nassau County'})
        if i in list(df[df.counties=='Hudson County'].geo):
            county.update({i:'Hudson County'})
        
    mta[type_county] = 0
    name_county = []
    for i in mta['col']:
        name_county.append(county.get(i))    
    mta[type_county] = name_county
    mta.drop('col',1,inplace=True)

# %%
def LatLong_to_county(Lat,Long,type_county):
    from uszipcode import SearchEngine
    search = SearchEngine(simple_zipcode=True)
    result=[]
    mta['col'] = mta[Lat].astype(str)+' '+mta[Long].astype(str)
    for i in range(len(mta['col'].unique())):
        result.append(search.by_coordinates(float(mta['col'].unique()[i].split()[0]), float(mta['col'].unique()[i].split()[1]), radius=80, returns=5)[0].values()[5])
    county = {}
    df = pd.DataFrame({'counties' : result, 'geo' : mta['col'].unique()})
    df.head()
   
    for i in mta['col'].unique():
        if i in list(df[df.counties=='Kings County'].geo):
            county.update({i:'Kings County'})
        if i in list(df[df.counties=='Westchester County'].geo):
            county.update({i:'Westchester County'})
        if i in list(df[df.counties=='Queens County'].geo):
            county.update({i:'Queens County'})
        if i in list(df[df.counties=='New York County'].geo):
            county.update({i:'New York County'})
        if i in list(df[df.counties=='Richmond County'].geo):
            county.update({i:'Richmond County'})
        if i in list(df[df.counties=='Bronx County'].geo):
            county.update({i:'Bronx County'})
        if i in list(df[df.counties=='Nassau County'].geo):
            county.update({i:'Nassau County'})
        if i in list(df[df.counties=='Hudson County'].geo):
            county.update({i:'Hudson County'})
        
    mta[type_county] = 0
    name_county = []
    for i in mta['col']:
        name_county.append(county.get(i))    
    mta[type_county] = name_county
    mta.drop('col',1,inplace=True)

# %%
mta.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
#        'VehicleLocation_Long', 'NextStopPointName', 'DistanceFromStop',
#        'ExpectedArrivalTime', 'ScheduledArrivalTime', 'Time_delay', 'Late_Bus',
#        'time_of_day'],
#       dtype='object')

# %%
mta.groupby(['org_dest','OriginName']).DistanceFromStop.max().sort_values(ascending=False)[:10]
# Out:
# org_dest                                                             OriginName
# ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via N JERSEY via MADISON  ELTINGVILLE/TRANSIT CENTER    33604.0
# WOODROW RD/VINELAND AV E MIDTOWN 57 ST via N JERSEY via MADISON      WOODROW RD/VINELAND AV        32772.0
# W 57 ST / 11 AV SUNNYSIDE via NEW JERSEY via FOREST AV               W 57 ST / 11 AV               30604.0
# E 57 ST/3 AV ARDEN HTS HUGENOT AV via NJ via DRMGOOLE                E 57 ST/3 AV                  29598.0
# HYLAN BL/RICHMOND AV (LOT) SUPER EXPRESS 42ST 1AV via NEW JERSEY     HYLAN BL/RICHMOND AV (LOT)    29541.0
# E 57 ST/3 AV TOTTENVILLE via NJ via ROSSVIL via AMBOY                E 57 ST/3 AV                  29516.0
# E 41 ST/1 AV SUPER EXPRESS ELTINGVILLE via NEW JERSEY                E 41 ST/1 AV                  29508.0
# E 57 ST/3 AV ELTINGVILLE TRANSIT CTR via NEW JERSEY                  E 57 ST/3 AV                  29345.0
# E 57 ST/3 AV SP EX TTNVLL via A KL via PK-RD via AMBY                E 57 ST/3 AV                  29230.0
# HYLAN BL/BEDELL AV E MIDTOWN 57 ST via N JERSEY via MADISON          HYLAN BL/BEDELL AV            28221.0
# Name: DistanceFromStop, dtype: float64

# %%
mta['org_dest'] = mta.OriginName.astype(str)+' '+mta.DestinationName.astype(str)

# %%
mta.groupby(['DestinationName','Late_Bus']).DistanceFromStop.mean().sort_values(ascending=False)
# Out:
# DestinationName                           Late_Bus
# SP EX TTNVLL via A KL via PK-RD via AMBY  1           13472.692308
# TOTTNVLLE via RSSVLL via PK RD via AMBOY  1            8911.888889
# TOTTENVILLE via NJ via ROSSVIL via AMBOY  1            7668.032258
# SUPER EXPRESS 57 ST via NJ via MADISON    1            6732.666667
# SUPER EXPRESS 42ST 1AV via NEW JERSEY     0            6593.869565
# E MIDTOWN 57 ST via N JERSEY via MADISON  0            6398.230769
# ELTINGVILLE TRANSIT CTR via NEW JERSEY    1            6356.880000
# SUNNYSIDE via NEW JERSEY via FOREST AV    1            6170.764706
# SUPER EXPRESS 57 ST via NJ via MADISON    0            6058.000000
# SUPER EXPRESS ELTINGVILLE via NEW JERSEY  1            5971.928571
# TOTTNVLLE via RSSVLL via PK RD via AMBOY  0            5718.800000
# TOTTENVILLE via NJ via ROSSVIL via AMBOY  0            5550.716981
# SUNNYSIDE via NEW JERSEY via FOREST AV    0            4647.461538
# 57 ST via NEW JERSEY via MADISON          0            4607.104167
# ARDEN HTS HUGENOT AV via NJ via DRMGOOLE  1            4420.386861
# E MIDTOWN 57 ST via N JERSEY via MADISON  1            3098.627907
# ELTINGVILLE TRANSIT CTR via NEW JERSEY    0            3054.900000
# PT RICHMOND via GANNON AV                 1            2972.000000
# TRAVIS                                    0            2618.157895
# FLORAL PARK via HILLSIDE                  1            2596.227273
# ROSEDALE via MERRICK                      1            2495.064516
# TRAVIS                                    1            2354.500000
# ARDEN HTS HUGUENOT AV                     1            2258.333333
# 23 STREET via CHURCH                      1            2199.166667
# ARDEN HTS HUGENOT AV via NJ via DRMGOOLE  0            2151.016484
# ELVLE TRANS CTR via F CAP BL via GFRDS L  1            2092.590164
# ARDEN HTS HUGUENOT AV                     0            2064.000000
# CONEY ISLAND SEA GATE via BROADWAY        1            2062.000000
# ANNADALE RD                               1            1943.818182
# DOWNTOWN VESEY ST via CHURCH via MURRAY   1            1914.692308
#                                                           ...
# LINCOLN CTR WEST END AV XTOWN             1              52.857143
# WEST SIDE BWAY - 106 ST XTOWN             1              52.718750
# AVENUE S                                  0              51.000000
# NARROWS AV                                0              50.000000
# LTD ST GEORGE via FOREST                  1              49.000000
# SHEEPSHEAD BAY STA                        0              48.000000
# AVENUE "D" CROSSTOWN                      1              47.666667
# 32 AV  CPL KENNEDY                        0              47.000000
# JAMAICA HILLSIDE - 153 via LIBERTY        1              45.869565
# HARLEM ST NICHLAS                         1              45.615385
# EAST SIDE 1 AV CROSSTOWN                  1              45.562500
# WEST ST CROSSTOWN                         1              41.944444
# 36 ST - 5 AV                              0              40.000000
# FOSTER AV FLATBUSH AV                     1              40.000000
# ARLINGTON SOUTH AV ARLIGTON PL            1              38.000000
# LITTLE NECK LIRR STATION via JAMAICA AV   1              32.500000
# TOTTENVILLE via HYLAN                     0              30.600000
# MIDWOOD KINGS HWY STA                     1              30.380952
# 108 ST H HRDNG EXY                        0              30.000000
# BEECHHURST POWELS COVE BL via 154 ST      1              27.000000
# 133 ST - BROADWAY                         1              26.333333
# H GRANT CIR                               0              26.000000
# FLATBUSH AV                               1              21.285714
# HAMILTON HTS  BWAY-145 ST                 1              20.800000
# 108 ST H HRDNG EXY                        1              20.000000
# LTD ST GEORGE via CASTLETON               1              19.000000
# BRIGHTON AV CASTLETON AV                  0              18.000000
# SAND LA FR CPDNO BL                       0              11.000000
# CANRSE PIER                               1               6.000000
# 36 ST                                     1               4.000000
# Name: DistanceFromStop, Length: 1156, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-6b9d48229d7a> in <module>
# ----> 1 plt.barh(x='DestinationName', y='Late_Bus', data=mta )
#
# TypeError: barh() missing 1 required positional argument: 'width'

# %%
len(mta.stops.unique())
# Out:
# 1031

# %%
w = mta[['DestinationName','Time_delay','Late_Bus','DistanceFromStop']].sort_values(by='DistanceFromStop',ascending=False).head(20)
#w.reset_index(level=0, inplace=True)
w
# Out:
#                                  DestinationName  Time_delay  Late_Bus  \
# 49130   E MIDTOWN 57 ST via N JERSEY via MADISON         0.0         0
# 70217   E MIDTOWN 57 ST via N JERSEY via MADISON        -7.0         0
# 66054   E MIDTOWN 57 ST via N JERSEY via MADISON         4.0         0
# 85897   E MIDTOWN 57 ST via N JERSEY via MADISON         1.0         0
# 26096   E MIDTOWN 57 ST via N JERSEY via MADISON         0.0         0
# 27507     SUNNYSIDE via NEW JERSEY via FOREST AV        12.0         1
# 8379      SUNNYSIDE via NEW JERSEY via FOREST AV        17.0         1
# 14536   ARDEN HTS HUGENOT AV via NJ via DRMGOOLE        21.0         1
# 36297   ARDEN HTS HUGENOT AV via NJ via DRMGOOLE         8.0         1
# 108832     SUPER EXPRESS 42ST 1AV via NEW JERSEY         2.0         0
# 107700  TOTTENVILLE via NJ via ROSSVIL via AMBOY         0.0         0
# 35207   SUPER EXPRESS ELTINGVILLE via NEW JERSEY        25.0         1
# 30354   E MIDTOWN 57 ST via N JERSEY via MADISON        -9.0         0
# 77418   ARDEN HTS HUGENOT AV via NJ via DRMGOOLE        13.0         1
# 11464   TOTTENVILLE via NJ via ROSSVIL via AMBOY         7.0         0
# 26021   TOTTENVILLE via NJ via ROSSVIL via AMBOY         7.0         0
# 84854     ELTINGVILLE TRANSIT CTR via NEW JERSEY        32.0         1
# 107083  TOTTENVILLE via NJ via ROSSVIL via AMBOY         6.0         0
# 112136  E MIDTOWN 57 ST via N JERSEY via MADISON        -6.0         0
# 36465   TOTTENVILLE via NJ via ROSSVIL via AMBOY        20.0         1
#
#         DistanceFromStop
# 49130            33604.0
# 70217            32913.0
# 66054            32772.0
# 85897            32419.0
# 26096            31555.0
# 27507            30604.0
# 8379             29887.0
# 14536            29598.0
# 36297            29569.0
# 108832           29541.0
# 107700           29516.0
# 35207            29508.0
# 30354            29444.0
# 77418            29443.0
# 11464            29368.0
# 26021            29356.0
# 84854            29345.0
# 107083           29343.0
# 112136           29311.0
# 36465            29272.0

# %%
mta.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
#        'VehicleLocation_Long', 'NextStopPointName', 'DistanceFromStop',
#        'ExpectedArrivalTime', 'ScheduledArrivalTime', 'Time_delay', 'Late_Bus',
#        'time_of_day', 'winsor_dist', 'org_dest'],
#       dtype='object')

# %%
mta.sort_values(by='DistanceFromStop', ascending=False)[:10]
# Out:
#             RecordedAtTime DirectionRef PublishedLineName  \
# 108832                 W 42 ST/8 AV           29541.0 2017-06-22 07:17:10
#
#        ScheduledArrivalTime  Time_delay  Late_Bus time_of_day  winsor_dist  \
# 49130   2017-06-05 06:53:00         0.0         0     morning        384.0
# 70217   2017-06-13 08:15:00        -7.0         0     morning        384.0
# 66054   2017-06-08 10:34:00         4.0         0     morning        384.0
# 85897   2017-06-05 07:31:00         1.0         0     morning        384.0
# 26096   2017-06-15 06:47:00         0.0         0     morning        384.0
# 27507   2017-06-13 17:38:09        12.0         1     evening        384.0
# 8379    2017-06-14 17:53:45        17.0         1     evening        384.0
# 14536   2017-06-23 16:40:26        21.0         1   afternoon        384.0
# 36297   2017-06-22 17:39:15         8.0         1     evening        384.0
# 108832  2017-06-22 07:15:00         2.0         0     morning        384.0
#
#                                                  org_dest
# 49130   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...
# 70217   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...
# 66054   WOODROW RD/VINELAND AV E MIDTOWN 57 ST via N J...
# 85897   WOODROW RD/VINELAND AV E MIDTOWN 57 ST via N J...
# 26096   WOODROW RD/VINELAND AV E MIDTOWN 57 ST via N J...
# 27507   W 57 ST / 11 AV SUNNYSIDE via NEW JERSEY via F...
# 8379    W 57 ST / 11 AV SUNNYSIDE via NEW JERSEY via F...
# 14536   E 57 ST/3 AV ARDEN HTS HUGENOT AV via NJ via D...
# 36297   E 57 ST/3 AV ARDEN HTS HUGENOT AV via NJ via D...
# 108832  HYLAN BL/RICHMOND AV (LOT) SUPER EXPRESS 42ST ...

# %%
# returns value counts of individual org_dest value counts
def v_counts(x):
    return mta[mta.org_dest==x].org_dest.value_counts()[0];
#mta['counts'] = mta.org_dest.apply(v_counts)

# %%
mta['org_dest'][1]
# Out:
# 'WHITE PLAINS RD/E GUN HILL RD THE HUB 150 ST via WEBSTER'

# %%
countsss = {}

countsss.update({mta.org_dest[1]:mta[mta['org_dest']==mta['org_dest'][1]]['org_dest'].value_counts()[0]})
countsss
# Out:
# {'WHITE PLAINS RD/E GUN HILL RD THE HUB 150 ST via WEBSTER': 226}

# %%
#make a dict of bus values counts
def counting(col):
    countsss = {}
    for i in range(len(mta[col].unique())):
         
        countsss.update({mta[col][i]:mta[mta[col]==mta[col][i]][col].value_counts()[0]})
    return int(countsss);
mta['yeeeees'] = mta.org_dest.map(counting('org_dest'))

# %%
print(counting('org_dest'))
# Out:
# {'KNAPP ST/SHORE PKY SBS WLMSBRG BRDG PLZ via NSTRND via RGRS': 292, 'WHITE PLAINS RD/E GUN HILL RD THE HUB 150 ST via WEBSTER': 226, '87 ST/4 Av MANHATTAN BEACH KINGSBORO CC': 356, 'JACKSON AV/QUEENS PZ S DOWNTOWN BKLYN FULTON MALL': 285, '132 ST/20 AV JAMAICA 165 ST TERM via F LEWIS': 181, 'ST NICHOLAS AV/W 124 ST FT GEORGE 193 ST via MADSON via ST. NICH': 14, 'POSTAL FACILITY RD/IN FRONT OF FACILITY RIDGEWOOD FOREST AV': 206, 'FLATBUSH AV/KINGS PLAZA LTD DNTWN BKLYN CADMAN PLZ via FLATBUSH': 218, 'ALABAMA AV / FULTON
# 49130   2017-06-05 06:53:00         0.0         0     morning        384.0
# 52124   2017-06-12 07:44:00        -7.0         0     morning        384.0
# 52989   2017-06-22 09:18:00        -8.0         0     morning        384.0
# 54362   2017-06-20 09:38:59         7.0         0     morning        304.0
# 55088   2017-06-12 08:27:00        -2.0         0     morning        384.0
# 60166   2017-06-22 07:09:00        -3.0         0     morning        384.0
# 60625   2017-06-13 08:23:00        31.0         1     morning        158.0
# 61741   2017-06-14 07:25:00         0.0         0     morning        240.0
# 64460   2017-06-08 08:15:48         1.0         0     morning        261.0
# 66023   2017-06-22 08:15:00        -9.0         0     morning        384.0
# 69967   2017-06-26 07:44:00       -12.0         0     morning        384.0
# 70217   2017-06-13 08:15:00        -7.0         0     morning        384.0
# 84174   2017-06-12 07:59:11        -6.0         0     morning        235.0
# 86161   2017-06-26 09:02:00         3.0         0     morning        384.0
# 86976   2017-06-30 08:00:00        -5.0         0     morning        384.0
# 87261   2017-06-05 09:22:59        -1.0         0     morning        118.0
# 94428   2017-06-20 07:00:36         6.0         0     morning        157.0
# 97074   2017-06-05 09:22:59        29.0         1     morning        298.0
# 99733   2017-06-06 06:53:00        10.0         1     morning        240.0
# 109057  2017-06-29 06:50:00         1.0         0     morning        320.0
# 109523  2017-06-29 08:27:02         3.0         0     morning         75.0
# 110148  2017-06-19 07:09:00        -4.0         0     morning        384.0
# 110780  2017-06-19 08:34:00        11.0         1     morning        384.0
# 112136  2017-06-01 08:15:00        -6.0         0     morning        384.0
#
#                                                  org_dest  counts
# 1119    ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 3104    ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 3435    ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 3916    ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 7584    ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 13064   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 13548   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 15022   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 17977   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 25981   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 26631   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 28352   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 29006   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 30354   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 30413   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 30727   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 38597   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 39187   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 41713   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 41888   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 44321   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 46465   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 49130   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 52124   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 52989   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 54362   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 55088   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 60166   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 60625   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 61741   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 64460   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 66023   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 69967   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 70217   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 84174   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 86161   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 86976   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 87261   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 94428   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 97074   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 99733   ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 109057  ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 109523  ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 110148  ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 110780  ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46
# 112136  ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via...      46

# %%
list(mta.sort_values(by='DistanceFromStop', ascending=False)[['org_dest','counts','DistanceFromStop','Late_Bus']][:10].org_dest)
# Out:
# ['ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via N JERSEY via MADISON',
#  'ELTINGVILLE/TRANSIT CENTER E MIDTOWN 57 ST via N JERSEY via MADISON',
#  'WOODROW RD/VINELAND AV E MIDTOWN 57 ST via N JERSEY via MADISON',
#  'WOODROW RD/VINELAND AV E MIDTOWN 57 ST via N JERSEY via MADISON',
#  'WOODROW RD/VINELAND AV E MIDTOWN 57 ST via N JERSEY via MADISON',
#  'W 57 ST / 11 AV SUNNYSIDE via NEW JERSEY via FOREST AV',
#  'W 57 ST / 11 AV SUNNYSIDE via NEW JERSEY via FOREST AV',
#  'E 57 ST/3 AV ARDEN HTS HUGENOT AV via NJ via DRMGOOLE',
#  'E 57 ST/3 AV ARDEN HTS HUGENOT AV via NJ via DRMGOOLE',
#  'HYLAN BL/RICHMOND AV (LOT) SUPER EXPRESS 42ST 1AV via NEW JERSEY']

# %%
e = mta[['org_dest','Time_delay','Late_Bus','DistanceFromStop']].sort_values(by='DistanceFromStop',ascending=False).head(20)
#w.reset_index(level=0, inplace=True)

plt.figure(figsize=(10,10))
sns.barplot(x='Late_Bus', y='org_dest', data=e, order=e.org_dest, palette="Greens_d")
plt.title('Arrival Delay\n'+'(orderd by distance from stop)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Time_delay', y='DestinationName', data=w, order=w.DestinationName, palette="Greens_d")
plt.title('Arrival Delay\n'+'(orderd by distance from stop)')
plt.xticks(rotation=90)
plt.show()

# %%
mta['VehicleLoc_counties'] = mta.

# %%
order = list(mta.groupby('DestinationName').Late_Bus.mean().sort_values(ascending=False).index)

# %%
order = pd.DataFrame(order)

# %%
order.reset_index(level=0, inplace=True)

# %%
order.sort_values(by='Late_Bus' , ascending=False).reset_index(level=0, inplace=True)

# %%
mta.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation_Lat',
#        'VehicleLocation_Long', 'NextStopPointName', 'DistanceFromStop',
#        'ExpectedArrivalTime', 'ScheduledArrivalTime', 'Time_delay', 'Late_Bus',
#        'time_of_day', 'winsor_dist', 'org_dest', 'counts', 'yeeeees', 'col',
#        'county'],
#       dtype='object')

# %%
def scatter(X,Y,HUE,Legend):
    plt.figure(figsize=(10,10))
    sns.scatterplot(x=X,y=Y,hue=HUE,legend=Legend)
scatter(mta.VehicleLocation_Long,mta.VehicleLocation_Lat,mta.PublishedLineName,False)

# %%
len(mta.PublishedLineName.unique())
# Out:
# 236

# %%
h = mta[mta.RecordedAtTime.dt.day==14]

# %%
sns.scatterplot(h.VehicleLocation_Long,h.VehicleLocation_Lat)

# %%
sns.scatterplot(mta.VehicleLocation_Long,mta.VehicleLocation_Lat,hue=mta.dest_counties)

# %%
mta['Vheicle']

# %%
mta['dest_counties'] = mta.col.map(county)

# %%
h.county.value_counts()
# Out:
# Kings County          1333
# New York County       1166
# Queens County          841
# Bronx County           798
# Richmond County        350
# Union County             5
# Hudson County            5
# Westchester County       2
# Middlesex County         2
# Essex County             2
# Name: county, dtype: int64

# %%
h.iloc[list(np.where(h.county=='Nassau County')[0])]
# Out:
#             RecordedAtTime DirectionRef PublishedLineName  \
# 459    2017-06-03 17:48:14            0               Q85
# 558    2017-06-18 16:42:36            1               Q36
# 905    2017-06-08 05:05:32            1               Q46
# 1051   2017-06-23 16:01:01            0               Q85
# 1642   2017-06-11 17:51:19            1                Q5
# 1657   2017-06-17 22:11:38            1               Q36
# 2353   2017-06-28 19:19:56            0               Q85
# 2383   2017-06-03 12:48:00            0               Q36
# 3016   2017-06-08 13:45:53            1               Q36
# 3067   2017-06-20 20:46:14            0                Q5
# 3175   2017-06-13 21:44:56            0               Q36
# 3644   2017-06-23 21:30:46            1               Q85
# 3788   2017-06-28 07:39:03            0                Q5
# 4693   2017-06-18 15:03:03            0                Q5
# 5818   2017-06-20 17:56:04            0               Q85
# 112293   afternoon        170.0
# 112357     morning         68.0
# 112737       night        384.0
# 113177     morning        168.0
# 113401     morning          8.0
# 114499   afternoon          6.0
# 114778     morning        384.0
# 114802     evening        131.0
# 115015     evening        384.0
# 115130       night        162.0
#
#                                                  org_dest  counts  yeeeees  \
# 459                          TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 558                 256 ST/JAMAICA AV JAMAICA 165 ST TERM     103    103.0
# 905     L.I.J.MEDICAL RDWY/271 ST KEW GARDENS QUEENS B...     226    226.0
# 1051                         TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 1642    WEST CIRCLE DR /PARKING STRUCTURE JAMAICA PRSN...     183    183.0
# 1657                256 ST/JAMAICA AV JAMAICA 165 ST TERM     103    103.0
# 2353                         TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 2383    165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 3016                256 ST/JAMAICA AV JAMAICA 165 ST TERM     103    103.0
# 3067             TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 3175    165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 3644    WEST CIRCLE DR /PARKING STRUCTURE JAMAICA PRSN...     131      NaN
# 3788             TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 4693             TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 5818                         TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 6103                         TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 6777    165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 7963                         TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 8198             TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 8467    165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 9112    WEST CIRCLE DR /PARKING STRUCTURE JAMAICA PRSN...     131      NaN
# 10100            TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 10416            TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 11864   165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 11897            TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# ...                                                   ...     ...      ...
# 105274                       TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 105451           TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 105574           TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 105860              256 ST/JAMAICA AV JAMAICA 165 ST TERM     103    103.0
# 106435  WEST CIRCLE DR /PARKING STRUCTURE JAMAICA PRSN...     183    183.0
# 106659  165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 106823  WEST CIRCLE DR /PARKING STRUCTURE JAMAICA PRSN...     131      NaN
# 108452  165 ST TERM/165 ST TERM BAY 6 LTD FLORAL PK 25...      33      NaN
# 108493           TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 108695           40 AV/LITTLE NECK PY JAMAICA 165 ST TERM      71      NaN
# 109241           TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 109312  WEST CIRCLE DR /PARKING STRUCTURE JAMAICA PRSN...     183    183.0
# 109809  165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 110844  WEST CIRCLE DR /PARKING STRUCTURE JAMAICA PRSN...     131      NaN
# 111843           40 AV/LITTLE NECK PY JAMAICA 165 ST TERM      71      NaN
# 112293                       TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 112357  165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 112737  QUEENS BL/78 AV LTD LK SUCCESS LIJ HOSP via UNION     109    109.0
# 113177           TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
# 113401  165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 114499  165 ST TERM/165 ST TERM BAY 6 FLORAL PARK 257 ...     114      NaN
# 114778         256 ST/JAMAICA AV LIMITED JAMAICA 165 TERM      33      NaN
# 114802                       TEARDROP/LAYOVER GREEN ACRES     140    140.0
# 115015  WEST CIRCLE DR /PARKING STRUCTURE JAMAICA PRSN...     131      NaN
# 115130           TEARDROP/LAYOVER GREEN ACRES via MERRICK     197    197.0
#
#                                   col         county  dest_counties
# 459     40.661846000000004 -73.723145  Nassau County  Nassau County
# 558      40.707615000000004 -73.79554  Nassau County  Queens County
# 905              40.714733 -73.831238  Nassau County  Queens County
# 1051    40.661846000000004 -73.723145  Nassau County  Nassau County
# 1642             40.701683 -73.802475  Nassau County  Queens County
# 1657     40.707615000000004 -73.79554  Nassau County  Queens County
# 2353    40.661846000000004 -73.723145  Nassau County  Nassau County
# 2383              40.727818 -73.70871  Nassau County  Nassau County
# 3016     40.707615000000004 -73.79554  Nassau County  Queens County
# 3067    40.661846000000004 -73.723145  Nassau County  Nassau County
# 3175              40.727818 -73.70871  Nassau County  Nassau County
# 3644             40.701683 -73.802475  Nassau County  Queens County
# 3788    40.661846000000004 -73.723145  Nassau County  Nassau County
# 4693    40.661846000000004 -73.723145  Nassau County  Nassau County
# 5818    40.661846000000004 -73.723145  Nassau County  Nassau County
# 6103    40.661846000000004 -73.723145  Nassau County  Nassau County
# 6777              40.727818 -73.70871  Nassau County  Nassau County
# 7963    40.661846000000004 -73.723145  Nassau County  Nassau County
# 8198    40.661846000000004 -73.723145  Nassau County  Nassau County
# 8467              40.727818 -73.70871  Nassau County  Nassau County
# 9112             40.701683 -73.802475  Nassau County  Queens County
# 10100   40.661846000000004 -73.723145  Nassau County  Nassau County
# 10416   40.661846000000004 -73.723145  Nassau County  Nassau County
# 11864             40.727818 -73.70871  Nassau County  Nassau County
# 11897   40.661846000000004 -73.723145  Nassau County  Nassau County
# ...                               ...            ...            ...
# 105274  40.661846000000004 -73.723145  Nassau County  Nassau County
# 105451  40.661846000000004 -73.723145  Nassau County  Nassau County
# 105574  40.661846000000004 -73.723145  Nassau County  Nassau County
# 105860   40.707615000000004 -73.79554  Nassau County  Queens County
# 106435           40.701683 -73.802475  Nassau County  Queens County
# 106659            40.727818 -73.70871  Nassau County  Nassau County
# 106823           40.701683 -73.802475  Nassau County  Queens County
# 108452            40.727818 -73.70871  Nassau County  Nassau County
# 108493  40.661846000000004 -73.723145  Nassau County  Nassau County
# 108695   40.707615000000004 -73.79554  Nassau County  Queens County
# 109241  40.661846000000004 -73.723145  Nassau County  Nassau County
# 109312           40.701683 -73.802475  Nassau County  Queens County
# 109809            40.727818 -73.70871  Nassau County  Nassau County
# 110844           40.701683 -73.802475  Nassau County  Queens County
# 111843   40.707615000000004 -73.79554  Nassau County  Queens County
# 112293  40.661846000000004 -73.723145  Nassau County  Nassau County
# 112357            40.727818 -73.70871  Nassau County  Nassau County
# 112737   40.754894 -73.70658900000001  Nassau County  Queens County
# 113177  40.661846000000004 -73.723145  Nassau County  Nassau County
# 113401            40.727818 -73.70871  Nassau County  Nassau County
# 114499            40.727818 -73.70871  Nassau County  Nassau County
# 114778   40.707615000000004 -73.79554  Nassau County  Queens County
# 114802  40.661846000000004 -73.723145  Nassau County  Nassau County
# 115015           40.701683 -73.802475  Nassau County  Queens County
# 115130  40.661846000000004 -73.723145  Nassau County  Nassau County
#
# [210 rows x 26 columns]

# %%
h.county.value_counts()
# Out:
# Queens County    9600
# Nassau County     210
# Name: county, dtype: int64

# %%
mta.loc[list(np.where(mta.county=='Nassau County')[0]),'county'] = 'Queens County'

# %%
h = mta[(mta.VehicleLocation_Lat<40.8)&(mta.VehicleLocation_Lat>40.6)&(mta.VehicleLocation_Long>-73.8)]
scatter(h.VehicleLocation_Long,h.VehicleLocation_Lat,mta.county,'full')

# %%
scatter(mta.VehicleLocation_Long,mta.VehicleLocation_Lat,mta.county,'full')

# %%
a.sort_values(by='Time_delay',ascending=False).OriginName[:30]
# Out:
# 68189           TRINITY PL/RECTOR ST
# 102660             W 179 ST/BROADWAY
# 63442               E 23 ST/BROADWAY
# 41078         LINCOLN RD/FLATBUSH AV
# 21900            KINGS PLZ/KINGS PLZ
# 81563              BROADWAY/W 178 ST
# 42511                   4 AV/E 10 ST
# 9117         LIVINGSTON ST/ COURT ST
# 68440     ELTINGVILLE/TRANSIT CENTER
# 17437                  E 126 ST/2 AV
# 19596              3 AV/E FORDHAM RD
# 40264                  41 RD/MAIN ST
# 68756                  39 AV /138 ST
# 110289         W 146 ST/MALCOLM X BL
# 21665         SOUTH END AV/ALBANY ST
# 34915            W 96 ST/WEST END AV
# 71460                   4 AV/E 10 ST
# 71419                  E 126 ST/2 AV
# 59698             FRONT ST / YORK ST
# 101826           3 AV/WESTCHESTER AV
# 39043                   AV U/E 54 ST
# 112861                  138 ST/37 AV
# 70503     ELTINGVILLE/TRANSIT CENTER
# 101371          ARCHER AV/MERRICK BL
# 45469           ROOSEVELT AV/MAIN ST
# 93983         CADMAN PZ W/TILLARY ST
# 94046         ROCKAWAY AV/HEGEMAN AV
# 75615               NARROWS AV/77 ST
# 35383      TOTTEN AV/CROSS ISLAND PY
# 13990      TOTTEN AV/CROSS ISLAND PY
# Name: OriginName, dtype: category
# Categories (570, object): [1 AV/125 ST, 1 AV/E 1 ST, 1 AV/E 27 ST, 116 AV/FRANCIS LEWIS BL, ..., WYCKOFF AV/DE KALB AV, WYCKOFF ST/PALMETTO ST, YUKON AV/KMART DWY, YUKON AV/WATCHMANS OFFICE]

# %%
dist = dict(mta.groupby('OriginName').DistanceFromStop.max())
mta['farthest_dist'] = mta.OriginName.map(dist)

# %%
plt.figure(figsize=(14,9))
order = a.sort_values(by='farthest_dist',ascending=False).groupby('DestinationName')['DestinationName'].tail(1)[:30]
sns.barplot(y=a.DestinationName,x=a.Late_Bus,palette="Greens_d", order=order)
plt.title('Avg. Arrival delay per Direction\n'+'(ordered by farthest distance between stops)')
plt.xticks(rotation=90)
plt.show()

# %%
c = mta[mta.PublishedLineName=='B44-SBS']
b = mta[mta.start_end==mta.start_end[0]].sort_values(by='DistanceFromStop')
plt.figure(figsize=(14,14))
sns.scatterplot(mta.VehicleLocation_Long, mta.VehicleLocation_Lat,color='black')
#sns.scatterplot(b.VehicleLocation_Long, b.VehicleLocation_Lat, hue=mta.Late_Bus)
sns.scatterplot(c.VehicleLocation_Long, c.VehicleLocation_Lat, hue=c.DirectionRef)

plt.show()
# Out:
# 570

# %%
mta.sort_values(by='farthest_dist',ascending=False)[:10] 
cc = mta[mta.PublishedLineName=='X1']
bb = mta[mta.start_end==mta.start_end[36435]].sort_values(by='DistanceFromStop')
plt.figure(figsize=(14,14))
sns.scatterplot(mta.VehicleLocation_Long, mta.VehicleLocation_Lat,color='black')
#sns.scatterplot(b.VehicleLocation_Long, b.VehicleLocation_Lat, hue=mta.Late_Bus)
sns.scatterplot(cc.VehicleLocation_Long, cc.VehicleLocation_Lat, hue=cc.DirectionRef)

plt.show()

# %%
mta.sort_values(by='Time_delay',ascending=False)[['Time_delay','PublishedLineName']].PublishedLineName[:]
# Out:
# 59698         B25
# 75615          B4
# 94046          B8
# 34915         M96
# 53347         X17
# 21900          B9
# 110289       M102
# 104767        B16
# 11271         B69
# 98204          X7
# 71460          M2
# 42511          M1
# 13990         Q13
# 82367         Q54
# 98241        Bx17
# 41078         B16
# 68756         Q13
# 8779          B83
# 68440          X1
# 34155         S78
# 70503          X1
# 21665          M9
# 9117          B45
# 35383         Q13
# 12189         B26
# 63442          X1
# 81563          M5
# 68189          X8
# 101826       Bx15
# 77998         B36
#            ...
# 84850         X31
# 61106         S48
# 47595         M96
# 50481        Bx21
# 100750        B49
# 86552          M4
# 100275        B46
# 31070          B4
# 25017         M96
# 28327         B39
# 67136         B14
# 8399      B44-SBS
# 96908          B6
# 110987         M2
# 30476     B46-SBS
# 53176         B41
# 55362        Bx17
# 18821          Q3
# 30795         S42
# 93105          X2
# 100799        Q55
# 78748         B49
# 24570         S59
# 52196         Q16
# 66592         M15
# 34823         M10
# 101737        Q30
# 21351         B38
# 11067        Bx40
# 66037        M102
# Name: PublishedLineName, Length: 115806, dtype: category
# Categories (236, object): [B1, B11, B12, B13, ..., X68, X7, X8, X9]

# %%
 
ccc = mta[mta.PublishedLineName=='B6']
bbb = mta[mta.start_end==mta.start_end[96908]].sort_values(by='DistanceFromStop')
plt.figure(figsize=(12,12))
sns.scatterplot(mta.VehicleLocation_Long, mta.VehicleLocation_Lat,color='black')
#sns.scatterplot(bbb.VehicleLocation_Long, bbb.VehicleLocation_Lat, hue=mta.Late_Bus)
#sns.scatterplot(ccc.VehicleLocation_Long, ccc.VehicleLocation_Lat, hue=ccc.Time_delay,palette='Reds_r')
sns.scatterplot(cc.VehicleLocation_Long, cc.VehicleLocation_Lat, hue=cc.Time_delay, palette='Reds_r')
 
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(mta.VehicleLocation_Long, mta.VehicleLocation_Lat, cmap=cmap, n_levels=10, shade=True);

# %%
sns.set_style('dark')
a= mta[mta.Time_delay>=7]
heatmap, xedges, yedges = np.histogram2d(a.VehicleLocation_Long, a.VehicleLocation_Lat, bins=300)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
plt.figure(figsize=(15,15))
plt.clf()
plt.imshow(heatmap.T, extent=extent, origin='lower')
plt.show()

# %%
# read the image
plt.figure(figsize=(10,10))
im = plt.imread('C:/Users\keith/Desktop/NY BUS/newyork.PNG')
plt.imshow(im)
plt.scatter(mta.VehicleLocation_Long, mta.VehicleLocation_Lat)
# show the image
plt.imshow(im)
plt.show()

# %%
plt.figure(figsize=(13,13))
img=plt.imread('C:/Users\keith/Desktop/NY BUS/newyork.PNG')

plt.imshow(img,zorder=0,extent=[mta['DestinationLong'].min(),mta['DestinationLong'].max(),mta['DestinationLat'].min(),mta['DestinationLat'].max()])
ax = plt.gca()
plt.plot(x=mta['DestinationLong'], y=mta['DestinationLong'], kind='scatter', alpha=0.4, 
     
          cmap=plt.get_cmap('jet'), colorbar=True, 
         zorder=5)
sns.scatterplot(mta.VehicleLocation_Long, mta.VehicleLocation_Lat, hue=mta.Late_Bus)      
 
plt.show()

# %%
plt.figure(figsize=(14,9))
plt.subplot(221)
sns.lineplot(a.ScheduledArrivalTime.dt.hour,a.Time_delay)
plt.title('Average Arrival Delay by hour')
plt.subplot(222)
sns.lineplot(a.ScheduledArrivalTime.dt.day,a.Time_delay)
plt.title('Average Arrival Delay by day')

plt.figure(figsize=(14,9))
plt.subplot(223)
sns.lineplot(mta.ScheduledArrivalTime.dt.hour,mta.Time_delay)
plt.title('Average Arrival Delay over 7 minutes (by hour)')
plt.subplot(224)
sns.lineplot(mta.ScheduledArrivalTime.dt.day,mta.Time_delay)
plt.title('Average Arrival Delay over 7 minutes (by day)')


plt.show()

# %%
plt.figure(figsize=(14,9))
plt.subplot(223)
sns.lineplot(mta.ScheduledArrivalTime.dt.hour,mta.Time_delay)
plt.title('Average Arrival Delay over 7 minutes (by hour)')
plt.subplot(224)
sns.lineplot(mta.ScheduledArrivalTime.dt.day,mta.Time_delay)
plt.title('Average Arrival Delay over 7 minutes (by day)')
