# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/keith/Desktop/titanic.csv')

# %%
a = df[['Fare']]

# %%
plt.plot(a, color='blue')
plt.ylim(0,550)
plt.xlim(0,900)
plt.ylabel('Fare')
plt.title('Titanic Fare')
plt.show()

# %%
# It is worth noting that some passengers paid no fare
