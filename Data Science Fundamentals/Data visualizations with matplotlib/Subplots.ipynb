# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/keith/Desktop/titanic.csv')

# %%
# Select survivors from .cvs file

a = df[df['Survived'] == 1]

# %%
# Select from survivors males and females

survived_f = a[a['Sex'] == 'female']
survived_m = a[a['Sex']=='male']

# %%
# Selcect age

Female = survived_f.loc[:, 'Age']
Male = survived_m.loc[:, 'Age']

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.hist(Male, bins=18, color='blue', density=True)
plt.ylabel('Age')
plt.title('Males Who Survived')

plt.subplot(1, 2, 2)
plt.hist(Female, bins=18, color='red', density=True)
plt.ylabel('Age')
plt.title('Females Who Survived')
plt.show()
